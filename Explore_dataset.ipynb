# %%
import pandas as pd
from plotnine import *
from termcolor import colored, cprint

# %%
data = pd.read_csv('dataset_with_labels.csv').drop('Unnamed: 0',axis=1).sample(n=5000).reset_index(drop=True)
print(data.columns)
# Out:
# Index(['subject_id', 'icustay_id', 'creatinine', 'age',
#        'arterial_pressure_systolic', 'arterial_pressure_systolic_delay',
#        'arterial_pressure_diastolic', 'arterial_pressure_diastolic_delay',
#        'heart_rate', 'heart_rate_delay', 'weight_daily', 'weight_daily_delay',
#        'temperature', 'temperature_delay', 'urine_output',
#        'urine_output_delay', 'day_urine_output', 'day_urine_output_delay',
#        'scr', 'scr_delay', 'sodium', 'sodium_delay', 'potassium',
#        'potassium_delay', 'calcium', 'calcium_delay', 'phosphor',
#        'phosphor_delay', 'hemoglobine', 'hemoglobine_delay', 'uric_acid',
#        'uric_acid_delay', 'chloride', 'chloride_delay', 'platelet_count',
#        'platelet_count_delay', 'ph_blood', 'ph_blood_delay', 'fibrinogen',
#        'fibrinogen_delay', 'urinary_sodium', 'urinary_sodium_delay',
#        'urinary_potassium', 'urinary_potassium_delay', 'urine_creatinin',
#        'urine_creatinin_delay', 'alkaline_phospatase',
#        'alkaline_phospatase_delay', 'total_protein_blood',
#        'total_protein_blood_delay', 'albumin', 'albumin_delay',
#        'total_protein_urine', 'total_protein_urine_delay', 'bilirubin',
#        'bilirubin_delay', 'c_reactive_protein', 'c_reactive_protein_delay',
#        'ethnicity', 'diagnosis', 'gender', 'creatinine_yesterday',
#        'creatinine_before_yesterday', 'label'],
#       dtype='object')

# %%
data.loc[:,'diagnosis'] = data['diagnosis'].astype('str')
for c,col in data.iteritems():
    
    Sbold = lambda x : colored(x, attrs=['bold'])
    Scyan_h = lambda x : colored(x, 'grey', 'on_cyan', attrs=['bold'])
    Sred = lambda x : colored(x, 'red', attrs=['bold'])
    Sred_h = lambda x : colored(x, 'grey', 'on_red', attrs=['bold'])
    Sgreen = lambda x : colored(x, 'green', attrs=['bold'])
    
    print('-----------------------------')
    
    print('Feature name : ' + Scyan_h(c))
    
    # Variable type
    var_type = type(col[0]).__name__
    print('Type : ' + Sbold(var_type))
    
    # Rate of missing values
    rate_na = 100*col.isnull().sum()/data.shape[0]
    if rate_na==100:
        print('Rate of missing values : ' + Sred_h(str(int(rate_na))+ '%'))
        print(Sred_h('This column is empty !'))
        # If the column is empty, don't do further tests
        continue
    elif rate_na==0:
        print('Rate of missing values : ' + Sgreen(str(int(rate_na))+ '%'))
    elif (rate_na>=50) & (rate_na<100):
        print('Rate of missing values : ' + Sred(str(int(rate_na))+ '%'))
    else:
        print('Rate of missing values : ' + Sbold(str(int(rate_na))+ '%'))
    
    # Number of unique values
    val_counts = col.value_counts()
    if val_counts.shape[0]==1:
        print('Number of unique values : ' + Sred_h(str(val_counts.shape[0])))
        print(Sred_h('This column is useless !'))
        # If the column is useless, don't do further tests
        continue
    else:
        print('Number of unique values : ' + Sbold(str(val_counts.shape[0])))
    
    # Basic statistics and plots for numerical values
    if var_type in ['int64','float64']:
        # Stats
        print('Median : ' + Sbold(int(col.median())))
        print('Mean : ' + Sbold(int(col.mean())))
        print('[Min, Max] : ' + Sbold('[' + str(int(col.min())) + ', ' + str(int(col.max())) + ']'))
        
        # Histogram
        text_size = 12
        if 'delay' in c: text_size = 10
        p = ggplot(aes(x=c), data=data.dropna(axis=0,subset=[c])) + geom_histogram(bins=50) \
        + theme_xkcd(length=30)
        print(p)
        
    # Basic statistics and plots for non-numerical values
    if var_type=='str':
        # Stats
        print('Mode : ' + Sbold(col.value_counts().index[0]))
        
        # Bar chart
        if val_counts.shape[0]<50:
            p = ggplot(aes(x=c, fill=c), data=data.dropna(axis=0,subset=[c])) + geom_bar() \
            + theme_xkcd(scale=0.5)
            print(p)
        else:
            print('10 Most frequent values : ')
            for i,val in val_counts[0:10].iteritems():
                print(Sbold(str(i) + ' (' + str(val) + ')'))
# Out:
# -----------------------------
# Feature name : subject_id
# Type : int64
# Rate of missing values : 0%
# Number of unique values : 2976
# Median : 60897
# Mean : 59934
# [Min, Max] : [124, 99985]
# <ggplot: (-9223372036564639267)>
# -----------------------------
# Feature name : icustay_id
# Type : int64
# Rate of missing values : 0%
# Number of unique values : 3239
# Median : 250479
# Mean : 249955
# [Min, Max] : [200033, 299889]
# <ggplot: (292252406)>
# -----------------------------
# Feature name : creatinine
# Type : float64
# Rate of missing values : 0%
# Number of unique values : 84
# Median : 1
# Mean : 1
# [Min, Max] : [0, 19]
# <ggplot: (-9223372036564639400)>
# -----------------------------
# Feature name : age
# Type : float64
# Rate of missing values : 0%
# Number of unique values : 3239
# Median : 65
# Mean : 70
# [Min, Max] : [16, 309]
# <ggplot: (-9223372036562418607)>
# -----------------------------
# Feature name : arterial_pressure_systolic
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 140
# Median : 118
# Mean : 120
# [Min, Max] : [0, 237]
# <ggplot: (290142840)>
# -----------------------------
# Feature name : arterial_pressure_systolic_delay
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 223
# Median : 2100
# Mean : 2619
# [Min, Max] : [0, 197940]
# <ggplot: (-9223372036571588920)>
# -----------------------------
# Feature name : arterial_pressure_diastolic
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 99
# Median : 59
# Mean : 73
# [Min, Max] : [0, 60127]
# <ggplot: (-9223372036562012640)>
# -----------------------------
# Feature name : arterial_pressure_diastolic_delay
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 224
# Median : 2100
# Mean : 2624
# [Min, Max] : [0, 197940]
# <ggplot: (-9223372036564635406)>
# -----------------------------
# Feature name : heart_rate
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 113
# Median : 87
# Mean : 87
# [Min, Max] : [40, 175]
# <ggplot: (-9223372036571106500)>
# -----------------------------
# Feature name : heart_rate_delay
# Type : float64
# Rate of missing values : 2%
# Number of unique values : 222
# Median : 2160
# Mean : 2568
# [Min, Max] : [0, 43740]
# <ggplot: (-9223372036570059232)>
# -----------------------------
# Feature name : weight_daily
# Type : float64
# Rate of missing values : 35%
# Number of unique values : 1040
# Median : 83
# Mean : 87
# [Min, Max] : [0, 295]
# <ggplot: (292549475)>
# -----------------------------
# Feature name : weight_daily_delay
# Type : float64
# Rate of missing values : 35%
# Number of unique values : 1958
# Median : 82830
# Mean : 150038
# [Min, Max] : [0, 2106000]
# <ggplot: (-9223372036562953065)>
# -----------------------------
# Feature name : temperature
# Type : float64
# Rate of missing values : 7%
# Number of unique values : 180
# Median : 98
# Mean : 98
# [Min, Max] : [0, 991]
# <ggplot: (-9223372036562971718)>
# -----------------------------
# Feature name : temperature_delay
# Type : float64
# Rate of missing values : 7%
# Number of unique values : 575
# Median : 6780
# Mean : 14089
# [Min, Max] : [0, 812220]
# <ggplot: (292543664)>
# -----------------------------
# Feature name : urine_output
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urine_output_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : day_urine_output
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : day_urine_output_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : scr
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 55
# Median : 1
# Mean : 1
# [Min, Max] : [0, 9]
# <ggplot: (291829838)>
# -----------------------------
# Feature name : scr_delay
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 99
# Median : 3600
# Mean : 16977
# [Min, Max] : [0, 1299060]
# <ggplot: (-9223372036562007559)>
# -----------------------------
# Feature name : sodium
# Type : float64
# Rate of missing values : 57%
# Number of unique values : 48
# Median : 137
# Mean : 137
# [Min, Max] : [0, 275]
# <ggplot: (290136328)>
# -----------------------------
# Feature name : sodium_delay
# Type : float64
# Rate of missing values : 57%
# Number of unique values : 1744
# Median : 239820
# Mean : 440364
# [Min, Max] : [240, 3923880]
# <ggplot: (-9223372036562415272)>
# -----------------------------
# Feature name : potassium
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : potassium_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : calcium
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : calcium_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : phosphor
# Type : float64
# Rate of missing values : 87%
# Number of unique values : 65
# Median : 3
# Mean : 3
# [Min, Max] : [0, 10]
# <ggplot: (-9223372036562939318)>
# -----------------------------
# Feature name : phosphor_delay
# Type : float64
# Rate of missing values : 87%
# Number of unique values : 140
# Median : 3600
# Mean : 22413
# [Min, Max] : [0, 1299060]
# <ggplot: (-9223372036562456295)>
# -----------------------------
# Feature name : hemoglobine
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 82
# Median : 9
# Mean : 9
# [Min, Max] : [5, 15]
# <ggplot: (290687324)>
# -----------------------------
# Feature name : hemoglobine_delay
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 189
# Median : 5100
# Mean : 15121
# [Min, Max] : [120, 1300800]
# <ggplot: (290627069)>
# -----------------------------
# Feature name : uric_acid
# Type : float64
# Rate of missing values : 99%
# Number of unique values : 19
# Median : 6
# Mean : 6
# [Min, Max] : [0, 14]
# <ggplot: (-9223372036562227624)>
# -----------------------------
# Feature name : uric_acid_delay
# Type : float64
# Rate of missing values : 99%
# Number of unique values : 34
# Median : 328680
# Mean : 546780
# [Min, Max] : [3600, 3115560]
# <ggplot: (290697578)>
# -----------------------------
# Feature name : chloride
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 36
# Median : 106
# Mean : 106
# [Min, Max] : [87, 127]
# <ggplot: (-9223372036564145141)>
# -----------------------------
# Feature name : chloride_delay
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 111
# Median : 3600
# Mean : 17387
# [Min, Max] : [0, 1299060]
# <ggplot: (-9223372036562786395)>
# -----------------------------
# Feature name : platelet_count
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 345
# Median : 221
# Mean : 256
# [Min, Max] : [12, 978]
# <ggplot: (290689940)>
# -----------------------------
# Feature name : platelet_count_delay
# Type : float64
# Rate of missing values : 86%
# Number of unique values : 196
# Median : 5160
# Mean : 15591
# [Min, Max] : [120, 1300800]
# <ggplot: (-9223372036562782015)>
# -----------------------------
# Feature name : ph_blood
# Type : float64
# Rate of missing values : 16%
# Number of unique values : 50
# Median : 7
# Mean : 7
# [Min, Max] : [7, 7]
# <ggplot: (-9223372036564107951)>
# -----------------------------
# Feature name : ph_blood_delay
# Type : float64
# Rate of missing values : 16%
# Number of unique values : 1728
# Median : 15240
# Mean : 94660
# [Min, Max] : [0, 3883260]
# <ggplot: (290684350)>
# -----------------------------
# Feature name : fibrinogen
# Type : float64
# Rate of missing values : 95%
# Number of unique values : 146
# Median : 320
# Mean : 422
# [Min, Max] : [87, 1773]
# <ggplot: (-9223372036562229665)>
# -----------------------------
# Feature name : fibrinogen_delay
# Type : float64
# Rate of missing values : 95%
# Number of unique values : 224
# Median : 265740
# Mean : 569675
# [Min, Max] : [420, 3090060]
# <ggplot: (290704227)>
# -----------------------------
# Feature name : urinary_sodium
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urinary_sodium_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urinary_potassium
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urinary_potassium_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urine_creatinin
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : urine_creatinin_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : alkaline_phospatase
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : alkaline_phospatase_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : total_protein_blood
# Type : float64
# Rate of missing values : 95%
# Number of unique values : 37
# Median : 5
# Mean : 5
# [Min, Max] : [3, 7]
# <ggplot: (-9223372036562763064)>
# -----------------------------
# Feature name : total_protein_blood_delay
# Type : float64
# Rate of missing values : 95%
# Number of unique values : 185
# Median : 420120
# Mean : 697486
# [Min, Max] : [0, 4453380]
# <ggplot: (292357910)>
# -----------------------------
# Feature name : albumin
# Type : float64
# Rate of missing values : 91%
# Number of unique values : 31
# Median : 2
# Mean : 2
# [Min, Max] : [1, 5]
# <ggplot: (-9223372036562417099)>
# -----------------------------
# Feature name : albumin_delay
# Type : float64
# Rate of missing values : 91%
# Number of unique values : 327
# Median : 128520
# Mean : 241273
# [Min, Max] : [0, 2122020]
# <ggplot: (-9223372036562962642)>
# -----------------------------
# Feature name : total_protein_urine
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : total_protein_urine_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : bilirubin
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : bilirubin_delay
# Type : float64
# Rate of missing values : 100%
# This column is empty !
# -----------------------------
# Feature name : c_reactive_protein
# Type : float64
# Rate of missing values : 96%
# Number of unique values : 107
# Median : 124
# Mean : 123
# [Min, Max] : [0, 366]
# <ggplot: (-9223372036564075113)>
# -----------------------------
# Feature name : c_reactive_protein_delay
# Type : float64
# Rate of missing values : 96%
# Number of unique values : 156
# Median : 482580
# Mean : 733851
# [Min, Max] : [5640, 4251900]
# <ggplot: (290671606)>
# -----------------------------
# Feature name : ethnicity
# Type : str
# Rate of missing values : 0%
# Number of unique values : 31
# Mode : WHITE
# <ggplot: (-9223372036564126611)>
# -----------------------------
# Feature name : diagnosis
# Type : str
# Rate of missing values : 0%
# Number of unique values : 1534
# Mode : PNEUMONIA
# 10 Most frequent values :
# PNEUMONIA (224)
# INTRACRANIAL HEMORRHAGE (149)
# SUBARACHNOID HEMORRHAGE (119)
# SEPSIS (116)
# PANCREATITIS (93)
# ALTERED MENTAL STATUS (77)
# CHEST PAIN (77)
# CONGESTIVE HEART FAILURE (65)
# ABDOMINAL PAIN (64)
# FEVER (60)
# -----------------------------
# Feature name : gender
# Type : str
# Rate of missing values : 0%
# Number of unique values : 2
# Mode : M
# <ggplot: (292549580)>
# -----------------------------
# Feature name : creatinine_yesterday
# Type : float64
# Rate of missing values : 59%
# Number of unique values : 65
# Median : 1
# Mean : 1
# [Min, Max] : [0, 18]
# <ggplot: (292757133)>
# -----------------------------
# Feature name : creatinine_before_yesterday
# Type : float64
# Rate of missing values : 42%
# Number of unique values : 75
# Median : 1
# Mean : 1
# [Min, Max] : [0, 24]
# <ggplot: (-9223372036569031848)>
# -----------------------------
# Feature name : label
# Type : float64
# Rate of missing values : 0%
# Number of unique values : 3
# Median : 2
# Mean : 1
# [Min, Max] : [0, 2]
# <ggplot: (-9223372036564095137)>

# %%
print(data['diagnosis'].value_counts())
# Out:
# PNEUMONIA                                                                                            224
# INTRACRANIAL HEMORRHAGE                                                                              149
# SUBARACHNOID HEMORRHAGE                                                                              119
# SEPSIS                                                                                               116
# PANCREATITIS                                                                                          93
# ALTERED MENTAL STATUS                                                                                 77
# CHEST PAIN                                                                                            77
# CONGESTIVE HEART FAILURE                                                                              65
# ABDOMINAL PAIN                                                                                        64
# FEVER                                                                                                 60
# S/P FALL                                                                                              59
# STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK                                                            58
# BLUNT TRAUMA                                                                                          55
# CORONARY ARTERY DISEASE                                                                               50
# UPPER GI BLEED                                                                                        41
# HYPOTENSION                                                                                           41
# GASTROINTESTINAL BLEED                                                                                39
# ACUTE SUBDURAL HEMATOMA                                                                               39
# RESPIRATORY FAILURE                                                                                   35
# LIVER FAILURE                                                                                         31
# DYSPNEA                                                                                               30
# CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS GRAFT /SDA                                             28
# AORTIC DISSECTION                                                                                     26
# ACUTE RENAL FAILURE                                                                                   26
# LOWER GI BLEED                                                                                        26
# S/P MOTOR VEHICLE ACCIDENT                                                                            26
# WEAKNESS                                                                                              25
# BOWEL OBSTRUCTION                                                                                     25
# ABDOMINAL AORTIC ANEURYSM/SDA                                                                         24
# S/P CARDIAC ARREST                                                                                    23
#                                                                                                     ...
# RENAL HEMORRHAGE                                                                                       1
# PERFORATED DIVERTICULITIS                                                                              1
# RIGHT WRIST FRACTURE;S/P FALL                                                                          1
# LINE SEPSIS                                                                                            1
# S/P FALL;LEFT EPIDURAL HEMORRHAGE                                                                      1
# RIGHT RECURRENT PLEURAL EFFUSION/SDA                                                                   1
# RESPIRATORY FAILURE;LUNG CANCER                                                                        1
# LEFT PLEURAL EFFUSION                                                                                  1
# SUPERIOR VENA CAVA SYNDROME                                                                            1
# PELVIC FX                                                                                              1
# HARDWARE INFECTION                                                                                     1
# AORTIC REPLACEMENT                                                                                     1
# AORTIC VALVE REPLACEMENT                                                                               1
# RESP DISTRESS                                                                                          1
# AORTIC STENOSIS\AVR, ? CORONARY ARTERY BYPASS GRAFT /SDA                                               1
# RIGHT PNEUMOTHORAX                                                                                     1
# OCCIPITAL MASS                                                                                         1
# PNEUMONIA-GAIT                                                                                         1
# URIMARY TRACT INFECTION;PYELONEPHRITIS                                                                 1
# NEUROENDOCRINE TUMOR OF LIVER AND PANCREAS/SDA                                                         1
# FTT;ABDOMINAL DISTENSION                                                                               1
# METASTATIC THYROID CANCER                                                                              1
# UMBILICAL HERNIA;ASCITES LEAK                                                                          1
# CHF, AF, CARDIOMYOPATHY\LEAD EXTRACTION; BIVENTRICULAR IMPLANTABLE CARDIOVERTER DEFIBRILLATOR/SDA      1
# FEMUR FRACTURES                                                                                        1
# ATRIAL FIBRILLATION;TELEMETRY                                                                          1
# FEVER OF UNKNOWN ORIGEN;JAUNDICE                                                                       1
# ?SMALL BOWEL OBSTRUCTION                                                                               1
# NECK PAIN;METS TO C-SPINE                                                                              1
# SUBDURAL HEMATOMA;HEAD INJURIES                                                                        1
# Name: diagnosis, Length: 1534, dtype: int64
