# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2

# below imports are used to print out pretty pandas dataframes
from IPython.display import display, HTML

# %matplotlib inline
plt.style.use('ggplot')

# %%
# information used to create a database connection
sqluser = 'postgres'
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to postgres with a copy of the MIMIC-III database
con = psycopg2.connect(dbname=dbname, user=sqluser)

# the below statement is prepended to queries to ensure they select from the right schema
query_schema = 'set search_path to ' + schema_name + ';'

# %%
def apply_inclusion_criteria(df):
    print('Initial size of table : ' + str(df.shape[0]))
    df = df.drop_duplicates(['icustay_id','creatinine_time'])
    print('After dropping duplicates : ' + str(df.shape[0]))
    criteria_list = [i for i in df.columns.values if 'inclusion' in i]
    for c in criteria_list:
        df = df.loc[df[c]==1,:].drop(c,axis=1)    
    print('After applying inclusion criteria : ' + str(df.shape[0]))
    return df

# %% [markdown]
# # Load file with features to be found in chartevents table

# %%
features_info = pd.read_csv('features_info.csv')
print(features_info)
# Out:
#                           name        table  variable  item_id  item_id_2  \
# 0   Arterial_pressure_systolic  chartevents  valuenum        6       51.0
# 1  Arterial_pressure_diastolic  chartevents  valuenum     8364     8368.0
# 2                   Heart_rate  chartevents  valuenum      211   220045.0
# 3                 Weight_daily  chartevents  valuenum      763   224639.0
# 4                  Temperature  chartevents  valuenum   223761      678.0
# 5                 Urine_output  chartevents  valuenum    43966    44706.0
# 6             day_urine_output  chartevents  valuenum    43372        NaN
#
#    item_id_3  item_id_4  item_id_5  item_id_6
# 0      455.0   220050.0   220179.0   225309.0
# 1     8441.0   220051.0   220180.0   225310.0
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4      645.0        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN
# 6        NaN        NaN        NaN        NaN

# %% [markdown]
# # Retrieve interesting features for patients that match inclusion criteria

# %%
query = query_schema + """
with cr as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    ce.valuenum as creatinine, ce.storetime as creatinine_time,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt
  from icustays icu
  inner join chartevents ce
    on icu.subject_id = ce.subject_id
    and ce.itemid = 220615
    and ce.valuenum is not null
    and ce.storetime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
),
cr_inc as
(
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt
  from cr
),
cr_feat as
(
select
cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
    cr_inc.creatinine, cr_inc.creatinine_time,
    cr_inc.age, cr_inc.inclusion_age,
    cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
    cr_inc.rrt, cr_inc.inclusion_rrt,
    ce.valuenum as """+features_info.loc[0,'name']+""", EXTRACT('epoch' from cr_inc.creatinine_time - ce.storetime) as """+features_info.loc[0,'name']+"""_delay, ce.storetime as """+features_info.loc[0,'name']+"""_time
  from cr_inc
  inner join """+features_info.loc[0,'table']+""" ce
    on cr_inc.subject_id = ce.subject_id
    and ce.itemid = """+str(features_info.loc[0,'item_id'])+"""
    and ce."""+features_info.loc[0,'variable']+""" is not null
    and ce.storetime between cr_inc.intime and cr_inc.creatinine_time
)
select 
a.subject_id, a.icustay_id, a.intime, a.outtime,
    a.creatinine, a.creatinine_time,
    a.age, a.inclusion_age,
    a.length_of_stay, a.inclusion_length_of_stay,
    a.rrt, a.inclusion_rrt,
    a."""+features_info.loc[0,'name']+""", a."""+features_info.loc[0,'name']+"""_delay, a."""+features_info.loc[0,'name']+"""_time
from cr_feat as a
    join (
        select creatinine_time, min("""+features_info.loc[0,'name']+"""_delay) as """+features_info.loc[0,'name']+"""_delay
        from cr_feat
        group by creatinine_time
    ) as b on a.creatinine_time = b.creatinine_time
where a."""+features_info.loc[0,'name']+"""_delay = b."""+features_info.loc[0,'name']+"""_delay
"""
df_chartevents = pd.read_sql_query(query, con)
print(df_chartevents.head())
df_chartevents = apply_inclusion_criteria(df_chartevents)
print(df_chartevents.head())
    
for i,row in features_info.loc[1:,:].iterrows():
    print('------------------------------------')
    print('--- Processing feature : ' + row['name'])
    print(row['table'], row['variable'])

    query = query_schema + """
    with cr as
    (
    select
        icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
        ce.valuenum as creatinine, ce.storetime as creatinine_time,
        EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
        (rrt.icustay_id is null) as rrt
      from icustays icu
      inner join chartevents ce
        on icu.subject_id = ce.subject_id
        and ce.itemid = 220615
        and ce.valuenum is not null
        and ce.storetime between icu.intime and icu.outtime
      inner join patients pat
        ON icu.subject_id = pat.subject_id
      left outer join rrt 
        on icu.icustay_id = rrt.icustay_id
    ),
    cr_inc as
    (
    select
    cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
        cr.creatinine, cr.creatinine_time,
        cr.age, CASE
                    WHEN cr.age >= 15 then 1
                ELSE 0 END
                as inclusion_age,
      cr.length_of_stay, CASE
                            WHEN cr.length_of_stay >= 48 then 1
                         ELSE 0 END
                         as inclusion_length_of_stay,
      cr.rrt, CASE
                WHEN cr.rrt = False then 1
              ELSE 0 END
              as inclusion_rrt
      from cr
    ),
    cr_feat as
    (
    select
    cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
        cr_inc.creatinine, cr_inc.creatinine_time,
        cr_inc.age, cr_inc.inclusion_age,
        cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
        cr_inc.rrt, cr_inc.inclusion_rrt,
        ce.valuenum as """+features_info.loc[i,'name']+""", EXTRACT('epoch' from cr_inc.creatinine_time - ce.storetime) as """+features_info.loc[i,'name']+"""_delay, ce.storetime as """+features_info.loc[i,'name']+"""_time
      from cr_inc
      inner join """+features_info.loc[i,'table']+""" ce
        on cr_inc.subject_id = ce.subject_id
        and ce.itemid = """+str(features_info.loc[i,'item_id'])+"""
        and ce."""+features_info.loc[i,'variable']+""" is not null
        and ce.storetime between cr_inc.intime and cr_inc.creatinine_time
    )
    select 
    a.subject_id, a.icustay_id, a.intime, a.outtime,
        a.creatinine, a.creatinine_time,
        a.age, a.inclusion_age,
        a.length_of_stay, a.inclusion_length_of_stay,
        a.rrt, a.inclusion_rrt,
        a."""+features_info.loc[i,'name']+""", a."""+features_info.loc[i,'name']+"""_delay, a."""+features_info.loc[i,'name']+"""_time
    from cr_feat as a
        join (
            select creatinine_time, min("""+features_info.loc[i,'name']+"""_delay) as """+features_info.loc[i,'name']+"""_delay
            from cr_feat
            group by creatinine_time
        ) as b on a.creatinine_time = b.creatinine_time
    where a."""+features_info.loc[i,'name']+"""_delay = b."""+features_info.loc[i,'name']+"""_delay
    """
    df = pd.read_sql_query(query, con)
    df = apply_inclusion_criteria(df)
    print(df.head())
    df_chartevents = pd.merge(df_chartevents,df,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt'],how='outer')
    print('---------------------------------')
    print('Merged table size : ' + str(df_chartevents.shape[0]))
    print(df_chartevents.head())
# Out:
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, inclusion_age, length_of_stay, inclusion_length_of_stay, rrt, inclusion_rrt, arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time]
# Index: []
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time]
# Index: []
# ------------------------------------
# --- Processing feature : Arterial_pressure_diastolic
# chartevents valuenum
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time]
# Index: []
# ------------------------------------
# --- Processing feature : Heart_rate
# chartevents valuenum
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py:1457: RuntimeWarning: divide by zero encountered in long_scalars
#   stride //= shape[i]
# Initial size of table : 20983
# After dropping duplicates : 16755
# After applying inclusion criteria : 14391
#     subject_id  icustay_id              intime             outtime  \
# 6          191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 7          191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 9          191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 18         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 19         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
#     creatinine     creatinine_time        age  length_of_stay    rrt  \
# 6          1.8 2196-04-10 00:30:00  73.159244      142.673056  False
# 7          2.0 2196-04-10 06:39:00  73.159244      142.673056  False
# 9          2.2 2196-04-11 00:30:00  73.159244      142.673056  False
# 18         2.6 2196-04-11 05:57:00  73.159244      142.673056  False
# 19         2.3 2196-04-12 03:40:00  73.159244      142.673056  False
#
#     heart_rate  heart_rate_delay     heart_rate_time
# 6         93.0             240.0 2196-04-10 00:26:00
# 7         81.0            4620.0 2196-04-10 05:22:00
# 9        113.0             540.0 2196-04-11 00:21:00
# 18        92.0            4320.0 2196-04-11 04:45:00
# 19        81.0            2880.0 2196-04-12 02:52:00
# ---------------------------------
# Merged table size : 14391
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         1.8
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.0
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.2
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.6
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.3
#
#       creatinine_time        age  length_of_stay    rrt  heart_rate  \
# 0 2196-04-10 00:30:00  73.159244      142.673056  False        93.0
# 1 2196-04-10 06:39:00  73.159244      142.673056  False        81.0
# 2 2196-04-11 00:30:00  73.159244      142.673056  False       113.0
# 3 2196-04-11 05:57:00  73.159244      142.673056  False        92.0
# 4 2196-04-12 03:40:00  73.159244      142.673056  False        81.0
#
#    heart_rate_delay     heart_rate_time
# 0             240.0 2196-04-10 00:26:00
# 1            4620.0 2196-04-10 05:22:00
# 2             540.0 2196-04-11 00:21:00
# 3            4320.0 2196-04-11 04:45:00
# 4            2880.0 2196-04-12 02:52:00
# ------------------------------------
# --- Processing feature : Weight_daily
# chartevents valuenum
# Initial size of table : 10943
# After dropping duplicates : 10910
# After applying inclusion criteria : 9992
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         1.8
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.0
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.2
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.6
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22         2.3
#
#       creatinine_time        age  length_of_stay    rrt  weight_daily  \
# 0 2196-04-10 00:30:00  73.159244      142.673056  False     88.699997
# 1 2196-04-10 06:39:00  73.159244      142.673056  False     88.699997
# 2 2196-04-11 00:30:00  73.159244      142.673056  False     88.699997
# 3 2196-04-11 05:57:00  73.159244      142.673056  False     88.699997
# 4 2196-04-12 03:40:00  73.159244      142.673056  False     88.699997
#
#    weight_daily_delay   weight_daily_time
# 0             15360.0 2196-04-09 20:14:00
# 1             37500.0 2196-04-09 20:14:00
# 2            101760.0 2196-04-09 20:14:00
# 3            121380.0 2196-04-09 20:14:00
# 4            199560.0 2196-04-09 20:14:00
# ---------------------------------
# Merged table size : 14393
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    subject_id  icustay_id              intime             outtime  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
#           ...             creatinine_time        age  length_of_stay    rrt  \
# 0         ...         2196-04-10 00:30:00  73.159244      142.673056  False
# 1         ...         2196-04-10 06:39:00  73.159244      142.673056  False
# 2         ...         2196-04-11 00:30:00  73.159244      142.673056  False
# 3         ...         2196-04-11 05:57:00  73.159244      142.673056  False
# 4         ...         2196-04-12 03:40:00  73.159244      142.673056  False
#
#   heart_rate  heart_rate_delay     heart_rate_time weight_daily  \
# 0       93.0             240.0 2196-04-10 00:26:00    88.699997
# 1       81.0            4620.0 2196-04-10 05:22:00    88.699997
# 2      113.0             540.0 2196-04-11 00:21:00    88.699997
# 3       92.0            4320.0 2196-04-11 04:45:00    88.699997
# 4       81.0            2880.0 2196-04-12 02:52:00    88.699997
#
#    weight_daily_delay   weight_daily_time
# 0             15360.0 2196-04-09 20:14:00
# 1             37500.0 2196-04-09 20:14:00
# 2            101760.0 2196-04-09 20:14:00
# 3            121380.0 2196-04-09 20:14:00
# 4            199560.0 2196-04-09 20:14:00
#
# [5 rows x 21 columns]
# ------------------------------------
# --- Processing feature : Temperature
# chartevents valuenum
# Initial size of table : 131120
# After dropping duplicates : 127474
# After applying inclusion criteria : 106818
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 2          36      241249 2134-05-12 06:52:47 2134-05-16 15:14:20         0.9
# 3          36      241249 2134-05-12 06:52:47 2134-05-16 15:14:20         1.0
# 4          36      241249 2134-05-12 06:52:47 2134-05-16 15:14:20         1.0
# 5          36      241249 2134-05-12 06:52:47 2134-05-16 15:14:20         0.8
# 9         109      236124 2141-10-13 23:11:01 2141-10-25 20:49:04         7.0
#
#       creatinine_time        age  length_of_stay    rrt  temperature  \
# 2 2134-05-12 10:01:00  72.733384      104.359167  False         99.3
# 3 2134-05-13 00:11:00  72.733384      104.359167  False        100.2
# 4 2134-05-13 06:10:00  72.733384      104.359167  False         99.5
# 5 2134-05-15 04:58:00  72.733384      104.359167  False         99.1
# 9 2141-10-23 03:36:00  24.186610      285.634167  False         98.6
#
#    temperature_delay    temperature_time
# 2             3000.0 2134-05-12 09:11:00
# 3            16020.0 2134-05-12 19:44:00
# 4             7500.0 2134-05-13 04:05:00
# 5             1800.0 2134-05-15 04:28:00
# 9            25980.0 2141-10-22 20:23:00
# ---------------------------------
# Merged table size : 120650
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    subject_id  icustay_id              intime             outtime  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
#          ...           rrt heart_rate  heart_rate_delay     heart_rate_time  \
# 0        ...         False       93.0             240.0 2196-04-10 00:26:00
# 1        ...         False       81.0            4620.0 2196-04-10 05:22:00
# 2        ...         False      113.0             540.0 2196-04-11 00:21:00
# 3        ...         False       92.0            4320.0 2196-04-11 04:45:00
# 4        ...         False       81.0            2880.0 2196-04-12 02:52:00
#
#   weight_daily  weight_daily_delay   weight_daily_time temperature  \
# 0    88.699997             15360.0 2196-04-09 20:14:00         NaN
# 1    88.699997             37500.0 2196-04-09 20:14:00         NaN
# 2    88.699997            101760.0 2196-04-09 20:14:00         NaN
# 3    88.699997            121380.0 2196-04-09 20:14:00         NaN
# 4    88.699997            199560.0 2196-04-09 20:14:00         NaN
#
#    temperature_delay  temperature_time
# 0                NaN               NaT
# 1                NaN               NaT
# 2                NaN               NaT
# 3                NaN               NaT
# 4                NaN               NaT
#
# [5 rows x 24 columns]
# ------------------------------------
# --- Processing feature : Urine_output
# chartevents valuenum
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, urine_output, urine_output_delay, urine_output_time]
# Index: []
# ---------------------------------
# Merged table size : 120650
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    subject_id  icustay_id              intime             outtime  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
#          ...             heart_rate_time weight_daily  weight_daily_delay  \
# 0        ...         2196-04-10 00:26:00    88.699997             15360.0
# 1        ...         2196-04-10 05:22:00    88.699997             37500.0
# 2        ...         2196-04-11 00:21:00    88.699997            101760.0
# 3        ...         2196-04-11 04:45:00    88.699997            121380.0
# 4        ...         2196-04-12 02:52:00    88.699997            199560.0
#
#     weight_daily_time temperature  temperature_delay  temperature_time  \
# 0 2196-04-09 20:14:00         NaN                NaN               NaT
# 1 2196-04-09 20:14:00         NaN                NaN               NaT
# 2 2196-04-09 20:14:00         NaN                NaN               NaT
# 3 2196-04-09 20:14:00         NaN                NaN               NaT
# 4 2196-04-09 20:14:00         NaN                NaN               NaT
#
#   urine_output  urine_output_delay  urine_output_time
# 0          NaN                 NaN                NaN
# 1          NaN                 NaN                NaN
# 2          NaN                 NaN                NaN
# 3          NaN                 NaN                NaN
# 4          NaN                 NaN                NaN
#
# [5 rows x 27 columns]
# ------------------------------------
# --- Processing feature : day_urine_output
# chartevents valuenum
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, day_urine_output, day_urine_output_delay, day_urine_output_time]
# Index: []
# ---------------------------------
# Merged table size : 120650
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    subject_id  icustay_id              intime             outtime  \
# 0         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 1         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 2         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 3         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
# 4         191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
#            ...             weight_daily_time temperature  temperature_delay  \
# 0          ...           2196-04-09 20:14:00         NaN                NaN
# 1          ...           2196-04-09 20:14:00         NaN                NaN
# 2          ...           2196-04-09 20:14:00         NaN                NaN
# 3          ...           2196-04-09 20:14:00         NaN                NaN
# 4          ...           2196-04-09 20:14:00         NaN                NaN
#
#    temperature_time urine_output  urine_output_delay  urine_output_time  \
# 0               NaT          NaN                 NaN                NaN
# 1               NaT          NaN                 NaN                NaN
# 2               NaT          NaN                 NaN                NaN
# 3               NaT          NaN                 NaN                NaN
# 4               NaT          NaN                 NaN                NaN
#
#   day_urine_output  day_urine_output_delay  day_urine_output_time
# 0              NaN                     NaN                    NaN
# 1              NaN                     NaN                    NaN
# 2              NaN                     NaN                    NaN
# 3              NaN                     NaN                    NaN
# 4              NaN                     NaN                    NaN
#
# [5 rows x 30 columns]

# %%
# Dump to file
df_chartevents.to_csv('creatinine_measurements_1.csv')
print(df_chartevents)
# Out:
#        arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
# 11                            NaN                              NaN
# 12                            NaN                              NaN
# 13                            NaN                              NaN
# 14                            NaN                              NaN
# 15                            NaN                              NaN
# 16                            NaN                              NaN
# 17                            NaN                              NaN
# 18                            NaN                              NaN
# 19                            NaN                              NaN
# 20                            NaN                              NaN
# 21                            NaN                              NaN
# 22                            NaN                              NaN
# 23                            NaN                              NaN
# 24                            NaN                              NaN
# 25                            NaN                              NaN
# 26                            NaN                              NaN
# 27                            NaN                              NaN
# 28                            NaN                              NaN
# 29                            NaN                              NaN
# ...                           ...                              ...
# 120620                        NaN                              NaN
# 120621                        NaN                              NaN
# 120622                        NaN                              NaN
# 120623                        NaN                              NaN
# 120624                        NaN                              NaN
# 120625                        NaN                              NaN
# 120626                        NaN                              NaN
# 120627                        NaN                              NaN
# 120628                        NaN                              NaN
# 120629                        NaN                              NaN
# 120630                        NaN                              NaN
# 120631                        NaN                              NaN
# 120632                        NaN                              NaN
# 120633                        NaN                              NaN
# 120634                        NaN                              NaN
# 120635                        NaN                              NaN
# 120636                        NaN                              NaN
# 120637                        NaN                              NaN
# 120638                        NaN                              NaN
# 120639                        NaN                              NaN
# 120640                        NaN                              NaN
# 120641                        NaN                              NaN
# 120642                        NaN                              NaN
# 120643                        NaN                              NaN
# 120644                        NaN                              NaN
# 120645                        NaN                              NaN
# 120646                        NaN                              NaN
# 120647                        NaN                              NaN
# 120648                        NaN                              NaN
# 120649                        NaN                              NaN
#
#        arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5                                  NaN                         NaN
# 6                                  NaN                         NaN
# 7                                  NaN                         NaN
# 8                                  NaN                         NaN
# 9                                  NaN                         NaN
# 10                                 NaN                         NaN
# 11                                 NaN                         NaN
# 12                                 NaN                         NaN
# 13                                 NaN                         NaN
# 14                                 NaN                         NaN
# 15                                 NaN                         NaN
# 16                                 NaN                         NaN
# 17                                 NaN                         NaN
# 18                                 NaN                         NaN
# 19                                 NaN                         NaN
# 20                                 NaN                         NaN
# 21                                 NaN                         NaN
# 22                                 NaN                         NaN
# 23                                 NaN                         NaN
# 24                                 NaN                         NaN
# 25                                 NaN                         NaN
# 26                                 NaN                         NaN
# 27                                 NaN                         NaN
# 28                                 NaN                         NaN
# 29                                 NaN                         NaN
# ...                                ...                         ...
# 120620                             NaN                         NaN
# 120621                             NaN                         NaN
# 120622                             NaN                         NaN
# 120623                             NaN                         NaN
# 120624                             NaN                         NaN
# 120625                             NaN                         NaN
# 120626                             NaN                         NaN
# 120627                             NaN                         NaN
# 120628                             NaN                         NaN
# 120629                             NaN                         NaN
# 120630                             NaN                         NaN
# 120631                             NaN                         NaN
# 120632                             NaN                         NaN
# 120633                             NaN                         NaN
# 120634                             NaN                         NaN
# 120635                             NaN                         NaN
# 120636                             NaN                         NaN
# 120637                             NaN                         NaN
# 120638                             NaN                         NaN
# 120639                             NaN                         NaN
# 120640                             NaN                         NaN
# 120641                             NaN                         NaN
# 120642                             NaN                         NaN
# 120643                             NaN                         NaN
# 120644                             NaN                         NaN
# 120645                             NaN                         NaN
# 120646                             NaN                         NaN
# 120647                             NaN                         NaN
# 120648                             NaN                         NaN
# 120649                             NaN                         NaN
#
#        arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5                                    NaN                              NaN
# 6                                    NaN                              NaN
# 7                                    NaN                              NaN
# 8                                    NaN                              NaN
# 9                                    NaN                              NaN
# 10                                   NaN                              NaN
# 11                                   NaN                              NaN
# 12                                   NaN                              NaN
# 13                                   NaN                              NaN
# 14                                   NaN                              NaN
# 15                                   NaN                              NaN
# 16                                   NaN                              NaN
# 17                                   NaN                              NaN
# 18                                   NaN                              NaN
# 19                                   NaN                              NaN
# 20                                   NaN                              NaN
# 21                                   NaN                              NaN
# 22                                   NaN                              NaN
# 23                                   NaN                              NaN
# 24                                   NaN                              NaN
# 25                                   NaN                              NaN
# 26                                   NaN                              NaN
# 27                                   NaN                              NaN
# 28                                   NaN                              NaN
# 29                                   NaN                              NaN
# ...                                  ...                              ...
# 120620                               NaN                              NaN
# 120621                               NaN                              NaN
# 120622                               NaN                              NaN
# 120623                               NaN                              NaN
# 120624                               NaN                              NaN
# 120625                               NaN                              NaN
# 120626                               NaN                              NaN
# 120627                               NaN                              NaN
# 120628                               NaN                              NaN
# 120629                               NaN                              NaN
# 120630                               NaN                              NaN
# 120631                               NaN                              NaN
# 120632                               NaN                              NaN
# 120633                               NaN                              NaN
# 120634                               NaN                              NaN
# 120635                               NaN                              NaN
# 120636                               NaN                              NaN
# 120637                               NaN                              NaN
# 120638                               NaN                              NaN
# 120639                               NaN                              NaN
# 120640                               NaN                              NaN
# 120641                               NaN                              NaN
# 120642                               NaN                              NaN
# 120643                               NaN                              NaN
# 120644                               NaN                              NaN
# 120645                               NaN                              NaN
# 120646                               NaN                              NaN
# 120647                               NaN                              NaN
# 120648                               NaN                              NaN
# 120649                               NaN                              NaN
#
#         subject_id  icustay_id              intime             outtime  \
# 0              191      280149 2196-04-09 19:52:59 2196-04-15 18:33:22
#
# 120637       99982      275958 2157-01-06 16:07:09 2157-01-11 14:44:39
# 120638       99982      221194 2156-11-28 11:57:12 2156-12-06 10:44:08
# 120639       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120640       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120641       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120642       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120643       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120644       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120645       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120646       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120647       99985      279638 2181-01-29 05:33:34 2181-02-09 12:45:20
# 120648       99991      226241 2184-12-28 17:30:58 2184-12-31 20:56:20
# 120649       99995      229633 2147-02-08 13:53:58 2147-02-10 17:46:30
#
#                 ...             weight_daily_time temperature  \
# 0               ...           2196-04-09 20:14:00         NaN
# 1               ...           2196-04-09 20:14:00         NaN
# 2               ...           2196-04-09 20:14:00         NaN
# 3               ...           2196-04-09 20:14:00         NaN
# 4               ...           2196-04-09 20:14:00         NaN
# 5               ...           2196-04-09 20:14:00         NaN
# 6               ...           2196-04-09 20:14:00         NaN
# 7               ...           2196-04-09 20:14:00         NaN
# 8               ...           2142-06-11 14:47:00         NaN
# 9               ...                           NaT         NaN
# 10              ...                           NaT         NaN
# 11              ...           2142-06-11 14:47:00         NaN
# 12              ...                           NaT         NaN
# 13              ...                           NaT         NaN
# 14              ...                           NaT         NaN
# 15              ...           2170-06-18 05:46:00         NaN
# 16              ...           2142-06-11 14:47:00         NaN
# 17              ...           2142-06-11 14:47:00         NaN
# 18              ...           2170-06-18 05:46:00         NaN
# 19              ...           2170-06-20 06:45:00         NaN
# 20              ...           2142-06-11 14:47:00         NaN
# 21              ...           2142-06-11 14:47:00         NaN
# 22              ...           2142-06-13 14:16:00         NaN
# 23              ...           2170-06-20 06:45:00         NaN
# 24              ...           2170-06-20 06:45:00         NaN
# 25              ...                           NaT         NaN
# 26              ...                           NaT         NaN
# 27              ...                           NaT        97.4
# 28              ...           2170-06-15 04:47:00         NaN
# 29              ...                           NaT        96.8
# ...             ...                           ...         ...
# 120620          ...                           NaT        98.0
# 120621          ...                           NaT        96.9
# 120622          ...                           NaT        97.0
# 120623          ...                           NaT        97.2
# 120624          ...                           NaT        97.4
# 120625          ...                           NaT        97.1
# 120626          ...                           NaT        95.8
# 120627          ...                           NaT        98.9
# 120628          ...                           NaT        98.0
# 120629          ...                           NaT        97.3
# 120630          ...                           NaT        97.3
# 120631          ...                           NaT        97.3
# 120632          ...                           NaT        97.3
# 120633          ...                           NaT        96.2
# 120634          ...                           NaT        99.6
# 120635          ...                           NaT        96.8
# 120636          ...                           NaT        98.7
# 120637          ...                           NaT        95.6
# 120638          ...                           NaT        97.3
# 120639          ...                           NaT        98.9
# 120640          ...                           NaT        99.1
# 120641          ...                           NaT       100.8
# 120642          ...                           NaT       100.0
# 120643          ...                           NaT        98.8
# 120644          ...                           NaT        99.3
# 120645          ...                           NaT       100.5
# 120646          ...                           NaT        99.2
# 120647          ...                           NaT        98.6
# 120648          ...                           NaT        99.7
# 120649          ...                           NaT        98.3
#
#         temperature_delay    temperature_time urine_output  \
# 0                     NaN                 NaT          NaN
# 1                     NaN                 NaT          NaN
# 2                     NaN                 NaT          NaN
# 3                     NaN                 NaT          NaN
# 4                     NaN                 NaT          NaN
# 5                     NaN                 NaT          NaN
# 6                     NaN                 NaT          NaN
# 7                     NaN                 NaT          NaN
# 8                     NaN                 NaT          NaN
# 9                     NaN                 NaT          NaN
# 10                    NaN                 NaT          NaN
# 11                    NaN                 NaT          NaN
# 12                    NaN                 NaT          NaN
# 13                    NaN                 NaT          NaN
# 14                    NaN                 NaT          NaN
# 15                    NaN                 NaT          NaN
# 16                    NaN                 NaT          NaN
# 17                    NaN                 NaT          NaN
# 18                    NaN                 NaT          NaN
# 19                    NaN                 NaT          NaN
# 20                    NaN                 NaT          NaN
# 21                    NaN                 NaT          NaN
# 22                    NaN                 NaT          NaN
# 23                    NaN                 NaT          NaN
# 24                    NaN                 NaT          NaN
# 25                    NaN                 NaT          NaN
# 26                    NaN                 NaT          NaN
# 27                 2220.0 2142-06-26 12:40:00          NaN
# 28                    NaN                 NaT          NaN
# 29                 5220.0 2142-06-27 04:07:00          NaN
# ...                   ...                 ...          ...
# 120620            17520.0 2157-02-22 00:53:00          NaN
# 120621            22320.0 2157-01-10 01:06:00          NaN
# 120622            12300.0 2157-01-10 13:13:00          NaN
# 120623            22020.0 2157-02-17 17:39:00          NaN
# 120624            13500.0 2157-02-18 01:23:00          NaN
# 120625             3600.0 2157-01-08 06:29:00          NaN
# 120626              780.0 2157-02-20 15:46:00          NaN
# 120627            13440.0 2156-11-28 22:51:00          NaN
# 120628            27960.0 2157-02-19 00:26:00          NaN
# 120629           213780.0 2156-11-29 03:52:00          NaN
# 120630           235320.0 2156-11-29 03:52:00          NaN
# 120631           168300.0 2156-11-29 03:52:00          NaN
# 120632            86700.0 2156-11-29 03:52:00          NaN
# 120633            20820.0 2157-01-07 01:07:00          NaN
# 120634            31980.0 2156-12-05 20:39:00          NaN
# 120635             8100.0 2156-11-28 14:06:00          NaN
# 120636            35280.0 2156-12-03 19:32:00          NaN
# 120637            14400.0 2157-01-08 11:33:00          NaN
# 120638           259260.0 2156-11-29 03:52:00          NaN
# 120639             3660.0 2181-01-31 04:10:00          NaN
# 120640             8220.0 2181-02-06 15:32:00          NaN
# 120641              720.0 2181-02-04 03:01:00          NaN
# 120642             5520.0 2181-02-03 04:08:00          NaN
# 120643            17220.0 2181-01-30 00:18:00          NaN
# 120644             5640.0 2181-02-02 03:49:00          NaN
# 120645            16800.0 2181-01-29 06:23:00          NaN
# 120646            35160.0 2181-02-04 19:54:00          NaN
# 120647              600.0 2181-02-09 04:53:00          NaN
# 120648             9540.0 2184-12-31 01:09:00          NaN
# 120649            13080.0 2147-02-09 00:40:00          NaN
#
#         urine_output_delay  urine_output_time day_urine_output  \
# 0                      NaN                NaN              NaN
# 1                      NaN                NaN              NaN
# 2                      NaN                NaN              NaN
# 3                      NaN                NaN              NaN
# 4                      NaN                NaN              NaN
# 5                      NaN                NaN              NaN
# 6                      NaN                NaN              NaN
# 7                      NaN                NaN              NaN
# 8                      NaN                NaN              NaN
# 9                      NaN                NaN              NaN
# 10                     NaN                NaN              NaN
# 11                     NaN                NaN              NaN
# 12                     NaN                NaN              NaN
# 13                     NaN                NaN              NaN
# 14                     NaN                NaN              NaN
# 15                     NaN                NaN              NaN
# 16                     NaN                NaN              NaN
# 17                     NaN                NaN              NaN
# 18                     NaN                NaN              NaN
# 19                     NaN                NaN              NaN
# 20                     NaN                NaN              NaN
# 21                     NaN                NaN              NaN
# 22                     NaN                NaN              NaN
# 23                     NaN                NaN              NaN
# 24                     NaN                NaN              NaN
# 25                     NaN                NaN              NaN
# 26                     NaN                NaN              NaN
# 27                     NaN                NaN              NaN
# 28                     NaN                NaN              NaN
# 29                     NaN                NaN              NaN
# ...                    ...                ...              ...
# 120620                 NaN                NaN              NaN
# 120621                 NaN                NaN              NaN
# 120622                 NaN                NaN              NaN
# 120623                 NaN                NaN              NaN
# 120624                 NaN                NaN              NaN
# 120625                 NaN                NaN              NaN
# 120626                 NaN                NaN              NaN
# 120627                 NaN                NaN              NaN
# 120628                 NaN                NaN              NaN
# 120629                 NaN                NaN              NaN
# 120630                 NaN                NaN              NaN
# 120631                 NaN                NaN              NaN
# 120632                 NaN                NaN              NaN
# 120633                 NaN                NaN              NaN
# 120634                 NaN                NaN              NaN
# 120635                 NaN                NaN              NaN
# 120636                 NaN                NaN              NaN
# 120637                 NaN                NaN              NaN
# 120638                 NaN                NaN              NaN
# 120639                 NaN                NaN              NaN
# 120640                 NaN                NaN              NaN
# 120641                 NaN                NaN              NaN
# 120642                 NaN                NaN              NaN
# 120643                 NaN                NaN              NaN
# 120644                 NaN                NaN              NaN
# 120645                 NaN                NaN              NaN
# 120646                 NaN                NaN              NaN
# 120647                 NaN                NaN              NaN
# 120648                 NaN                NaN              NaN
# 120649                 NaN                NaN              NaN
#
#         day_urine_output_delay  day_urine_output_time
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# 5                          NaN                    NaN
# 6                          NaN                    NaN
# 7                          NaN                    NaN
# 8                          NaN                    NaN
# 9                          NaN                    NaN
# 10                         NaN                    NaN
# 11                         NaN                    NaN
# 12                         NaN                    NaN
# 13                         NaN                    NaN
# 14                         NaN                    NaN
# 15                         NaN                    NaN
# 16                         NaN                    NaN
# 17                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 20                         NaN                    NaN
# 21                         NaN                    NaN
# 22                         NaN                    NaN
# 23                         NaN                    NaN
# 24                         NaN                    NaN
# 25                         NaN                    NaN
# 26                         NaN                    NaN
# 27                         NaN                    NaN
# 28                         NaN                    NaN
# 29                         NaN                    NaN
# ...                        ...                    ...
# 120620                     NaN                    NaN
# 120621                     NaN                    NaN
# 120622                     NaN                    NaN
# 120623                     NaN                    NaN
# 120624                     NaN                    NaN
# 120625                     NaN                    NaN
# 120626                     NaN                    NaN
# 120627                     NaN                    NaN
# 120628                     NaN                    NaN
# 120629                     NaN                    NaN
# 120630                     NaN                    NaN
# 120631                     NaN                    NaN
# 120632                     NaN                    NaN
# 120633                     NaN                    NaN
# 120634                     NaN                    NaN
# 120635                     NaN                    NaN
# 120636                     NaN                    NaN
# 120637                     NaN                    NaN
# 120638                     NaN                    NaN
# 120639                     NaN                    NaN
# 120640                     NaN                    NaN
# 120641                     NaN                    NaN
# 120642                     NaN                    NaN
# 120643                     NaN                    NaN
# 120644                     NaN                    NaN
# 120645                     NaN                    NaN
# 120646                     NaN                    NaN
# 120647                     NaN                    NaN
# 120648                     NaN                    NaN
# 120649                     NaN                    NaN
#
# [120650 rows x 30 columns]

# %% [markdown]
# # Retrieve missing static information

# %%
# Creatinine measurements, AKI flags + stage for all stays
# Inclusion flags :
# patient age > 15
# length of stay > 48hours
query = query_schema + """
with cr as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    ce.valuenum as creatinine, ce.storetime as creatinine_time,
    adm.ethnicity, adm.diagnosis,
    pat.gender as gender,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt
  from icustays icu
  inner join chartevents ce
    on icu.subject_id = ce.subject_id
    and ce.itemid = 220615
    and ce.valuenum is not null
    and ce.storetime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  inner join admissions adm
    on icu.subject_id = adm.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
)
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.ethnicity, cr.diagnosis,
    cr.gender,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt
  from cr
"""
df_static = pd.read_sql_query(query, con)
print(df_static.head())
df_static = apply_inclusion_criteria(df_static)
print(df_static.head())
# Out:
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0         494      268296 2171-12-20 22:10:57 2171-12-21 22:37:41         1.0
# 1         494      268296 2171-12-20 22:10:57 2171-12-21 22:37:41         1.0
# 2         199      235675 2174-04-12 11:00:25 2174-04-17 17:02:50         1.1
# 3         199      235675 2174-04-12 11:00:25 2174-04-17 17:02:50         1.1
# 4         199      235675 2174-04-12 11:00:25 2174-04-17 17:02:50         1.1
#
#       creatinine_time        ethnicity       diagnosis gender        age  \
# 0 2171-12-21 02:16:00  WHITE - RUSSIAN      CHEST PAIN      F  61.997044
# 1 2171-12-21 02:16:00  WHITE - RUSSIAN          ANEMIA      F  61.997044
# 2 2174-04-17 02:12:00            WHITE  CARDIOMYOPATHY      M  48.500607
# 3 2174-04-14 03:11:00            WHITE  CARDIOMYOPATHY      M  48.500607
# 4 2174-04-15 03:29:00            WHITE  CARDIOMYOPATHY      M  48.500607
#
#    inclusion_age  length_of_stay  inclusion_length_of_stay    rrt  \
# 0              1       24.445556                         0  False
# 1              1       24.445556                         0  False
# 2              1      126.040278                         1  False
# 3              1      126.040278                         1  False
# 4              1      126.040278                         1  False
#
#    inclusion_rrt
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# 7                       CARDIOMYOPATHY      M   48.500607      126.040278
# 8                       CARDIOMYOPATHY      M   48.500607      126.040278
# 9                       CARDIOMYOPATHY      M   48.500607      126.040278
# 18                     UNSTABLE ANGINA      M   73.575503       96.160833
# 19                     UNSTABLE ANGINA      M   73.575503       96.160833
# 20                     UNSTABLE ANGINA      M   73.575503       96.160833
# 21                     UNSTABLE ANGINA      M   73.575503       96.160833
# 22                     UNSTABLE ANGINA      M   73.575503       96.160833
# 23                     UNSTABLE ANGINA      M   73.575503       96.160833
# 36      INCREASING SHORTNESS OF BREATH      M   52.499219       73.839444
# 37      INCREASING SHORTNESS OF BREATH      M   52.499219       73.839444
# 38      INCREASING SHORTNESS OF BREATH      M   52.499219       73.839444
# 41      INCREASING SHORTNESS OF BREATH      M   52.499219       73.839444
# 42      INCREASING SHORTNESS OF BREATH      M   52.499219       73.839444
# 77             CORONARY ARTERY DISEASE      M  309.615099       54.623056
# 78             CORONARY ARTERY DISEASE      M  309.615099       54.623056
# 79             CORONARY ARTERY DISEASE      M  309.615099       54.623056
# 87            ASTHMA/COPD EXACERBATION      F   65.785094       75.324722
# 88            ASTHMA/COPD EXACERBATION      F   65.785094       75.324722
# 89            ASTHMA/COPD EXACERBATION      F   65.785094       75.324722
# 96              INTRACUTANEOUS FISTULA      F   68.428194      304.285556
# 97              INTRACUTANEOUS FISTULA      F   68.428194      304.285556
# 106                          PNEUMONIA      M   66.476030      192.852778
# 107                          PNEUMONIA      M   66.332938       75.099167
# 108                          PNEUMONIA      M   66.476030      192.852778
# ...                                ...    ...         ...             ...
# 315339                           FEVER      F   52.641192      741.343611
# 315340                           FEVER      F   52.641192      741.343611
# 315341                           FEVER      F   53.217130      182.481667
# 315342                           FEVER      F   52.641192      741.343611
# 315343                           FEVER      F   53.217130      182.481667
# 315344                           FEVER      F   53.217130      182.481667
# 315345                           FEVER      F   52.641192      741.343611
# 315404                     BRADYCARDIA      F  300.003209      143.105000
# 315405                     BRADYCARDIA      F  300.003209      143.105000
# 315406                     BRADYCARDIA      F  300.003209      143.105000
# 315407                     BRADYCARDIA      F  300.003209      143.105000
# 315408                     BRADYCARDIA      F  300.003209      143.105000
# 315409                     BRADYCARDIA      F  300.003209      143.105000
# 315410                     BRADYCARDIA      F  300.003209      143.105000
# 315411                     BRADYCARDIA      F  300.003209      143.105000
# 315412                     BRADYCARDIA      F  300.003209      143.105000
# 315413                     BRADYCARDIA      F  300.003209      143.105000
# 315419                  R/O METASTASIS      F   77.807404      101.913611
# 315420                  R/O METASTASIS      F   77.807404      101.913611
# 315421                  R/O METASTASIS      F   77.822144       65.770278
# 315422                  R/O METASTASIS      F   77.807404      101.913611
# 315423                  R/O METASTASIS      F   77.822144       65.770278
# 315424                  R/O METASTASIS      F   77.822144       65.770278
# 315425                  R/O METASTASIS      F   77.822144       65.770278
# 315426                  R/O METASTASIS      F   77.807404      101.913611
# 315427                  R/O METASTASIS      F   77.807404      101.913611
# 315428                  R/O METASTASIS      F   77.807404      101.913611
# 315429                  R/O METASTASIS      F   77.807404      101.913611
# 315430                  R/O METASTASIS      F   77.807404      101.913611
# 315431                  R/O METASTASIS      F   77.807404      101.913611
#
#           rrt
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 36      False
# 37      False
# 38      False
# 41      False
# 42      False
# 77      False
# 78      False
# 79      False
# 87      False
# 88      False
# 89      False
# 96      False
# 97      False
# 106     False
# 107     False
# 108     False
# ...       ...
# 315339  False
# 315340  False
# 315341  False
# 315342  False
# 315343  False
# 315344  False
# 315345  False
# 315404  False
# 315405  False
# 315406  False
# 315407  False
# 315408  False
# 315409  False
# 315410  False
# 315411  False
# 315412  False
# 315413  False
# 315419  False
# 315420  False
# 315421  False
# 315422  False
# 315423  False
# 315424  False
# 315425  False
# 315426  False
# 315427  False
# 315428  False
# 315429  False
# 315430  False
# 315431  False
#
# [126881 rows x 12 columns]

# %% [markdown]
# # Merge tables into one

# %%
print('Chartevents :')
print(df_chartevents.shape)
print(df_chartevents.columns.values)
print('')

print('Static:')
print(df_static.shape)
print(df_static.columns.values)
# Out:
# Chartevents :
# (120650, 30)
# ['arterial_pressure_systolic' 'arterial_pressure_systolic_delay'
#  'arterial_pressure_systolic_time' 'arterial_pressure_diastolic'
#  'arterial_pressure_diastolic_delay' 'arterial_pressure_diastolic_time'
#  'subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'age' 'length_of_stay' 'rrt' 'heart_rate'
#  'heart_rate_delay' 'heart_rate_time' 'weight_daily' 'weight_daily_delay'
#  'weight_daily_time' 'temperature' 'temperature_delay' 'temperature_time'
#  'urine_output' 'urine_output_delay' 'urine_output_time' 'day_urine_output'
#  'day_urine_output_delay' 'day_urine_output_time']
#
# Static:
# (126881, 12)
# ['subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'ethnicity' 'diagnosis' 'gender' 'age' 'length_of_stay'
#  'rrt']

# %%
merged_df = pd.merge(df_chartevents,df_static,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt'],how='outer')

# %% [markdown]
# # Remove columns that are not features (except icustay_id and patient_id that are needed to build the table with labels)

# %%
# REMOVE COLUMNS THAT WERE USED FOR INCLUSION CRITERIA BUT THAT ARE NOT AVAILABLE FEATURES FOR THE PREDICTION
# REMOVE ICUSTAY_IDS FOR WHICH THERE IS ONLY ONE MEASUREMENT OF CREATININE

print('Number of lines : ' + str(merged_df.shape[0]))
to_remove = ['intime','outtime','length_of_stay','rrt']
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)
        
# Remove columns with _time suffix
to_remove = [i for i in merged_df.columns.values if '_time' in i]
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)

# Remove icustay_ids for which there's only one measurement of creatinine
count_mes = merged_df['icustay_id'].value_counts()
to_remove = count_mes.index.values[count_mes==1]
for i in to_remove:
    merged_df = merged_df.loc[merged_df['icustay_id']!=i,:]

print('After dropping unique measurements of creatinine : ' + str(merged_df.shape[0]))
merged_df.head()
# Out:
# Number of lines : 126884
# After dropping unique measurements of creatinine : 126815
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_diastolic arterial_pressure_diastolic_delay  subject_id  \
# 0                         NaN                               NaN         191
# 1                         NaN                               NaN         191
# 2                         NaN                               NaN         191
# 3                         NaN                               NaN         191
# 4                         NaN                               NaN         191
#
#    icustay_id  creatinine        age  heart_rate  heart_rate_delay  ...    \
# 0      280149         1.8  73.159244        93.0             240.0  ...
# 1      280149         2.0  73.159244        81.0            4620.0  ...
# 2      280149         2.2  73.159244       113.0             540.0  ...
# 3      280149         2.6  73.159244        92.0            4320.0  ...
# 4      280149         2.3  73.159244        81.0            2880.0  ...
#
#    weight_daily_delay  temperature  temperature_delay  urine_output  \
# 0             15360.0          NaN                NaN           NaN
# 1             37500.0          NaN                NaN           NaN
# 2            101760.0          NaN                NaN           NaN
# 3            121380.0          NaN                NaN           NaN
# 4            199560.0          NaN                NaN           NaN
#
#   urine_output_delay day_urine_output day_urine_output_delay ethnicity  \
# 0                NaN              NaN                    NaN     ASIAN
# 1                NaN              NaN                    NaN     ASIAN
# 2                NaN              NaN                    NaN     ASIAN
# 3                NaN              NaN                    NaN     ASIAN
# 4                NaN              NaN                    NaN     ASIAN
#
#   diagnosis gender
# 0   ARF,GIB      M
# 1   ARF,GIB      M
# 2   ARF,GIB      M
# 3   ARF,GIB      M
# 4   ARF,GIB      M
#
# [5 rows x 21 columns]

# %%
# Dump to file
merged_df.to_csv('creatinine_measurements_merged.csv')
print(merged_df)
# Out:
#        arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
# 11                            NaN                              NaN
# 12                            NaN                              NaN
# 13                            NaN                              NaN
# 14                            NaN                              NaN
# 15                            NaN                              NaN
# 16                            NaN                              NaN
# 17                            NaN                              NaN
# 18                            NaN                              NaN
# 19                            NaN                              NaN
# 20                            NaN                              NaN
# 21                            NaN                              NaN
# 22                            NaN                              NaN
# 23                            NaN                              NaN
# 24                            NaN                              NaN
# 25                            NaN                              NaN
# 26                            NaN                              NaN
# 27                            NaN                              NaN
# 28                            NaN                              NaN
# 29                            NaN                              NaN
# ...                           ...                              ...
# 126854                        NaN                              NaN
# 126855                        NaN                              NaN
# 126856                        NaN                              NaN
# 126857                        NaN                              NaN
# 126858                        NaN                              NaN
# 126859                        NaN                              NaN
# 126860                        NaN                              NaN
# 126861                        NaN                              NaN
# 126862                        NaN                              NaN
# 126863                        NaN                              NaN
# 126864                        NaN                              NaN
# 126865                        NaN                              NaN
# 126866                        NaN                              NaN
# 126867                        NaN                              NaN
# 126868                        NaN                              NaN
# 126869                        NaN                              NaN
# 126870                        NaN                              NaN
# 126871                        NaN                              NaN
# 126872                        NaN                              NaN
# 126873                        NaN                              NaN
# 126874                        NaN                              NaN
# 126875                        NaN                              NaN
# 126876                        NaN                              NaN
# 126877                        NaN                              NaN
# 126878                        NaN                              NaN
# 126879                        NaN                              NaN
# 126880                        NaN                              NaN
# 126881                        NaN                              NaN
# 126882                        NaN                              NaN
# 126883                        NaN                              NaN
#
#        arterial_pressure_diastolic arterial_pressure_diastolic_delay  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# 5                              NaN                               NaN
# 6                              NaN                               NaN
# 7                              NaN                               NaN
# 8                              NaN                               NaN
# 9                              NaN                               NaN
# 10                             NaN                               NaN
# 11                             NaN                               NaN
# 12                             NaN                               NaN
# 13                             NaN                               NaN
# 14                             NaN                               NaN
# 15                             NaN                               NaN
# 16                             NaN                               NaN
# 17                             NaN                               NaN
# 18                             NaN                               NaN
# 19                             NaN                               NaN
# 20                             NaN                               NaN
# 21                             NaN                               NaN
# 22                             NaN                               NaN
# 23                             NaN                               NaN
# 24                             NaN                               NaN
# 25                             NaN                               NaN
# 26                             NaN                               NaN
# 27                             NaN                               NaN
# 28                             NaN                               NaN
# 29                             NaN                               NaN
# ...                            ...                               ...
# 126854                         NaN                               NaN
# 126855                         NaN                               NaN
# 126856                         NaN                               NaN
# 126857                         NaN                               NaN
# 126858                         NaN                               NaN
# 126859                         NaN                               NaN
# 126860                         NaN                               NaN
# 126861                         NaN                               NaN
# 126862                         NaN                               NaN
# 126863                         NaN                               NaN
# 126864                         NaN                               NaN
# 126865                         NaN                               NaN
# 126866                         NaN                               NaN
# 126867                         NaN                               NaN
# 126868                         NaN                               NaN
# 126869                         NaN                               NaN
# 126870                         NaN                               NaN
# 126871                         NaN                               NaN
# 126872                         NaN                               NaN
# 126873                         NaN                               NaN
# 126874                         NaN                               NaN
# 126875                         NaN                               NaN
# 126876                         NaN                               NaN
# 126877                         NaN                               NaN
# 126878                         NaN                               NaN
# 126879                         NaN                               NaN
# 126880                         NaN                               NaN
# 126881                         NaN                               NaN
# 126882                         NaN                               NaN
# 126883                         NaN                               NaN
#
#         subject_id  icustay_id  creatinine         age  heart_rate  \
# 0              191      280149         1.8   73.159244        93.0
# 1              191      280149         2.0   73.159244        81.0
# 2              191      280149         2.2   73.159244       113.0
# 3              191      280149         2.6   73.159244        92.0
# 4              191      280149         2.3   73.159244        81.0
# 5              191      280149         2.0   73.159244        84.0
# 6              191      280149         1.9   73.159244       108.0
# 7              191      280149         1.5   73.159244       110.0
# 8              222      232363         1.5   68.879206        81.0
# 9              345      260258         0.4  300.003614        80.0
# 10             345      260258         0.5  300.003614       107.0
# 11             222      232363         1.7   68.879206        72.0
# 12             345      260258         0.4  300.003614        74.0
# 13             345      260258         0.5  300.003614        94.0
# 14             345      260258         0.5  300.003614       105.0
# 15             256      254418         2.6   83.873614        68.0
# 16             222      232363         1.6   68.879206        86.0
# 17             222      232363         1.7   68.879206       115.0
# 18             256      254418         2.8   83.873614        58.0
# 19             256      254418         2.7   83.873614        60.0
# 20             222      232363         1.7   68.879206       110.0
# 21             222      232363         1.6   68.879206       118.0
# 22             222      232363         1.1   68.879206       114.0
# 23             256      254418         2.6   83.873614        61.0
# 24             256      254418         2.5   83.873614        76.0
# 25             222      260665         1.3   68.912773        64.0
# 26             222      260665         1.1   68.912773       117.0
# 27             222      260665         1.0   68.912773        88.0
# 28             256      254418         1.6   83.873614        53.0
# 29             222      260665         1.0   68.912773        88.0
# ...            ...         ...         ...         ...         ...
# 126854       97747      210930         0.7   56.599575         NaN
# 126855       97747      210930         0.6   56.599575         NaN
# 126856       97747      210930         0.6   56.599575         NaN
# 126857       94297      200697         1.2   69.363406         NaN
# 126858       94297      200697         1.9   69.363406         NaN
# 126859       94297      200697         1.2   69.363406         NaN
# 126860       94297      200697         1.7   69.363406         NaN
# 126861       94297      200697         1.3   69.363406         NaN
# 126862       94297      200697         1.5   69.363406         NaN
# 126863       94297      200697         1.2   69.363406         NaN
# 126864       94297      200697         1.8   69.363406         NaN
# 126865       94329      289578         1.0   82.322137         NaN
# 126866       93800      241652         3.9   45.344101         NaN
# 126867       96232      213668         1.1   63.737116         NaN
# 126868       96232      213668         0.8   63.737116         NaN
# 126869       96232      213668         1.7   63.737116         NaN
# 126870       96238      261048         2.4  300.001870         NaN
# 126871       95373      278834         0.6   68.372350         NaN
# 126872       95373      278834         0.7   68.372350         NaN
# 126873       98666      273456         0.2   53.217130         NaN
# 126874       98666      273456         0.3   53.217130         NaN
# 126875       98666      273456         0.2   53.217130         NaN
# 126876       98666      273456         0.3   53.217130         NaN
# 126877       98666      273456         0.3   53.217130         NaN
# 126878       98666      273456         0.2   53.217130         NaN
# 126879       98666      273456         0.3   53.217130         NaN
# 126880       98666      273456         0.2   53.217130         NaN
# 126881       98666      273456         0.2   53.217130         NaN
# 126882       98666      273456         0.2   53.217130         NaN
# 126883       98753      207506         1.4   77.807404         NaN
#
#         heart_rate_delay  ...    weight_daily_delay  temperature  \
# 0                  240.0  ...               15360.0          NaN
# 1                 4620.0  ...               37500.0          NaN
# 2                  540.0  ...              101760.0          NaN
# 3                 4320.0  ...              121380.0          NaN
# 4                 2880.0  ...              199560.0          NaN
# 5                 3780.0  ...              287100.0          NaN
# 6                 4800.0  ...              384000.0          NaN
# 7                 2160.0  ...              469260.0          NaN
# 8                 2760.0  ...                2760.0          NaN
# 9                 1620.0  ...                   NaN          NaN
# 10                3660.0  ...                   NaN          NaN
# 11                1140.0  ...               23760.0          NaN
# 12                3540.0  ...                   NaN          NaN
# 13                1980.0  ...                   NaN          NaN
# 14                1140.0  ...                   NaN          NaN
# 15                 300.0  ...               82260.0          NaN
# 16                1860.0  ...               43860.0          NaN
# 17                3420.0  ...               92040.0          NaN
# 18                5760.0  ...              166440.0          NaN
# 19                6600.0  ...               39660.0          NaN
# 20                1680.0  ...              115680.0          NaN
# 21                 660.0  ...              135000.0          NaN
# 22                3480.0  ...               49140.0          NaN
# 23                1800.0  ...               79440.0          NaN
# 24                 960.0  ...              162720.0          NaN
# 25                5640.0  ...                   NaN          NaN
# 26                 900.0  ...                   NaN          NaN
# 27               14820.0  ...                   NaN         97.4
# 28                 960.0  ...               15780.0          NaN
# 29               73440.0  ...                   NaN         96.8
# ...                  ...  ...                   ...          ...
# 126854               NaN  ...                   NaN          NaN
# 126855               NaN  ...                   NaN          NaN
# 126856               NaN  ...                   NaN          NaN
# 126857               NaN  ...                   NaN          NaN
# 126858               NaN  ...                   NaN          NaN
# 126859               NaN  ...                   NaN          NaN
# 126860               NaN  ...                   NaN          NaN
# 126871                NaN           NaN                NaN              NaN
# 126872                NaN           NaN                NaN              NaN
# 126873                NaN           NaN                NaN              NaN
# 126874                NaN           NaN                NaN              NaN
# 126875                NaN           NaN                NaN              NaN
# 126876                NaN           NaN                NaN              NaN
# 126877                NaN           NaN                NaN              NaN
# 126878                NaN           NaN                NaN              NaN
# 126879                NaN           NaN                NaN              NaN
# 126880                NaN           NaN                NaN              NaN
# 126881                NaN           NaN                NaN              NaN
# 126882                NaN           NaN                NaN              NaN
# 126883                NaN           NaN                NaN              NaN
#
#        day_urine_output_delay               ethnicity  \
# 0                         NaN                   ASIAN
# 1                         NaN                   ASIAN
# 2                         NaN                   ASIAN
# 3                         NaN                   ASIAN
# 4                         NaN                   ASIAN
# 5                         NaN                   ASIAN
# 6                         NaN                   ASIAN
# 7                         NaN                   ASIAN
# 8                         NaN                   WHITE
# 9                         NaN      HISPANIC OR LATINO
# 10                        NaN      HISPANIC OR LATINO
# 11                        NaN                   WHITE
# 12                        NaN      HISPANIC OR LATINO
# 13                        NaN      HISPANIC OR LATINO
# 14                        NaN      HISPANIC OR LATINO
# 15                        NaN                   WHITE
# 16                        NaN                   WHITE
# 17                        NaN                   WHITE
# 18                        NaN                   WHITE
# 19                        NaN                   WHITE
# 20                        NaN                   WHITE
# 21                        NaN                   WHITE
# 22                        NaN                   WHITE
# 23                        NaN                   WHITE
# 24                        NaN                   WHITE
# 25                        NaN                   WHITE
# 26                        NaN                   WHITE
# 27                        NaN                   WHITE
# 28                        NaN                   WHITE
# 29                        NaN                   WHITE
# ...                       ...                     ...
# 126854                    NaN                   WHITE
# 126855                    NaN                   WHITE
# 126856                    NaN                   WHITE
# 126857                    NaN                   WHITE
# 126858                    NaN                   WHITE
# 126859                    NaN                   WHITE
# 126860                    NaN                   WHITE
# 126861                    NaN                   WHITE
# 126862                    NaN                   WHITE
# 126863                    NaN                   WHITE
# 126864                    NaN                   WHITE
# 126865                    NaN                   WHITE
# 126866                    NaN                   WHITE
# 126867                    NaN                   WHITE
# 126868                    NaN                   WHITE
# 126869                    NaN                   WHITE
# 126870                    NaN                   WHITE
# 126871                    NaN                   OTHER
# 126872                    NaN                   OTHER
# 126873                    NaN  BLACK/AFRICAN AMERICAN
# 126874                    NaN  BLACK/AFRICAN AMERICAN
# 126875                    NaN  BLACK/AFRICAN AMERICAN
# 126876                    NaN  BLACK/AFRICAN AMERICAN
# 126877                    NaN  BLACK/AFRICAN AMERICAN
# 126878                    NaN  BLACK/AFRICAN AMERICAN
# 126879                    NaN  BLACK/AFRICAN AMERICAN
# 126880                    NaN  BLACK/AFRICAN AMERICAN
# 126881                    NaN  BLACK/AFRICAN AMERICAN
# 126882                    NaN  BLACK/AFRICAN AMERICAN
# 126883                    NaN                   WHITE
#
#                                                 diagnosis gender
# 0                                                 ARF,GIB      M
# 1                                                 ARF,GIB      M
# 2                                                 ARF,GIB      M
# 3                                                 ARF,GIB      M
# 4                                                 ARF,GIB      M
# 5                                                 ARF,GIB      M
# 6                                                 ARF,GIB      M
# 7                                                 ARF,GIB      M
# 8                          CAROTID STENOSIS\CAROTID STENT      F
# 9                                   ALTERED MENTAL STATUS      F
# 10                                  ALTERED MENTAL STATUS      F
# 11                         CAROTID STENOSIS\CAROTID STENT      F
# 12                                  ALTERED MENTAL STATUS      F
# 13                                  ALTERED MENTAL STATUS      F
# 14                                  ALTERED MENTAL STATUS      F
# 15                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 16                         CAROTID STENOSIS\CAROTID STENT      F
# 17                         CAROTID STENOSIS\CAROTID STENT      F
# 18                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 19                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 20                         CAROTID STENOSIS\CAROTID STENT      F
# 21                         CAROTID STENOSIS\CAROTID STENT      F
# 22                         CAROTID STENOSIS\CAROTID STENT      F
# 23                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 24                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 25                         CAROTID STENOSIS\CAROTID STENT      F
# 26                         CAROTID STENOSIS\CAROTID STENT      F
# 27                         CAROTID STENOSIS\CAROTID STENT      F
# 28                          ABDOMINAL AORTIC ANEURYSM/SDA      M
# 29                         CAROTID STENOSIS\CAROTID STENT      F
# ...                                                   ...    ...
# 126854                                 ACUTE PANCREATITIS      M
# 126855                                 ACUTE PANCREATITIS      M
# 126856                                 ACUTE PANCREATITIS      M
# 126857  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126858  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126859  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126860  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126861  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126862  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126863  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126864  EXERTIONAL DYSPNEA; BIVENTRICULAR HEART FAILUR...      F
# 126865                            LT ARM WEAKNESS;R/P CVA      M
# 126866                                             SEPSIS      M
# 126867      AORTIC STENOSIS\AORTIC VALVE REPLACEMENT /SDA      F
# 126868      AORTIC STENOSIS\AORTIC VALVE REPLACEMENT /SDA      F
# 126869      AORTIC STENOSIS\AORTIC VALVE REPLACEMENT /SDA      F
# 126870                             GASTROINTESTINAL BLEED      M
# 126871  MITRAL VALVE INSUFFICIENCY\MITRAL VALVE REPLAC...      F
# 126872  MITRAL VALVE INSUFFICIENCY\MITRAL VALVE REPLAC...      F
# 126873                                              FEVER      F
# 126874                                              FEVER      F
# 126875                                              FEVER      F
# 126876                                              FEVER      F
# 126877                                              FEVER      F
# 126878                                              FEVER      F
# 126879                                              FEVER      F
# 126880                                              FEVER      F
# 126881                                              FEVER      F
# 126882                                              FEVER      F
# 126883                                     R/O METASTASIS      F
#
# [126815 rows x 21 columns]
