# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2

# below imports are used to print out pretty pandas dataframes
from IPython.display import display, HTML

# %matplotlib inline
plt.style.use('ggplot')

# %%
# information used to create a database connection
sqluser = 'postgres'
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to postgres with a copy of the MIMIC-III database
con = psycopg2.connect(dbname=dbname, user=sqluser)

# the below statement is prepended to queries to ensure they select from the right schema
query_schema = 'set search_path to ' + schema_name + ';'

# %%
def apply_inclusion_criteria(df):
    print('Initial size of table : ' + str(df.shape[0]))
    df = df.drop_duplicates(['icustay_id','creatinine_time'])
    print('After dropping duplicates : ' + str(df.shape[0]))
    criteria_list = [i for i in df.columns.values if 'inclusion' in i]
    for c in criteria_list:
        df = df.loc[df[c]==1,:].drop(c,axis=1)    
    print('After applying inclusion criteria : ' + str(df.shape[0]))
    return df

# %% [markdown]
# # Retrieve interesting lab events for patients that match inclusion criteria

# %%
features_info = pd.read_csv('features_info.csv')
#features_list = ['Urea','Temperature']
# Cut the table for test purposes
#features_info = features_info.loc[features_info['name'].apply(lambda x:x in features_list),:].reset_index(drop=True)
print(features_info)
# Out:
#                            name        table  variable  item_id  item_id_2  \
# 0    Arterial_pressure_systolic  chartevents  valuenum        6       51.0
# 1   Arterial_pressure_diastolic  chartevents  valuenum     8364     8368.0
# 2                    Heart_rate  chartevents  valuenum      211   220045.0
# 3                  Weight_daily  chartevents  valuenum      763   224639.0
# 4                   Temperature  chartevents  valuenum   223761      678.0
# 5                  Urine_output  chartevents  valuenum    43966    44706.0
# 6              day_urine_output  chartevents  valuenum    43372        NaN
# 7                           SCr    labevents  valuenum    50912    51081.0
# 8                          Urea    labevents  valuenum    51006        NaN
# 9                        Sodium    labevents  valuenum    50824    50983.0
# 10                    Potassium    labevents  valuenum    50822    50971.0
# 11                      Calcium    labevents  valuenum    50808    50893.0
# 12                     Phosphor    labevents  valuenum    50970        NaN
# 13                   Leukocytes    labevents  valuenum    51300        NaN
# 14                  Hemoglobine    labevents  valuenum    50811    50855.0
# 15                  Bicarbonate    labevents  valuenum    50803    50882.0
# 16                      Lactate    labevents  valuenum    50813        NaN
# 17                    Uric_acid    labevents  valuenum    51007        NaN
# 18                     Chloride    labevents  valuenum    50806    50902.0
# 19                  Neutrophils    labevents  valuenum    51256        NaN
# 20                  Lymphocytes    labevents  valuenum    51244    51133.0
# 21               Platelet_count    labevents  valuenum    51265        NaN
# 22                     pH_blood    labevents  valuenum    50820        NaN
# 23                     pH_urine    labevents  valuenum    51094    51491.0
# 24                    Monocytes    labevents  valuenum    51253    51254.0
# 25                   fibrinogen    labevents  valuenum    51214        NaN
# 26               urinary_sodium    labevents  valuenum    51100        NaN
# 27            urinary_potassium    labevents  valuenum    51097        NaN
# 28                   urine_urea    labevents  valuenum    51104        NaN
# 29              urine_creatinin    labevents  valuenum    51082    51081.0
# 30          alkaline_phospatase    labevents  valuenum    50863        NaN
# 31          Total_protein_blood    labevents  valuenum    50976        NaN
# 32                      albumin    labevents  valuenum    50862        NaN
# 33          Total_protein_urine    labevents  valuenum    51102    51492.0
# 34                    bilirubin    labevents  valuenum    50885        NaN
# 35           C_reactive_protein    labevents  valuenum    50889        NaN
#
#     item_id_3  item_id_4  item_id_5  item_id_6
# 0       455.0   220050.0   220179.0   225309.0
# 1      8441.0   220051.0   220180.0   225310.0
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# 4       645.0        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN
# 13        NaN        NaN        NaN        NaN
# 14    51222.0        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN
# 16        NaN        NaN        NaN        NaN
# 17        NaN        NaN        NaN        NaN
# 18        NaN        NaN        NaN        NaN
# 19        NaN        NaN        NaN        NaN
# 20        NaN        NaN        NaN        NaN
# 21        NaN        NaN        NaN        NaN
# 22        NaN        NaN        NaN        NaN
# 23        NaN        NaN        NaN        NaN
# 24        NaN        NaN        NaN        NaN
# 25        NaN        NaN        NaN        NaN
# 26        NaN        NaN        NaN        NaN
# 27        NaN        NaN        NaN        NaN
# 28        NaN        NaN        NaN        NaN
# 29    51106.0        NaN        NaN        NaN
# 30        NaN        NaN        NaN        NaN
# 31        NaN        NaN        NaN        NaN
# 32        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN
# 34        NaN        NaN        NaN        NaN
# 35        NaN        NaN        NaN        NaN

# %%
query = query_schema + """
with cr as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    le.valuenum as creatinine, le.charttime as creatinine_time,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt
  from icustays icu
  inner join """+features_info.loc[0,'table']+""" le
    on icu.subject_id = le.subject_id
    and le.itemid = 50912
    and le."""+features_info.loc[0,'variable']+""" is not null
    and le.charttime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
),
cr_inc as
(
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt
  from cr),
cr_feat as
(
select
cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
    cr_inc.creatinine, cr_inc.creatinine_time,
    cr_inc.age, cr_inc.inclusion_age,
    cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
    cr_inc.rrt, cr_inc.inclusion_rrt,
    le.valuenum as """+features_info.loc[0,'name']+""", EXTRACT('epoch' from cr_inc.creatinine_time - le.charttime) as """+features_info.loc[0,'name']+"""_delay, le.charttime as """+features_info.loc[0,'name']+"""_time
  from cr_inc
  inner join """+features_info.loc[0,'table']+""" le
    on cr_inc.subject_id = le.subject_id
    and le.itemid = """+str(features_info.loc[0,'item_id'])+"""
    and le."""+features_info.loc[0,'variable']+""" is not null
    and le.charttime between cr_inc.intime and cr_inc.creatinine_time
)
select 
a.subject_id, a.icustay_id, a.intime, a.outtime,
    a.creatinine, a.creatinine_time,
    a.age, a.inclusion_age,
    a.length_of_stay, a.inclusion_length_of_stay,
    a.rrt, a.inclusion_rrt,
    a."""+features_info.loc[0,'name']+""", a."""+features_info.loc[0,'name']+"""_delay, a."""+features_info.loc[0,'name']+"""_time
from cr_feat as a
    join (
        -- Get the min seenID for each personID
        select creatinine_time, min("""+features_info.loc[0,'name']+"""_delay) as """+features_info.loc[0,'name']+"""_delay
        from cr_feat
        group by creatinine_time
    ) as b on a.creatinine_time = b.creatinine_time
where a."""+features_info.loc[0,'name']+"""_delay = b."""+features_info.loc[0,'name']+"""_delay
"""
df_labevents = pd.read_sql_query(query, con)
print(df_labevents.head())
df_labevents = apply_inclusion_criteria(df_labevents)
print(df_labevents.head())
    
for i,row in features_info.loc[1:,:].iterrows():
    print('------------------------------------')
    print('--- Processing feature : ' + row['name'])

    query = query_schema + """
    with cr as
    (
    select
        icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
        le.valuenum as creatinine, le.charttime as creatinine_time,
        EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
        (rrt.icustay_id is null) as rrt
      from icustays icu
      inner join """+row['table']+""" le
        on icu.subject_id = le.subject_id
        and le.itemid = 50912
        and le."""+row['variable']+""" is not null
        and le.charttime between icu.intime and icu.outtime
      inner join patients pat
        ON icu.subject_id = pat.subject_id
      left outer join rrt 
        on icu.icustay_id = rrt.icustay_id
    ),
    cr_inc as
    (
    select
    cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
        cr.creatinine, cr.creatinine_time,
        cr.age, CASE
                    WHEN cr.age >= 15 then 1
                ELSE 0 END
                as inclusion_age,
      cr.length_of_stay, CASE
                            WHEN cr.length_of_stay >= 48 then 1
                         ELSE 0 END
                         as inclusion_length_of_stay,
      cr.rrt, CASE
                WHEN cr.rrt = False then 1
              ELSE 0 END
              as inclusion_rrt
      from cr),
    cr_feat as
    (
    select
    cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
        cr_inc.creatinine, cr_inc.creatinine_time,
        cr_inc.age, cr_inc.inclusion_age,
        cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
        cr_inc.rrt, cr_inc.inclusion_rrt,
        le.valuenum as """+row['name']+""", EXTRACT('epoch' from cr_inc.creatinine_time - le.charttime) as """+row['name']+"""_delay, le.charttime as """+row['name']+"""_time
      from cr_inc
      inner join """+row['table']+""" le
        on cr_inc.subject_id = le.subject_id
        and le.itemid = """+str(row['item_id'])+"""
        and le."""+row['variable']+""" is not null
        and le.charttime between cr_inc.intime and cr_inc.creatinine_time
    )
    select 
    a.subject_id, a.icustay_id, a.intime, a.outtime,
        a.creatinine, a.creatinine_time,
        a.age, a.inclusion_age,
        a.length_of_stay, a.inclusion_length_of_stay,
        a.rrt, a.inclusion_rrt,
        a."""+row['name']+""", a."""+row['name']+"""_delay, a."""+row['name']+"""_time
    from cr_feat as a
        join (
            -- Get the min seenID for each personID
            select creatinine_time, min("""+row['name']+"""_delay) as """+row['name']+"""_delay
            from cr_feat
            group by creatinine_time
        ) as b on a.creatinine_time = b.creatinine_time
    where a."""+row['name']+"""_delay = b."""+row['name']+"""_delay
    """
    df = pd.read_sql_query(query, con)
    df = apply_inclusion_criteria(df)
    print(df.head())
    df_labevents = pd.merge(df_labevents,df,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt'],how='outer')
    print('---------------------------------')
    print('Merged table size : ' + str(df_labevents.shape[0]))
    print(df_labevents.head())
# Out:
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, inclusion_age, length_of_stay, inclusion_length_of_stay, rrt, inclusion_rrt, arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time]
# Index: []
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time]
# Index: []
# ------------------------------------
# --- Processing feature : Arterial_pressure_diastolic
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time]
# Index: []
# ------------------------------------
# --- Processing feature : Heart_rate
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, heart_rate, heart_rate_delay, heart_rate_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, heart_rate, heart_rate_delay, heart_rate_time]
# Index: []
# ------------------------------------
# --- Processing feature : Weight_daily
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, weight_daily, weight_daily_delay, weight_daily_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time, heart_rate, heart_rate_delay, heart_rate_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, weight_daily, weight_daily_delay, weight_daily_time]
# Index: []
#
# [0 rows x 21 columns]
# ------------------------------------
# --- Processing feature : Temperature
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, temperature, temperature_delay, temperature_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time, heart_rate, heart_rate_delay, heart_rate_time, weight_daily, weight_daily_delay, weight_daily_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, temperature, temperature_delay, temperature_time]
# Index: []
#
# [0 rows x 24 columns]
# ------------------------------------
# --- Processing feature : Urine_output
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, urine_output, urine_output_delay, urine_output_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time, heart_rate, heart_rate_delay, heart_rate_time, weight_daily, weight_daily_delay, weight_daily_time, temperature, temperature_delay, temperature_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, urine_output, urine_output_delay, urine_output_time]
# Index: []
#
# [0 rows x 27 columns]
# ------------------------------------
# --- Processing feature : day_urine_output
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py:1457: RuntimeWarning: divide by zero encountered in long_scalars
#   stride //= shape[i]
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Empty DataFrame
# Columns: [subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, day_urine_output, day_urine_output_delay, day_urine_output_time]
# Index: []
# ---------------------------------
# Merged table size : 0
# Empty DataFrame
# Columns: [arterial_pressure_systolic, arterial_pressure_systolic_delay, arterial_pressure_systolic_time, arterial_pressure_diastolic, arterial_pressure_diastolic_delay, arterial_pressure_diastolic_time, heart_rate, heart_rate_delay, heart_rate_time, weight_daily, weight_daily_delay, weight_daily_time, temperature, temperature_delay, temperature_time, urine_output, urine_output_delay, urine_output_time, subject_id, icustay_id, intime, outtime, creatinine, creatinine_time, age, length_of_stay, rrt, day_urine_output, day_urine_output_delay, day_urine_output_time]
# Index: []
#
# [0 rows x 30 columns]
# ------------------------------------
# --- Processing feature : SCr
# Initial size of table : 327367
# After dropping duplicates : 326653
# After applying inclusion criteria : 279205
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         2.4
# 1          12      232669 2104-08-08 02:08:17 2104-08-15 17:22:25         1.1
# 2          12      232669 2104-08-08 02:08:17 2104-08-15 17:22:25         1.3
# 3          13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31         0.5
# 4          21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32         2.3
#
#       creatinine_time        age  length_of_stay    rrt  scr  scr_delay  \
# 0 2101-10-20 19:26:00  76.526792      145.549444  False  2.4        0.0
# 1 2104-08-13 03:51:00  72.374177      183.235556  False  1.1        0.0
# 2 2104-08-08 04:15:00  72.374177      183.235556  False  1.3        0.0
# 3 2167-01-09 17:09:00  39.866118       87.985000  False  0.5        0.0
# 4 2134-09-14 03:54:00  87.440295      141.641111  False  2.3        0.0
#
#              scr_time
# 0 2101-10-20 19:26:00
# 1 2104-08-13 03:51:00
# 2 2104-08-08 04:15:00
# 3 2167-01-09 17:09:00
# 4 2134-09-14 03:54:00
# ---------------------------------
# Merged table size : 279205
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...                      intime             outtime creatinine  \
# 0         ...         2101-10-20 19:10:11 2101-10-26 20:43:09        2.4
# 1         ...         2104-08-08 02:08:17 2104-08-15 17:22:25        1.1
# 2         ...         2104-08-08 02:08:17 2104-08-15 17:22:25        1.3
# 3         ...         2167-01-08 18:44:25 2167-01-12 10:43:31        0.5
# 4         ...         2134-09-11 20:50:04 2134-09-17 18:28:32        2.3
#
#       creatinine_time        age length_of_stay    rrt  scr scr_delay  \
# 0 2101-10-20 19:26:00  76.526792     145.549444  False  2.4       0.0
# 1 2104-08-13 03:51:00  72.374177     183.235556  False  1.1       0.0
# 2 2104-08-08 04:15:00  72.374177     183.235556  False  1.3       0.0
# 3 2167-01-09 17:09:00  39.866118      87.985000  False  0.5       0.0
# 4 2134-09-14 03:54:00  87.440295     141.641111  False  2.3       0.0
#
#              scr_time
# 0 2101-10-20 19:26:00
# 1 2104-08-13 03:51:00
# 2 2104-08-08 04:15:00
# 3 2167-01-09 17:09:00
# 4 2134-09-14 03:54:00
#
# [5 rows x 33 columns]
# ------------------------------------
# --- Processing feature : Urea
# Initial size of table : 327154
# After dropping duplicates : 326439
# After applying inclusion criteria : 279085
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 1         231      242685 2176-05-28 22:09:25 2176-06-03 16:44:30         0.6
# 2         231      242685 2176-05-28 22:09:25 2176-06-03 16:44:30         0.4
# 3         231      242685 2176-05-28 22:09:25 2176-06-03 16:44:30         0.5
# 4         231      242685 2176-05-28 22:09:25 2176-06-03 16:44:30         0.5
# 5         231      242685 2176-05-28 22:09:25 2176-06-03 16:44:30         0.6
#
#       creatinine_time        age  length_of_stay    rrt  leukocytes  \
# 1 2176-05-31 21:48:00  36.769931      138.584722  False        17.9
# 2 2176-06-02 05:22:00  36.769931      138.584722  False        17.9
# 3 2176-06-03 04:51:00  36.769931      138.584722  False        17.9
# 4 2176-05-30 08:04:00  36.769931      138.584722  False        17.9
# 5 2176-05-31 02:50:00  36.769931      138.584722  False        17.9
#
#    leukocytes_delay     leukocytes_time
# 1          135840.0 2176-05-30 08:04:00
# 2          249480.0 2176-05-30 08:04:00
# 3          334020.0 2176-05-30 08:04:00
# 4               0.0 2176-05-30 08:04:00
# 5           67560.0 2176-05-30 08:04:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily       ...        \
# 0        NaN              NaN             NaN          NaN       ...
# 1        NaN              NaN             NaN          NaN       ...
# 2        NaN              NaN             NaN          NaN       ...
# 3        NaN              NaN             NaN          NaN       ...
# 4        NaN              NaN             NaN          NaN       ...
#
#        potassium_time calcium calcium_delay        calcium_time phosphor  \
# 0 2101-10-20 19:14:00    0.82         720.0 2101-10-20 19:14:00      4.7
# 1 2104-08-12 22:21:00    1.13         660.0 2104-08-13 03:40:00      2.6
# 2 2104-08-08 02:42:00    0.96        2700.0 2104-08-08 03:30:00      6.6
# 3 2167-01-09 15:47:00    1.34        4920.0 2167-01-09 15:47:00      4.5
# 4                 NaT    1.25       21900.0 2134-09-13 21:49:00      4.4
#
#   phosphor_delay       phosphor_time leukocytes leukocytes_delay  \
# 0            0.0 2101-10-20 19:26:00        NaN              NaN
# 1            0.0 2104-08-13 03:51:00        NaN              NaN
# 2            0.0 2104-08-08 04:15:00        NaN              NaN
# 3        35880.0 2167-01-09 07:11:00        NaN              NaN
# 4            0.0 2134-09-14 03:54:00        NaN              NaN
#
#   leukocytes_time
# 0             NaT
# 1             NaT
# 2             NaT
# 3             NaT
# 4             NaT
#
# [5 rows x 51 columns]
# ------------------------------------
# --- Processing feature : Hemoglobine
# Initial size of table : 125671
# After dropping duplicates : 125508
# After applying inclusion criteria : 117688
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.7
# 1           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.9
# 2           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.3
# 3           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         2.0
# 4           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         1.4
#
#       creatinine_time        age  length_of_stay    rrt  hemoglobine  \
# 0 2101-10-22 21:15:00  76.526792      145.549444  False         10.1
# 1 2101-10-22 04:00:00  76.526792      145.549444  False          8.8
# 2 2101-10-25 03:00:00  76.526792      145.549444  False         10.5
# 3 2149-11-12 03:00:00  41.790228      127.753333  False         14.0
# 4 2149-11-10 03:00:00  41.790228      127.753333  False         14.0
#
#    hemoglobine_delay    hemoglobine_time
# 0            18780.0 2101-10-22 16:02:00
# 1             7560.0 2101-10-22 01:54:00
# 2            79680.0 2101-10-24 04:52:00
# 3           205980.0 2149-11-09 17:47:00
# 4            33180.0 2149-11-09 17:47:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...                calcium_time phosphor phosphor_delay  \
# 0         ...         2101-10-20 19:14:00      4.7            0.0
# 1         ...         2104-08-13 03:40:00      2.6            0.0
# 2         ...         2104-08-08 03:30:00      6.6            0.0
# 3         ...         2167-01-09 15:47:00      4.5        35880.0
# 4         ...         2134-09-13 21:49:00      4.4            0.0
#
#         phosphor_time leukocytes leukocytes_delay leukocytes_time hemoglobine  \
# 0 2101-10-20 19:26:00        NaN              NaN             NaT         NaN
# 1 2104-08-13 03:51:00        NaN              NaN             NaT        12.0
# 2 2104-08-08 04:15:00        NaN              NaN             NaT        11.1
# 3 2167-01-09 07:11:00        NaN              NaN             NaT         7.9
# 4 2134-09-14 03:54:00        NaN              NaN             NaT        11.1
#
#   hemoglobine_delay    hemoglobine_time
# 0               NaN                 NaT
# 1          321360.0 2104-08-09 10:35:00
# 2            2700.0 2104-08-08 03:30:00
# 3            4920.0 2167-01-09 15:47:00
# 4          147180.0 2134-09-12 11:01:00
#
# [5 rows x 54 columns]
# ------------------------------------
# --- Processing feature : Bicarbonate
# Initial size of table : 21034
# After dropping duplicates : 21034
# After applying inclusion criteria : 20467
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.7
# 1           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         2.5
# 2           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.6
# 3           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.9
# 4           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.5
#
#       creatinine_time        age  length_of_stay    rrt  bicarbonate  \
# 0 2101-10-22 21:15:00  76.526792      145.549444  False         15.0
# 1 2101-10-21 03:00:00  76.526792      145.549444  False         15.0
# 2 2101-10-23 03:45:00  76.526792      145.549444  False         15.0
# 3 2101-10-22 04:00:00  76.526792      145.549444  False         15.0
# 4 2101-10-24 03:15:00  76.526792      145.549444  False         15.0
#
#    bicarbonate_delay    bicarbonate_time
# 0           156540.0 2101-10-21 01:46:00
# 1             4440.0 2101-10-21 01:46:00
# 2           179940.0 2101-10-21 01:46:00
# 3            94440.0 2101-10-21 01:46:00
# 4           264540.0 2101-10-21 01:46:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...               phosphor_time leukocytes leukocytes_delay  \
# 0         ...         2101-10-20 19:26:00        NaN              NaN
# 1         ...         2104-08-13 03:51:00        NaN              NaN
# 2         ...         2104-08-08 04:15:00        NaN              NaN
# 3         ...         2167-01-09 07:11:00        NaN              NaN
# 4         ...         2134-09-14 03:54:00        NaN              NaN
#
#   leukocytes_time hemoglobine hemoglobine_delay    hemoglobine_time  \
# 0             NaT         NaN               NaN                 NaT
# 1             NaT        12.0          321360.0 2104-08-09 10:35:00
# 2             NaT        11.1            2700.0 2104-08-08 03:30:00
# 3             NaT         7.9            4920.0 2167-01-09 15:47:00
# 4             NaT        11.1          147180.0 2134-09-12 11:01:00
#
#   bicarbonate bicarbonate_delay    bicarbonate_time
# 0         NaN               NaN                 NaT
# 1        10.0          437760.0 2104-08-08 02:15:00
# 2        10.0            7200.0 2104-08-08 02:15:00
# 3         NaN               NaN                 NaT
# 4         NaN               NaN                 NaT
#
# [5 rows x 57 columns]
# ------------------------------------
# --- Processing feature : Lactate
# Initial size of table : 212890
# After dropping duplicates : 212479
# After applying inclusion criteria : 199761
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.9
# 1           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.7
# 2           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.3
# 3           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         2.0
# 4           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         1.6
#
#       creatinine_time        age  length_of_stay    rrt  lactate  \
# 0 2101-10-22 04:00:00  76.526792      145.549444  False      1.3
# 1 2101-10-22 21:15:00  76.526792      145.549444  False      1.3
# 2 2101-10-25 03:00:00  76.526792      145.549444  False      1.0
# 3 2149-11-11 03:00:00  41.790228      127.753333  False      2.3
# 4 2149-11-13 03:20:00  41.790228      127.753333  False      2.6
#
#    lactate_delay        lactate_time
# 0         7800.0 2101-10-22 01:50:00
# 1        60240.0 2101-10-22 04:31:00
# 2       173640.0 2101-10-23 02:46:00
# 3        18180.0 2149-11-10 21:57:00
# 4       172380.0 2149-11-11 03:27:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...         leukocytes_time hemoglobine hemoglobine_delay  \
# 0         ...                     NaT         NaN               NaN
# 1         ...                     NaT        12.0          321360.0
# 2         ...                     NaT        11.1            2700.0
# 3         ...                     NaT         7.9            4920.0
# 4         ...                     NaT        11.1          147180.0
#
#      hemoglobine_time bicarbonate bicarbonate_delay    bicarbonate_time  \
# 0                 NaT         NaN               NaN                 NaT
# 1 2104-08-09 10:35:00        10.0          437760.0 2104-08-08 02:15:00
# 2 2104-08-08 03:30:00        10.0            7200.0 2104-08-08 02:15:00
# 3 2167-01-09 15:47:00         NaN               NaN                 NaT
# 4 2134-09-12 11:01:00         NaN               NaN                 NaT
#
#   lactate lactate_delay        lactate_time
# 0     8.8         720.0 2101-10-20 19:14:00
# 1     2.9         660.0 2104-08-13 03:40:00
# 2    13.1        2700.0 2104-08-08 03:30:00
# 3     NaN           NaN                 NaT
# 4     1.5       62700.0 2134-09-13 10:29:00
#
# [5 rows x 60 columns]
# ------------------------------------
# --- Processing feature : Uric_acid
# Initial size of table : 20796
# After dropping duplicates : 20796
# After applying inclusion criteria : 19907
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.9
# 1           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         2.5
# 2           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         2.5
# 3           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.5
# 4           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.7
#
#       creatinine_time        age  length_of_stay    rrt  uric_acid  \
# 0 2101-10-22 04:00:00  76.526792      145.549444  False       10.3
# 1 2101-10-20 19:59:00  76.526792      145.549444  False       10.3
# 2 2101-10-21 03:00:00  76.526792      145.549444  False       10.3
# 3 2101-10-24 03:15:00  76.526792      145.549444  False       10.3
# 4 2101-10-22 21:15:00  76.526792      145.549444  False       10.3
#
#    uric_acid_delay      uric_acid_time
# 0         115260.0 2101-10-20 19:59:00
# 1              0.0 2101-10-20 19:59:00
# 2          25260.0 2101-10-20 19:59:00
# 3         285360.0 2101-10-20 19:59:00
# ...
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...         urine_creatinin_time alkaline_phospatase  \
# 0         ...                          NaT                 NaN
# 1         ...                          NaT               193.0
# 2         ...                          NaT                 NaN
# 3         ...                          NaT                49.0
# 4         ...                          NaT                72.0
#
#   alkaline_phospatase_delay alkaline_phospatase_time total_protein_blood  \
# 0                       NaN                      NaT                 NaN
# 1                       0.0      2104-08-13 03:51:00                 NaN
# 2                       NaN                      NaT                 NaN
# 3                   74460.0      2167-01-08 20:28:00                 NaN
# 4                  170640.0      2134-09-12 04:30:00                 NaN
#
#   total_protein_blood_delay total_protein_blood_time albumin albumin_delay  \
# 0                       NaN                      NaT     NaN           NaN
# 1                       NaN                      NaT     2.2           0.0
# 2                       NaN                      NaT     NaN           NaN
# 3                       NaN                      NaT     3.9       74460.0
# 4                       NaN                      NaT     NaN           NaN
#
#          albumin_time
# 0                 NaT
# 1 2104-08-13 03:51:00
# 2                 NaT
# 3 2167-01-08 20:28:00
# 4                 NaT
#
# [5 rows x 108 columns]
# ------------------------------------
# --- Processing feature : Total_protein_urine
# Initial size of table : 15708
# After dropping duplicates : 15681
# After applying inclusion criteria : 15241
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0          83      254066 2142-04-03 10:33:32 2142-04-05 18:05:53         3.0
# 1          83      254066 2142-04-03 10:33:32 2142-04-05 18:05:53         2.8
# 2          94      213450 2176-09-02 16:27:46 2176-09-25 14:00:30         0.3
# 3          94      213450 2176-09-02 16:27:46 2176-09-25 14:00:30         0.3
# 4          94      213450 2176-09-02 16:27:46 2176-09-25 14:00:30         0.4
#
#       creatinine_time        age  length_of_stay    rrt  total_protein_urine  \
# 0 2142-04-04 05:22:00  65.546788       55.539167  False                196.0
# 1 2142-04-05 05:52:00  65.546788       55.539167  False                196.0
# 2 2176-09-10 00:49:00  74.954923      549.545556  False                 12.0
# 3 2176-09-14 04:01:00  74.954923      549.545556  False                 12.0
# 4 2176-09-12 02:15:00  74.954923      549.545556  False                 12.0
#
#    total_protein_urine_delay total_protein_urine_time
# 0                    25380.0      2142-04-03 22:19:00
# 1                   113580.0      2142-04-03 22:19:00
# 2                    40260.0      2176-09-09 13:38:00
# 3                   397380.0      2176-09-09 13:38:00
# 4                   218220.0      2176-09-09 13:38:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#             ...            alkaline_phospatase_time total_protein_blood  \
# 0           ...                                 NaT                 NaN
# 1           ...                 2104-08-13 03:51:00                 NaN
# 2           ...                                 NaT                 NaN
# 3           ...                 2167-01-08 20:28:00                 NaN
# 4           ...                 2134-09-12 04:30:00                 NaN
#
#   total_protein_blood_delay total_protein_blood_time albumin albumin_delay  \
# 0                       NaN                      NaT     NaN           NaN
# 1                       NaN                      NaT     2.2           0.0
# 2                       NaN                      NaT     NaN           NaN
# 3                       NaN                      NaT     3.9       74460.0
# 4                       NaN                      NaT     NaN           NaN
#
#          albumin_time total_protein_urine total_protein_urine_delay  \
# 0                 NaT                 NaN                       NaN
# 1 2104-08-13 03:51:00                 NaN                       NaN
# 2                 NaT                 NaN                       NaN
# 3 2167-01-08 20:28:00                 NaN                       NaN
# 4                 NaT                 NaN                       NaN
#
#   total_protein_urine_time
# 0                      NaT
# 1                      NaT
# 2                      NaT
# 3                      NaT
# 4                      NaT
#
# [5 rows x 111 columns]
# ------------------------------------
# --- Processing feature : bilirubin
# Initial size of table : 193432
# After dropping duplicates : 193018
# After applying inclusion criteria : 177120
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           3      211552 2101-10-20 19:10:11 2101-10-26 20:43:09         1.3
# 1           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         5.1
# 2           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         1.6
# 3          12      232669 2104-08-08 02:08:17 2104-08-15 17:22:25         1.2
# 4          12      232669 2104-08-08 02:08:17 2104-08-15 17:22:25         1.1
#
#       creatinine_time        age  length_of_stay    rrt  bilirubin  \
# 0 2101-10-25 03:00:00  76.526792      145.549444  False        0.8
# 1 2175-06-03 00:58:00  65.942297       88.150000  False        0.3
# 2 2149-11-13 03:20:00  41.790228      127.753333  False        0.4
# 3 2104-08-10 01:00:00  72.374177      183.235556  False        9.9
# 4 2104-08-11 03:00:00  72.374177      183.235556  False        8.4
#
#    bilirubin_delay      bilirubin_time
# 0         255600.0 2101-10-22 04:00:00
# 1              0.0 2175-06-03 00:58:00
# 2          87600.0 2149-11-12 03:00:00
# 3              0.0 2104-08-10 01:00:00
# 4              0.0 2104-08-11 03:00:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#           ...         total_protein_blood_time albumin albumin_delay  \
# 0         ...                              NaT     NaN           NaN
# 1         ...                              NaT     2.2           0.0
# 2         ...                              NaT     NaN           NaN
# 3         ...                              NaT     3.9       74460.0
# 4         ...                              NaT     NaN           NaN
#
#          albumin_time total_protein_urine total_protein_urine_delay  \
# 0                 NaT                 NaN                       NaN
# 1 2104-08-13 03:51:00                 NaN                       NaN
# 2                 NaT                 NaN                       NaN
# 3 2167-01-08 20:28:00                 NaN                       NaN
# 4                 NaT                 NaN                       NaN
#
#   total_protein_urine_time bilirubin bilirubin_delay      bilirubin_time
# 0                      NaT       NaN             NaN                 NaT
# 1                      NaT       8.2             0.0 2104-08-13 03:51:00
# 2                      NaT       NaN             NaN                 NaT
# 3                      NaT       0.4         74460.0 2167-01-08 20:28:00
# 4                      NaT       0.4        170640.0 2134-09-12 04:30:00
#
# [5 rows x 114 columns]
# ------------------------------------
# --- Processing feature : C_reactive_protein
# Initial size of table : 7917
# After dropping duplicates : 7917
# After applying inclusion criteria : 7574
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0          36      211200 2131-05-16 23:18:26 2131-05-23 19:56:11         1.1
# 1          36      211200 2131-05-16 23:18:26 2131-05-23 19:56:11         1.1
# 2         109      271885 2138-04-16 17:45:30 2138-04-19 18:00:22         4.9
# 3         109      271885 2138-04-16 17:45:30 2138-04-19 18:00:22         5.8
# 4         109      271885 2138-04-16 17:45:30 2138-04-19 18:00:22         5.3
#
#       creatinine_time        age  length_of_stay    rrt  c_reactive_protein  \
# 0 2131-05-23 00:58:00  69.745460      164.629167  False              123.40
# 1 2131-05-22 02:05:00  69.745460      164.629167  False              123.40
# 2 2138-04-17 05:01:00  20.692417       72.247778  False                2.59
# 3 2138-04-18 01:42:00  20.692417       72.247778  False                2.59
# 4 2138-04-19 06:30:00  20.692417       72.247778  False                2.59
#
#    c_reactive_protein_delay c_reactive_protein_time
# 0                   82380.0     2131-05-22 02:05:00
# 1                       0.0     2131-05-22 02:05:00
# 2                       0.0     2138-04-17 05:01:00
# 3                   74460.0     2138-04-17 05:01:00
# 4                  178140.0     2138-04-17 05:01:00
# ---------------------------------
# Merged table size : 279206
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#   heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0        NaN              NaN             NaN          NaN
# 1        NaN              NaN             NaN          NaN
# 2        NaN              NaN             NaN          NaN
# 3        NaN              NaN             NaN          NaN
# 4        NaN              NaN             NaN          NaN
#
#             ...                  albumin_time total_protein_urine  \
# 0           ...                           NaT                 NaN
# 1           ...           2104-08-13 03:51:00                 NaN
# 2           ...                           NaT                 NaN
# 3           ...           2167-01-08 20:28:00                 NaN
# 4           ...                           NaT                 NaN
#
#   total_protein_urine_delay total_protein_urine_time bilirubin  \
# 0                       NaN                      NaT       NaN
# 1                       NaN                      NaT       8.2
# 2                       NaN                      NaT       NaN
# 3                       NaN                      NaT       0.4
# 4                       NaN                      NaT       0.4
#
#   bilirubin_delay      bilirubin_time c_reactive_protein  \
# 0             NaN                 NaT                NaN
# 1             0.0 2104-08-13 03:51:00                NaN
# 2             NaN                 NaT                NaN
# 3         74460.0 2167-01-08 20:28:00                NaN
# 4        170640.0 2134-09-12 04:30:00                NaN
#
#   c_reactive_protein_delay c_reactive_protein_time
# 0                      NaN                     NaT
# 1                      NaN                     NaT
# 2                      NaN                     NaT
# 3                      NaN                     NaT
# 4                      NaN                     NaT
#
# [5 rows x 117 columns]

# %%
# REMOVE COLUMNS THAT WERE USED FOR INCLUSION CRITERIA BUT THAT ARE NOT AVAILABLE FEATURES FOR THE PREDICTION
# REMOVE ICUSTAY_IDS FOR WHICH THERE IS ONLY ONE MEASUREMENT OF CREATININE

#print('Number of lines : ' + str(last_df.shape[0]))
#to_remove = ['intime','outtime','length_of_stay','rrt']
#for c in to_remove:
#    if (c in last_df.columns.values): last_df = last_df.drop(c,axis=1)

# Remove icustay_ids for which there's only one measurement of creatinine
#count_mes = last_df['icustay_id'].value_counts()
#to_remove = count_mes.index.values[count_mes==1]
#for i in to_remove:
#    last_df = last_df.loc[last_df['icustay_id']!=i,:]

#print('After dropping unique measurements of creatinine : ' + str(last_df.shape[0]))
#last_df.head()

# %%
# Dump to file
df_labevents.to_csv('creatinine_measurements_1.csv')
print(df_labevents)
# Out:
#        arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
# 11                            NaN                              NaN
# 12                            NaN                              NaN
# 13                            NaN                              NaN
# 14                            NaN                              NaN
# 15                            NaN                              NaN
# 16                            NaN                              NaN
# 17                            NaN                              NaN
# 18                            NaN                              NaN
# 19                            NaN                              NaN
# 20                            NaN                              NaN
# 21                            NaN                              NaN
# 22                            NaN                              NaN
# 23                            NaN                              NaN
# 24                            NaN                              NaN
# 25                            NaN                              NaN
# 26                            NaN                              NaN
# 27                            NaN                              NaN
# 28                            NaN                              NaN
# 29                            NaN                              NaN
# ...                           ...                              ...
# 279176                        NaN                              NaN
# 279177                        NaN                              NaN
# 279178                        NaN                              NaN
# 279179                        NaN                              NaN
# 279180                        NaN                              NaN
# 279181                        NaN                              NaN
# 279182                        NaN                              NaN
# 279183                        NaN                              NaN
# 279184                        NaN                              NaN
# 279185                        NaN                              NaN
# 279186                        NaN                              NaN
# 279187                        NaN                              NaN
# 279188                        NaN                              NaN
# 279189                        NaN                              NaN
# 279190                        NaN                              NaN
# 279191                        NaN                              NaN
# 279192                        NaN                              NaN
# 279193                        NaN                              NaN
# 279194                        NaN                              NaN
# 279195                        NaN                              NaN
# 279196                        NaN                              NaN
# 279197                        NaN                              NaN
# 279198                        NaN                              NaN
# 279199                        NaN                              NaN
# 279200                        NaN                              NaN
# 279201                        NaN                              NaN
# 279202                        NaN                              NaN
# 279203                        NaN                              NaN
# 279204                        NaN                              NaN
# 279205                        NaN                              NaN
#
#        arterial_pressure_systolic_time arterial_pressure_diastolic  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5                                  NaN                         NaN
# 6                                  NaN                         NaN
# 7                                  NaN                         NaN
# 8                                  NaN                         NaN
# 9                                  NaN                         NaN
# 10                                 NaN                         NaN
# 11                                 NaN                         NaN
# 12                                 NaN                         NaN
# 13                                 NaN                         NaN
# 14                                 NaN                         NaN
# 15                                 NaN                         NaN
# 16                                 NaN                         NaN
# 17                                 NaN                         NaN
# 18                                 NaN                         NaN
# 19                                 NaN                         NaN
# 20                                 NaN                         NaN
# 21                                 NaN                         NaN
# 22                                 NaN                         NaN
# 23                                 NaN                         NaN
# 24                                 NaN                         NaN
# 25                                 NaN                         NaN
# 26                                 NaN                         NaN
# 27                                 NaN                         NaN
# 28                                 NaN                         NaN
# 29                                 NaN                         NaN
# ...                                ...                         ...
# 279176                             NaN                         NaN
# 279177                             NaN                         NaN
# 279178                             NaN                         NaN
# 279179                             NaN                         NaN
# 279180                             NaN                         NaN
# 279181                             NaN                         NaN
# 279182                             NaN                         NaN
# 279183                             NaN                         NaN
# 279184                             NaN                         NaN
# 279185                             NaN                         NaN
# 279186                             NaN                         NaN
# 279187                             NaN                         NaN
# 279188                             NaN                         NaN
# 279189                             NaN                         NaN
# 279190                             NaN                         NaN
# 279191                             NaN                         NaN
# 279192                             NaN                         NaN
# 279193                             NaN                         NaN
# 279194                             NaN                         NaN
# 279195                             NaN                         NaN
# 279196                             NaN                         NaN
# 279197                             NaN                         NaN
# 279198                             NaN                         NaN
# 279199                             NaN                         NaN
# 279200                             NaN                         NaN
# 279201                             NaN                         NaN
# 279202                             NaN                         NaN
# 279203                             NaN                         NaN
# 279204                             NaN                         NaN
# 279205                             NaN                         NaN
#
#        arterial_pressure_diastolic_delay arterial_pressure_diastolic_time  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5                                    NaN                              NaN
# 6                                    NaN                              NaN
# 7                                    NaN                              NaN
# 8                                    NaN                              NaN
# 9                                    NaN                              NaN
# 10                                   NaN                              NaN
# 11                                   NaN                              NaN
# 12                                   NaN                              NaN
# 13                                   NaN                              NaN
# 14                                   NaN                              NaN
# 15                                   NaN                              NaN
# 16                                   NaN                              NaN
# 17                                   NaN                              NaN
# 18                                   NaN                              NaN
# 19                                   NaN                              NaN
# 20                                   NaN                              NaN
# 21                                   NaN                              NaN
# 22                                   NaN                              NaN
# 23                                   NaN                              NaN
# 24                                   NaN                              NaN
# 25                                   NaN                              NaN
# 26                                   NaN                              NaN
# 27                                   NaN                              NaN
# 28                                   NaN                              NaN
# 29                                   NaN                              NaN
# ...                                  ...                              ...
# 279176                               NaN                              NaN
# 279177                               NaN                              NaN
# 279178                               NaN                              NaN
# 279179                               NaN                              NaN
# 279180                               NaN                              NaN
# 279181                               NaN                              NaN
# 279182                               NaN                              NaN
# 279183                               NaN                              NaN
# 279184                               NaN                              NaN
# 279185                               NaN                              NaN
# 279186                               NaN                              NaN
# 279187                               NaN                              NaN
# 279188                               NaN                              NaN
# 279189                               NaN                              NaN
# 279190                               NaN                              NaN
# 279191                               NaN                              NaN
# 279192                               NaN                              NaN
# 279193                               NaN                              NaN
# 279194                               NaN                              NaN
# 279195                               NaN                              NaN
# 279196                               NaN                              NaN
# 279197                               NaN                              NaN
# 279198                               NaN                              NaN
# 279199                               NaN                              NaN
# 279200                               NaN                              NaN
# 279201                               NaN                              NaN
# 279202                               NaN                              NaN
# 279203                               NaN                              NaN
# 279204                               NaN                              NaN
# 279205                               NaN                              NaN
#
#        heart_rate heart_rate_delay heart_rate_time weight_daily  \
# 0             NaN              NaN             NaN          NaN
# 1             NaN              NaN             NaN          NaN
# 2             NaN              NaN             NaN          NaN
# 3             NaN              NaN             NaN          NaN
# 4             NaN              NaN             NaN          NaN
# 5             NaN              NaN             NaN          NaN
# 6             NaN              NaN             NaN          NaN
# 7             NaN              NaN             NaN          NaN
# 8             NaN              NaN             NaN          NaN
# 9             NaN              NaN             NaN          NaN
# 10            NaN              NaN             NaN          NaN
# 11            NaN              NaN             NaN          NaN
# 12            NaN              NaN             NaN          NaN
# 13            NaN              NaN             NaN          NaN
# 14            NaN              NaN             NaN          NaN
# 15            NaN              NaN             NaN          NaN
# 16            NaN              NaN             NaN          NaN
# 17            NaN              NaN             NaN          NaN
# 18            NaN              NaN             NaN          NaN
# 19            NaN              NaN             NaN          NaN
# 20            NaN              NaN             NaN          NaN
# 21            NaN              NaN             NaN          NaN
# 22            NaN              NaN             NaN          NaN
# 23            NaN              NaN             NaN          NaN
# 24            NaN              NaN             NaN          NaN
# 25            NaN              NaN             NaN          NaN
# 26            NaN              NaN             NaN          NaN
# 27            NaN              NaN             NaN          NaN
# 28            NaN              NaN             NaN          NaN
# 29            NaN              NaN             NaN          NaN
# ...           ...              ...             ...          ...
# 279176        NaN              NaN             NaN          NaN
# 279177        NaN              NaN             NaN          NaN
# 279178        NaN              NaN             NaN          NaN
# 279179        NaN              NaN             NaN          NaN
# 279180        NaN              NaN             NaN          NaN
# 279181        NaN              NaN             NaN          NaN
# 279182        NaN              NaN             NaN          NaN
# 279183        NaN              NaN             NaN          NaN
# 279184        NaN              NaN             NaN          NaN
# 279185        NaN              NaN             NaN          NaN
# 279186        NaN              NaN             NaN          NaN
# 279187        NaN              NaN             NaN          NaN
# 279188        NaN              NaN             NaN          NaN
# 279189        NaN              NaN             NaN          NaN
# 279190        NaN              NaN             NaN          NaN
# 279191        NaN              NaN             NaN          NaN
# 279192        NaN              NaN             NaN          NaN
# 279193        NaN              NaN             NaN          NaN
# 279194        NaN              NaN             NaN          NaN
# 279195        NaN              NaN             NaN          NaN
# 279196        NaN              NaN             NaN          NaN
# 279197        NaN              NaN             NaN          NaN
# 279198        NaN              NaN             NaN          NaN
# 279199        NaN              NaN             NaN          NaN
# 279200        NaN              NaN             NaN          NaN
# 279201        NaN              NaN             NaN          NaN
# 279202        NaN              NaN             NaN          NaN
# 279203        NaN              NaN             NaN          NaN
# 279204        NaN              NaN             NaN          NaN
# 279205        NaN              NaN             NaN          NaN
#
#                  ...                  albumin_time total_protein_urine  \
# 0                ...                           NaT                 NaN
# 1                ...           2104-08-13 03:51:00                 NaN
# 2                ...                           NaT                 NaN
# 3                ...           2167-01-08 20:28:00                 NaN
# 4                ...                           NaT                 NaN
# 5                ...           2135-01-31 05:20:00                 NaN
# 6                ...           2108-08-26 02:55:00                 NaN
# 7                ...                           NaT                 NaN
# 8                ...                           NaT                 NaN
# 9                ...           2131-05-17 06:09:00                 NaN
# 10               ...           2131-05-17 06:09:00                 NaN
# 11               ...                           NaT                 NaN
# 12               ...           2166-08-12 01:24:00                 NaN
# 13               ...           2166-08-17 09:16:00                 NaN
# 14               ...           2166-08-23 00:52:00                 NaN
# 15               ...           2166-08-17 09:16:00                 NaN
# 16               ...           2166-08-23 00:52:00                 NaN
# 17               ...           2166-08-23 00:52:00                 NaN
# 18               ...                           NaT                 NaN
# 19               ...           2186-10-02 14:10:00                 NaN
# 20               ...                           NaT                 NaN
# 21               ...                           NaT                 NaN
# 22               ...                           NaT                 NaN
# 23               ...                           NaT                 NaN
# 24               ...           2174-01-10 08:16:00                 NaN
# 25               ...           2174-01-11 03:56:00                 NaN
# 26               ...                           NaT                 NaN
# 27               ...           2164-02-05 05:54:00                 NaN
# 28               ...                           NaT                 NaN
# 29               ...                           NaT                 NaN
# ...              ...                           ...                 ...
# 279176           ...           2116-06-08 01:54:00                 NaN
# 279177           ...           2116-07-01 03:01:00                 NaN
# 279178           ...           2116-06-08 01:54:00                 NaN
# 279179           ...                           NaT                94.0
# 279180           ...                           NaT                94.0
# 279181           ...                           NaT                 NaN
# 279182           ...                           NaT                94.0
# 279183           ...                           NaT                94.0
# 279184           ...                           NaT                 NaN
# 279185           ...           2174-01-20 14:30:00                 NaN
# 279186           ...                           NaT                 NaN
# 279187           ...                           NaT                 NaN
# 279188           ...           2129-07-05 09:00:00                 NaN
# 279189           ...                           NaT                 NaN
# 279190           ...           2129-07-05 09:00:00                 NaN
# 279191           ...                           NaT                 NaN
# 279192           ...                           NaT                 NaN
# 279193           ...                           NaT                 NaN
# 279194           ...           2153-04-17 05:35:00                 NaN
# 279195           ...                           NaT                 NaN
# 279196           ...           2201-05-16 12:45:00                 NaN
# 279197           ...                           NaT                 NaN
# 279198           ...                           NaT                 NaN
# 279199           ...                           NaT                 NaN
# 279200           ...                           NaT                 NaN
# 279201           ...           2156-11-28 15:29:00                 NaN
# 279202           ...                           NaT                 NaN
# 279203           ...           2181-01-30 03:19:00                 NaN
# 279204           ...                           NaT                 NaN
# 279205           ...                           NaT                 NaN
#
#        total_protein_urine_delay total_protein_urine_time bilirubin  \
# 0                            NaN                      NaT       NaN
# 1                            NaN                      NaT       8.2
# 2                            NaN                      NaT       NaN
# 3                            NaN                      NaT       0.4
# 4                            NaN                      NaT       0.4
# 5                            NaN                      NaT       0.2
# 6                            NaN                      NaT       0.6
# 7                            NaN                      NaT       NaN
# 8                            NaN                      NaT       NaN
# 9                            NaN                      NaT       0.4
# 10                           NaN                      NaT       0.4
# 11                           NaN                      NaT       NaN
# 12                           NaN                      NaT       1.1
# 13                           NaN                      NaT       0.8
# 14                           NaN                      NaT       0.8
# 15                           NaN                      NaT       0.8
# 16                           NaN                      NaT       0.8
# 17                           NaN                      NaT       0.8
# 18                           NaN                      NaT       NaN
# 19                           NaN                      NaT       2.6
# 20                           NaN                      NaT       NaN
# 21                           NaN                      NaT       NaN
# 22                           NaN                      NaT       NaN
# 23                           NaN                      NaT       1.9
# 24                           NaN                      NaT       2.1
# 25                           NaN                      NaT       1.8
# 26                           NaN                      NaT       1.0
# 27                           NaN                      NaT       1.3
# 28                           NaN                      NaT       NaN
# 29                           NaN                      NaT       0.2
# ...                          ...                      ...       ...
# 279176                       NaN                      NaT       5.0
# 279177                       NaN                      NaT       1.3
# 279178                       NaN                      NaT       4.5
# 279179                  183060.0      2142-04-05 12:39:00       NaN
# 279180                  736860.0      2142-04-05 12:39:00       NaN
# 279181                       NaN                      NaT       NaN
# 279182                 1254300.0      2142-04-05 12:39:00       0.2
# 279183                  253260.0      2142-04-05 12:39:00       NaN
# 279184                       NaN                      NaT       NaN
# 279185                       NaN                      NaT       0.4
# 279186                       NaN                      NaT       NaN
# 279187                       NaN                      NaT       NaN
# 279188                       NaN                      NaT       0.3
# 279189                       NaN                      NaT       NaN
# 279190                       NaN                      NaT       0.3
# 279191                       NaN                      NaT       NaN
# 279192                       NaN                      NaT       NaN
# 279193                       NaN                      NaT       NaN
# 279194                       NaN                      NaT       0.5
# 279195                       NaN                      NaT       NaN
# 279196                       NaN                      NaT       3.0
# 279197                       NaN                      NaT       0.5
# 279198                       NaN                      NaT       NaN
# 279199                       NaN                      NaT       NaN
# 279200                       NaN                      NaT       NaN
# 279201                       NaN                      NaT       1.4
# 279202                       NaN                      NaT       NaN
# 279203                       NaN                      NaT       0.5
# 279204                       NaN                      NaT       NaN
# 279205                       NaN                      NaT       NaN
#
#        bilirubin_delay      bilirubin_time c_reactive_protein  \
# 0                  NaN                 NaT                NaN
# 1                  0.0 2104-08-13 03:51:00                NaN
# 2                  NaN                 NaT                NaN
# 3              74460.0 2167-01-08 20:28:00                NaN
# 4             170640.0 2134-09-12 04:30:00                NaN
# 5                  0.0 2135-02-01 02:59:00                NaN
# 6                  0.0 2108-08-26 02:55:00                NaN
# 7                  NaN                 NaT                NaN
# 8                  NaN                 NaT                NaN
# 9             245460.0 2131-05-17 06:09:00                NaN
# 10                 0.0 2131-05-17 06:09:00                NaN
# 11                 NaN                 NaT                NaN
# 12             36360.0 2166-08-12 01:24:00                NaN
# 13            176820.0 2166-08-16 01:39:00                NaN
# 14            601980.0 2166-08-16 01:39:00                NaN
# 15            258900.0 2166-08-16 01:39:00                NaN
# 16           1207680.0 2166-08-16 01:39:00                NaN
# 279186                      NaN                     NaT
# 279187                      NaN                     NaT
# 279188                      NaN                     NaT
# 279189                      NaN                     NaT
# 279190                      NaN                     NaT
# 279191                      NaN                     NaT
# 279192                      NaN                     NaT
# 279193                      NaN                     NaT
# 279194                      NaN                     NaT
# 279195                      NaN                     NaT
# 279196                      NaN                     NaT
# 279197                      NaN                     NaT
# 279198                      NaN                     NaT
# 279199                      NaN                     NaT
# 279200                      NaN                     NaT
# 279201                      NaN                     NaT
# 279202                      NaN                     NaT
# 279203                      NaN                     NaT
# 279204                      NaN                     NaT
# 279205                      NaN                     NaT
#
# [279206 rows x 117 columns]

# %% [markdown]
# # Retrieve missing static information

# %%
# Creatinine measurements, AKI flags + stage for all stays
# Inclusion flags :
# patient age > 15
# length of stay > 48hours
query = query_schema + """
with cr as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    le.valuenum as creatinine, le.charttime as creatinine_time,
    adm.ethnicity, adm.diagnosis,
    pat.gender as gender,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt
  from icustays icu
  inner join labevents le
    on icu.subject_id = le.subject_id
    and le.itemid = 50912
    and le.valuenum is not null
    and le.charttime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  inner join admissions adm
    on icu.subject_id = adm.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
)
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.ethnicity, cr.diagnosis,
    cr.gender,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt
  from cr
"""
df_static = pd.read_sql_query(query, con)
print(df_static.head())
df_static = apply_inclusion_criteria(df_static)
print(df_static.head())
# Out:
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0           4      294638 2191-03-16 00:29:31 2191-03-17 16:46:31         0.5
# 1           4      294638 2191-03-16 00:29:31 2191-03-17 16:46:31         0.4
# 2           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54        10.0
# 3           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         7.4
# 4           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         6.2
#
#       creatinine_time ethnicity                            diagnosis gender  \
# 0 2191-03-16 05:42:00     WHITE  FEVER,DEHYDRATION,FAILURE TO THRIVE      F
# 1 2191-03-17 06:00:00     WHITE  FEVER,DEHYDRATION,FAILURE TO THRIVE      F
# 2 2175-05-31 01:48:00     WHITE            CHRONIC RENAL FAILURE/SDA      F
# 3 2175-06-01 03:00:00     WHITE            CHRONIC RENAL FAILURE/SDA      F
# 4 2175-06-02 02:06:00     WHITE            CHRONIC RENAL FAILURE/SDA      F
#
#          age  inclusion_age  length_of_stay  inclusion_length_of_stay    rrt  \
# 0  47.845047              1       40.283333                         0  False
# 1  47.845047              1       40.283333                         0  False
# 2  65.942297              1       88.150000                         1  False
# 3  65.942297              1       88.150000                         1  False
# 4  65.942297              1       88.150000                         1  False
#
#    inclusion_rrt
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# Initial size of table : 658558
# After dropping duplicates : 326653
# After applying inclusion criteria : 279205
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 2           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54        10.0
# 3           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         7.4
# 4           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         6.2
# 5           6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54         5.1
# 6           9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14         1.4
#
#       creatinine_time              ethnicity                  diagnosis  \
# 2 2175-05-31 01:48:00                  WHITE  CHRONIC RENAL FAILURE/SDA
# 3 2175-06-01 03:00:00                  WHITE  CHRONIC RENAL FAILURE/SDA
# 4 2175-06-02 02:06:00                  WHITE  CHRONIC RENAL FAILURE/SDA
# 5 2175-06-03 00:58:00                  WHITE  CHRONIC RENAL FAILURE/SDA
# 6 2149-11-10 03:00:00  UNKNOWN/NOT SPECIFIED            HEMORRHAGIC CVA
#
#   gender        age  length_of_stay    rrt
# 2      F  65.942297       88.150000  False
# 3      F  65.942297       88.150000  False
# 4      F  65.942297       88.150000  False
# 5      F  65.942297       88.150000  False
# 6      M  41.790228      127.753333  False

# %%
# REMOVE COLUMNS THAT WERE USED FOR INCLUSION CRITERIA BUT THAT ARE NOT AVAILABLE FEATURES FOR THE PREDICTION
# REMOVE ICUSTAY_IDS FOR WHICH THERE IS ONLY ONE MEASUREMENT OF CREATININE

#print('Number of lines : ' + str(df.shape[0]))
#to_remove = ['intime','outtime','length_of_stay','rrt']
#for c in to_remove:
#    if (c in df.columns.values): df = df.drop(c,axis=1)

# Remove icustay_ids for which there's only one measurement of creatinine
#count_mes = df['icustay_id'].value_counts()
#to_remove = count_mes.index.values[count_mes==1]
#for i in to_remove:
#    df = df.loc[df['icustay_id']!=i,:]

#print('After dropping unique measurements of creatinine : ' + str(df.shape[0]))
#print(df.head())

# %%
# Dump to file
df_static.to_csv('creatinine_measurements_2.csv')
print(df_static)
# Out:
#         subject_id  icustay_id              intime             outtime  \
# 2                6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54
# 3                6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54
# 4                6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54
# 5                6      228232 2175-05-30 21:30:54 2175-06-03 13:39:54
# 6                9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 9                9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 10               9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 11               9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 12               9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 13               9      220597 2149-11-09 13:07:02 2149-11-14 20:52:14
# 14              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 15              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 16              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 17              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 18              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 19              13      263738 2167-01-08 18:44:25 2167-01-12 10:43:31
# 24              17      277042 2134-12-27 16:21:48 2134-12-29 18:04:03
# 26              17      277042 2134-12-27 16:21:48 2134-12-29 18:04:03
# 28              17      277042 2134-12-27 16:21:48 2134-12-29 18:04:03
# 31              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 33              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 35              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 38              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 40              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 42              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 44              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 46              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 48              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:32
# 50              21      217847 2134-09-11 20:50:04 2134-09-17 18:28:
#         length_of_stay    rrt
# 2            88.150000  False
# 3            88.150000  False
# 4            88.150000  False
# 5            88.150000  False
# 6           127.753333  False
# 9           127.753333  False
# 10          127.753333  False
# 11          127.753333  False
# 12          127.753333  False
# 13          127.753333  False
# 14           87.985000  False
# 15           87.985000  False
# 16           87.985000  False
# 17           87.985000  False
# 18           87.985000  False
# 19           87.985000  False
# 24           49.704167  False
# 26           49.704167  False
# 28           49.704167  False
# 31          141.641111  False
# 33          141.641111  False
# 35          141.641111  False
# 38          141.641111  False
# 40          141.641111  False
# 42          141.641111  False
# 44          141.641111  False
# 46          141.641111  False
# 48          141.641111  False
# 50          141.641111  False
# 52          141.641111  False
# ...                ...    ...
# 658512      111.209444  False
# 658516      340.203333  False
# 658517      340.203333  False
# 658518      221.427222  False
# 658520       65.215556  False
# 658522      642.776111  False
# 658523      642.776111  False
# 658524       73.967222  False
# 658526       73.967222  False
# 658530      346.394722  False
# 658531      346.394722  False
# 658532      346.394722  False
# 658533      346.394722  False
# 658534      310.440833  False
# 658535      310.440833  False
# 658536      486.535556  False
# 658538      346.394722  False
# 658539       51.387222  False
# 658540       51.387222  False
# 658541      546.977222  False
# 658542      546.977222  False
# 658543       62.162778  False
# 658547       62.162778  False
# 658551      766.601667  False
# 658552      766.601667  False
# 658553      766.601667  False
# 658554      766.601667  False
# 658555      766.601667  False
# 658556      766.601667  False
# 658557      115.296944  False
#
# [279205 rows x 12 columns]

# %% [markdown]
# # Merge tables into one

# %%
print('Labevents :')
print(df_labevents.shape)
print(df_labevents.columns.values)
print('')

print('Static:')
print(df_static.shape)
print(df_static.columns.values)
# Out:
# Labevents :
# (279206, 117)
# ['arterial_pressure_systolic' 'arterial_pressure_systolic_delay'
#  'arterial_pressure_systolic_time' 'arterial_pressure_diastolic'
#  'arterial_pressure_diastolic_delay' 'arterial_pressure_diastolic_time'
#  'heart_rate' 'heart_rate_delay' 'heart_rate_time' 'weight_daily'
#  'weight_daily_delay' 'weight_daily_time' 'temperature' 'temperature_delay'
#  'temperature_time' 'urine_output' 'urine_output_delay' 'urine_output_time'
#  'day_urine_output' 'day_urine_output_delay' 'day_urine_output_time'
#  'subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'age' 'length_of_stay' 'rrt' 'scr' 'scr_delay'
#  'scr_time' 'urea' 'urea_delay' 'urea_time' 'sodium' 'sodium_delay'
#  'sodium_time' 'potassium' 'potassium_delay' 'potassium_time' 'calcium'
#  'calcium_delay' 'calcium_time' 'phosphor' 'phosphor_delay' 'phosphor_time'
#  'leukocytes' 'leukocytes_delay' 'leukocytes_time' 'hemoglobine'
#  'hemoglobine_delay' 'hemoglobine_time' 'bicarbonate' 'bicarbonate_delay'
#  'bicarbonate_time' 'lactate' 'lactate_delay' 'lactate_time' 'uric_acid'
#  'uric_acid_delay' 'uric_acid_time' 'chloride' 'chloride_delay'
#  'chloride_time' 'neutrophils' 'neutrophils_delay' 'neutrophils_time'
#  'lymphocytes' 'lymphocytes_delay' 'lymphocytes_time' 'platelet_count'
#  'platelet_count_delay' 'platelet_count_time' 'ph_blood' 'ph_blood_delay'
#  'ph_blood_time' 'ph_urine' 'ph_urine_delay' 'ph_urine_time' 'monocytes'
#  'monocytes_delay' 'monocytes_time' 'fibrinogen' 'fibrinogen_delay'
#  'fibrinogen_time' 'urinary_sodium' 'urinary_sodium_delay'
#  'urinary_sodium_time' 'urinary_potassium' 'urinary_potassium_delay'
#  'urinary_potassium_time' 'urine_urea' 'urine_urea_delay' 'urine_urea_time'
#  'urine_creatinin' 'urine_creatinin_delay' 'urine_creatinin_time'
#  'alkaline_phospatase' 'alkaline_phospatase_delay'
#  'alkaline_phospatase_time' 'total_protein_blood'
#  'total_protein_blood_delay' 'total_protein_blood_time' 'albumin'
#  'albumin_delay' 'albumin_time' 'total_protein_urine'
#  'total_protein_urine_delay' 'total_protein_urine_time' 'bilirubin'
#  'bilirubin_delay' 'bilirubin_time' 'c_reactive_protein'
#  'c_reactive_protein_delay' 'c_reactive_protein_time']
#
# Static:
# (279205, 12)
# ['subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'ethnicity' 'diagnosis' 'gender' 'age' 'length_of_stay'
#  'rrt']

# %%
merged_df = pd.merge(df_labevents,df_static,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt'],how='outer')

# %% [markdown]
# # Remove columns that are not features (except icustay_id and patient_id that are needed to build the table with labels)

# %%
# REMOVE COLUMNS THAT WERE USED FOR INCLUSION CRITERIA BUT THAT ARE NOT AVAILABLE FEATURES FOR THE PREDICTION
# REMOVE ICUSTAY_IDS FOR WHICH THERE IS ONLY ONE MEASUREMENT OF CREATININE

print('Number of lines : ' + str(merged_df.shape[0]))
to_remove = ['intime','outtime','length_of_stay','rrt']
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)
        
# Remove columns with _time suffix
to_remove = [i for i in merged_df.columns.values if '_time' in i]
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)

# Remove icustay_ids for which there's only one measurement of creatinine
count_mes = merged_df['icustay_id'].value_counts()
to_remove = count_mes.index.values[count_mes==1]
for i in to_remove:
    merged_df = merged_df.loc[merged_df['icustay_id']!=i,:]

print('After dropping unique measurements of creatinine : ' + str(merged_df.shape[0]))
merged_df.head()
# Out:
# Number of lines : 279036
# After dropping unique measurements of creatinine : 279036
#   arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#   arterial_pressure_diastolic arterial_pressure_diastolic_delay heart_rate  \
# 0                         NaN                               NaN        NaN
# 1                         NaN                               NaN        NaN
# 2                         NaN                               NaN        NaN
# 3                         NaN                               NaN        NaN
# 4                         NaN                               NaN        NaN
#
#   heart_rate_delay weight_daily weight_daily_delay temperature  \
# 0              NaN          NaN                NaN         NaN
# 1              NaN          NaN                NaN         NaN
# 2              NaN          NaN                NaN         NaN
# 3              NaN          NaN                NaN         NaN
# 4              NaN          NaN                NaN         NaN
#
#   temperature_delay   ...   albumin_delay total_protein_urine  \
# 0               NaN   ...             NaN                 NaN
# 1               NaN   ...             0.0                 NaN
# 2               NaN   ...             NaN                 NaN
# 3               NaN   ...         74460.0                 NaN
# 4               NaN   ...             NaN                 NaN
#
#   total_protein_urine_delay bilirubin  bilirubin_delay  c_reactive_protein  \
# 0                       NaN       NaN              NaN                 NaN
# 1                       NaN       8.2              0.0                 NaN
# 2                       NaN       NaN              NaN                 NaN
# 3                       NaN       0.4          74460.0                 NaN
# 4                       NaN       0.4         170640.0                 NaN
#
#    c_reactive_protein_delay  ethnicity                diagnosis  gender
# 0                       NaN      WHITE              HYPOTENSION       M
# 1                       NaN      WHITE    PANCREATIC CANCER/SDA       M
# 2                       NaN      WHITE    PANCREATIC CANCER/SDA       M
# 3                       NaN      WHITE  CORONARY ARTERY DISEASE       F
# 4                       NaN      WHITE                   SEPSIS       M
#
# [5 rows x 79 columns]

# %%
# Dump to file
merged_df.to_csv('creatinine_measurements_merged.csv')
print(merged_df)
# Out:
#        arterial_pressure_systolic arterial_pressure_systolic_delay  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
# 11                            NaN                              NaN
# 12                            NaN                              NaN
# 13                            NaN                              NaN
# 14                            NaN                              NaN
# 15                            NaN                              NaN
# 16                            NaN                              NaN
# 17                            NaN                              NaN
# 18                            NaN                              NaN
# 19                            NaN                              NaN
# 20                            NaN                              NaN
# 21                            NaN                              NaN
# 22                            NaN                              NaN
# 23                            NaN                              NaN
# 24                            NaN                              NaN
# 25                            NaN                              NaN
# 26                            NaN                              NaN
# 27                            NaN                              NaN
# 28                            NaN                              NaN
# 29                            NaN                              NaN
# ...                           ...                              ...
# 279176                        NaN                              NaN
# 279177                        NaN                              NaN
# 279178                        NaN                              NaN
# 279179                        NaN                              NaN
# 279180                        NaN                              NaN
# 279181                        NaN                              NaN
# 279182                        NaN                              NaN
# 279183                        NaN                              NaN
# 279184                        NaN                              NaN
# 279185                        NaN                              NaN
# 279186                        NaN                              NaN
# 279187                        NaN                              NaN
# 279188                        NaN                              NaN
# 279189                        NaN                              NaN
# 279190                        NaN                              NaN
# 279191                        NaN                              NaN
# 279192                        NaN                              NaN
# 279193                        NaN                              NaN
# 279194                        NaN                              NaN
# 279195                        NaN                              NaN
# 279196                        NaN                              NaN
# 279197                        NaN                              NaN
# 279198                        NaN                              NaN
# 279199                        NaN                              NaN
# 279200                        NaN                              NaN
# 279201                        NaN                              NaN
# 279202                        NaN                              NaN
# 279203                        NaN                              NaN
# 279204                        NaN                              NaN
# 279205                        NaN                              NaN
#
#        arterial_pressure_diastolic arterial_pressure_diastolic_delay  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# 5                              NaN                               NaN
# 6                              NaN                               NaN
# 7                              NaN                               NaN
# 8                              NaN                               NaN
# 9                              NaN                               NaN
# 10                             NaN                               NaN
# 11                             NaN                               NaN
# 12                             NaN                               NaN
# 13                             NaN                               NaN
# 14                             NaN                               NaN
# 15                             NaN                               NaN
# 16                             NaN                               NaN
# 17                             NaN                               NaN
# 18                             NaN                               NaN
# 19                             NaN                               NaN
# 20                             NaN                               NaN
# 21                             NaN                               NaN
# 22                             NaN                               NaN
# 23                             NaN                               NaN
# 24                             NaN                               NaN
# 25                             NaN                               NaN
# 26                             NaN                               NaN
# 27                             NaN                               NaN
# 279196        NaN              NaN          NaN                NaN
# 279197        NaN              NaN          NaN                NaN
# 279198        NaN              NaN          NaN                NaN
# 279199        NaN              NaN          NaN                NaN
# 279200        NaN              NaN          NaN                NaN
# 279201        NaN              NaN          NaN                NaN
# 279202        NaN              NaN          NaN                NaN
# 279203        NaN              NaN          NaN                NaN
# 279204        NaN              NaN          NaN                NaN
# 279205        NaN              NaN          NaN                NaN
#
#        temperature temperature_delay   ...   albumin_delay  \
# 0              NaN               NaN   ...             NaN
# 1              NaN               NaN   ...             0.0
# 2              NaN               NaN   ...             NaN
# 3              NaN               NaN   ...         74460.0
# 4              NaN               NaN   ...             NaN
# 5              NaN               NaN   ...         77940.0
# 6              NaN               NaN   ...             0.0
# 7              NaN               NaN   ...             NaN
# 8              NaN               NaN   ...             NaN
# 9              NaN               NaN   ...        245460.0
# 10             NaN               NaN   ...             0.0
# 11             NaN               NaN   ...             NaN
# 12             NaN               NaN   ...         36360.0
# 13             NaN               NaN   ...         63000.0
# 14             NaN               NaN   ...             0.0
# 15             NaN               NaN   ...        145080.0
# 16             NaN               NaN   ...        605700.0
# 17             NaN               NaN   ...         84720.0
# 18             NaN               NaN   ...             NaN
# 19             NaN               NaN   ...        129660.0
# 20             NaN               NaN   ...             NaN
# 21             NaN               NaN   ...             NaN
# 22             NaN               NaN   ...             NaN
# 23             NaN               NaN   ...             NaN
# 24             NaN               NaN   ...         55860.0
# 25             NaN               NaN   ...        261060.0
# 26             NaN               NaN   ...             NaN
# 27             NaN               NaN   ...             0.0
# 28             NaN               NaN   ...             NaN
# 29             NaN               NaN   ...             NaN
# ...            ...               ...   ...             ...
# 279176         NaN               NaN   ...        256860.0
# 279177         NaN               NaN   ...        774960.0
# 279178         NaN               NaN   ...        228780.0
# 279179         NaN               NaN   ...             NaN
# 279180         NaN               NaN   ...             NaN
# 279181         NaN               NaN   ...             NaN
# 279182         NaN               NaN   ...             NaN
# 279183         NaN               NaN   ...             NaN
# 279184         NaN               NaN   ...             NaN
# 279185         NaN               NaN   ...         73440.0
# 279186         NaN               NaN   ...             NaN
# 279187         NaN               NaN   ...             NaN
# 279188         NaN               NaN   ...             0.0
# 279189         NaN               NaN   ...             NaN
# 279190         NaN               NaN   ...         18960.0
# 279191         NaN               NaN   ...             NaN
# 279192         NaN               NaN   ...             NaN
# 279193         NaN               NaN   ...             NaN
# 279194         NaN               NaN   ...        511800.0
# 279195         NaN               NaN   ...             NaN
# 279196         NaN               NaN   ...             0.0
# 279197         NaN               NaN   ...             NaN
# 279198         NaN               NaN   ...             NaN
# 279199         NaN               NaN   ...             NaN
# 279200         NaN               NaN   ...             NaN
# 279201         NaN               NaN   ...        648660.0
# 279202         NaN               NaN   ...             NaN
# 279203         NaN               NaN   ...        651240.0
# 279204         NaN               NaN   ...             NaN
# 279205         NaN               NaN   ...             NaN
#
#        total_protein_urine total_protein_urine_delay bilirubin  \
# 0                      NaN                       NaN       NaN
# 1                      NaN                       NaN       8.2
# 2                      NaN                       NaN       NaN
# 3                      NaN                       NaN       0.4
# 4                      NaN                       NaN       0.4
# 5                      NaN                       NaN       0.2
# 6                      NaN                       NaN       0.6
# 7                      NaN                       NaN       NaN
# 8                      NaN                       NaN       NaN
# 9                      NaN                       NaN       0.4
# 10                     NaN                       NaN       0.4
# 11                     NaN                       NaN       NaN
# 12                     NaN                       NaN       1.1
# 13                     NaN                       NaN       0.8
# 14                     NaN                       NaN       0.8
# 15                     NaN                       NaN       0.8
# 16                     NaN                       NaN       0.8
# 17                     NaN                       NaN       0.8
# 18                     NaN                       NaN       NaN
# 19                     NaN                       NaN       2.6
# 20                     NaN                       NaN       NaN
# 21                     NaN                       NaN       NaN
# 22                     NaN                       NaN       NaN
# 23                     NaN                       NaN       1.9
# 24                     NaN                       NaN       2.1
# 25                     NaN                       NaN       1.8
# 26                     NaN                       NaN       1.0
# 27                     NaN                       NaN       1.3
# 28                     NaN                       NaN       NaN
# 29                     NaN                       NaN       0.2
# ...                    ...                       ...       ...
# 279176                 NaN                       NaN       5.0
# 279177                 NaN                       NaN       1.3
# 279178                 NaN                       NaN       4.5
# 279179                94.0                  183060.0       NaN
# 279180                94.0                  736860.0       NaN
# 279181                 NaN                       NaN       NaN
# 279182                94.0                 1254300.0       0.2
# 279183                94.0                  253260.0       NaN
# 279184                 NaN                       NaN       NaN
# 279185                 NaN                       NaN       0.4
# 279186                 NaN                       NaN       NaN
# 279187                 NaN                       NaN       NaN
# 279188                 NaN                       NaN       0.3
# 279189                 NaN                       NaN       NaN
# 279190                 NaN                       NaN       0.3
# 279191                 NaN                       NaN       NaN
# 279192                 NaN                       NaN       NaN
# 279193                 NaN                       NaN       NaN
# 279194                 NaN                       NaN       0.5
# 279195                 NaN                       NaN       NaN
# 279196                 NaN                       NaN       3.0
# 279197                 NaN                       NaN       0.5
# 279198                 NaN                       NaN       NaN
# 279199                 NaN                       NaN       NaN
# 279200                 NaN                       NaN       NaN
# 279201                 NaN                       NaN       1.4
# 279202                 NaN                       NaN       NaN
# 279203                 NaN                       NaN       0.5
# 279204                 NaN                       NaN       NaN
# 279205                 NaN                       NaN       NaN
#
#         bilirubin_delay  c_reactive_protein  c_reactive_protein_delay  \
# 0                   NaN                 NaN                       NaN
# 1                   0.0                 NaN                       NaN
# 2                   NaN                 NaN                       NaN
# 3               74460.0                 NaN                       NaN
# 4              170640.0                 NaN                       NaN
# 5                   0.0                 NaN                       NaN
# 6                   0.0                 NaN                       NaN
# 7                   NaN                 NaN                       NaN
# 8                   NaN                 NaN                       NaN
# 9              245460.0                 NaN                       NaN
# 10                  0.0                 NaN                       NaN
# 11                  NaN                 NaN                       NaN
# 12              36360.0                 NaN                       NaN
# 13             176820.0                 NaN                       NaN
# 14             601980.0                 NaN                       NaN
# 15             258900.0                 NaN                       NaN
# 16            1207680.0                 NaN                       NaN
# 17             686700.0                 NaN                       NaN
# 18                  NaN                 NaN                       NaN
# 19             129660.0                 NaN                       NaN
# 20                  NaN                 NaN                       NaN
# 21                  NaN                 NaN                       NaN
# 22                  NaN                 NaN                       NaN
# 23                  0.0                 NaN                       NaN
# 24                  0.0                 NaN                       NaN
# 25              87360.0                 NaN                       NaN
# 26              34920.0                 NaN                       NaN
# 27                  0.0                 NaN                       NaN
# 28                  NaN                 NaN                       NaN
# 29              72000.0                 NaN                       NaN
# ...                 ...                 ...                       ...
# 279176              0.0                 NaN                       NaN
# 279177         172380.0                 NaN                       NaN
# 279178          61620.0                 NaN                       NaN
# 279179              NaN                 NaN                       NaN
# 279180              NaN                 NaN                       NaN
# 279181              NaN                 NaN                       NaN
# 279182          86640.0                 NaN                       NaN
# 279183              NaN                 NaN                       NaN
# 279184              NaN                 NaN                       NaN
# 279185          73440.0                 NaN                       NaN
# 279186              NaN                 NaN                       NaN
# 279187              NaN                 NaN                       NaN
# 279188              0.0                 NaN                       NaN
# 279189              NaN                 NaN                       NaN
# 279190          18960.0                 NaN                       NaN
# 279191              NaN                 NaN                       NaN
# 279192              NaN                 NaN                       NaN
# 279193              NaN                 NaN                       NaN
# 279194         511800.0                 NaN                       NaN
# 279195              NaN                 NaN                       NaN
# 279196              0.0                 NaN                       NaN
# 279197         191280.0                 NaN                       NaN
# 279198              NaN                 NaN                       NaN
# 279199              NaN                 NaN                       NaN
# 279200              NaN                 NaN                       NaN
# 279201         611460.0                 NaN                       NaN
# 279202              NaN                 NaN                       NaN
# 279203          47280.0                 NaN                       NaN
# 279204              NaN                 NaN                       NaN
# 279205              NaN                 NaN                       NaN
#
#                           ethnicity  \
# 0                             WHITE
# 1                             WHITE
# 2                             WHITE
# 3                             WHITE
# 4                             WHITE
# 5                             WHITE
# 6                             WHITE
# 7                             WHITE
# 8                             WHITE
# 9                             WHITE
# 10                            WHITE
# 11                            WHITE
# 12                            WHITE
# 13                            WHITE
# 14                            WHITE
# 15                            WHITE
# 16                            WHITE
# 17                            WHITE
# 18                            WHITE
# 19                            WHITE
# 20                            WHITE
# 21       PATIENT DECLINED TO ANSWER
# 22       PATIENT DECLINED TO ANSWER
# 23           BLACK/AFRICAN AMERICAN
# 24           BLACK/AFRICAN AMERICAN
# 25           BLACK/AFRICAN AMERICAN
# 26           BLACK/AFRICAN AMERICAN
# 27                            ASIAN
# 28                            ASIAN
# 29                            WHITE
# ...                             ...
# 279176             UNABLE TO OBTAIN
# 279177             UNABLE TO OBTAIN
# 279178             UNABLE TO OBTAIN
# 279179            WHITE - BRAZILIAN
# 279180            WHITE - BRAZILIAN
# 279181            WHITE - BRAZILIAN
# 279182            WHITE - BRAZILIAN
# 279183            WHITE - BRAZILIAN
# 279184                        WHITE
# 279185                        WHITE
# 279186                        WHITE
# 279187                        WHITE
# 279188                        WHITE
# 279189                        WHITE
# 279190                        WHITE
# 279191       BLACK/AFRICAN AMERICAN
# 279192                        WHITE
# 279193                        WHITE
# 279194                        WHITE
# 279195  HISPANIC/LATINO - DOMINICAN
# 279196                        WHITE
# 279197                        WHITE
# 279198                        WHITE
# 279199                        WHITE
# 279200                        WHITE
# 279201                        WHITE
# 279202                        WHITE
# 279203                        WHITE
# 279204                        WHITE
# 279205        UNKNOWN/NOT SPECIFIED
#
#                                                 diagnosis  gender
# 0                                             HYPOTENSION       M
# 1                                   PANCREATIC CANCER/SDA       M
# 2                                   PANCREATIC CANCER/SDA       M
# 3                                 CORONARY ARTERY DISEASE       F
# 4                                                  SEPSIS       M
# 5                                                  SEPSIS       M
# 6                                      STATUS EPILEPTICUS       M
# 7                                   TRACHEAL STENOSIS/SDA       M
# 8       AORTIC VALVE DISEASE\CORONARY ARTERY BYPASS GR...       F
# 9                                      VENTRAL HERNIA/SDA       M
# 10                                     VENTRAL HERNIA/SDA       M
# 11                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 12                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 13                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 14                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 15                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 16                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 17                     ACUTE MYOCARDIAL INFARCTION-SEPSIS       M
# 18                            RIGHT BRAIN STEM LESION/SDA       M
# 19                                           T12 FRACTURE       M
# 20                     HYPOGLYCEMIA;HYPOTENSION;TELEMETRY       F
# 21                         SEPSIS,URINARY TRACT INFECTION       M
# 22                         SEPSIS,URINARY TRACT INFECTION       M
# 23                                      FUNGAL MENINGITIS       F
# 24                                               WEAKNESS       F
# 25                                               WEAKNESS       F
# 26                                               WEAKNESS       F
# 27                                               OVERDOSE       F
# 28                                               OVERDOSE       F
# 29                            ACUTE MYOCARDIAL INFARCTION       F
# ...                                                   ...     ...
# 279176                                          HEPATITIS       F
# 279177                                          HEPATITIS       F
# 279178                                          HEPATITIS       F
# 279179         STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK       M
# 279180         STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK       M
# 279181         STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK       M
# 279182         STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK       M
# 279183         STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK       M
# 279184  RULE OTU CORONARY ARTERY DISEASE; SEVERE MITRA...       M
# 279185                          CHRONIC OBST PULM DISEASE       M
# 279186  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...       M
# 279187                           CONGESTIVE HEART FAILURE       M
# 279188                                     LOWER GI BLEED       F
# 279189                                     LOWER GI BLEED       F
# 279190                                     LOWER GI BLEED       F
# 279191                                             12-AQV       M
# 279192               CONGESTIVE HEART FAILURE;HYPOTENSION       M
# 279193               CONGESTIVE HEART FAILURE;HYPOTENSION       M
# 279194                                          PNEUMONIA       M
# 279195                            CORONARY ARTERY DISEASE       M
# 279196                            END STAGE LIVER DISEASE       M
# 279197                                  SYNCOPE;TELEMETRY       F
# 279198                                             SEPSIS       F
# 279199                        BIVENTRICULAR HEART FAILURE       M
# 279200                        BIVENTRICULAR HEART FAILURE       M
# 279201                        BIVENTRICULAR HEART FAILURE       M
# 279202                        BIVENTRICULAR HEART FAILURE       M
# 279203                                              FEVER       M
# 279204                                 DIVERTICULITIS/SDA       M
# 279205                                             S/P MI       F
#
# [279036 rows x 79 columns]
