# %% [markdown]
# # Build the dataset from the SQL database and dump it into a CSV file

# %% [markdown]
# ## 0. Useful imports

# %%
# Import libraries
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2

# below imports are used to print out pretty pandas dataframes
from IPython.display import display, HTML

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ## 1. Connection to postgresql

# %%
# information used to create a database connection
sqluser = 'postgres'
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to postgres with a copy of the MIMIC-III database
con = psycopg2.connect(dbname=dbname, user=sqluser)

# the below statement is prepended to queries to ensure they select from the right schema
query_schema = 'set search_path to ' + schema_name + ';'

# %% [markdown]
# ## 2. Utils functions
# The function below allows to apply the inclusion criteria after the SQL query is done :
# - The dataframe df obtained from the SQL query, contains some columns that are named "inclusion_...". These are boolean variables that take value `True` if the patient matches the criteria and should be included in the dataset.
# - This function drops patients with any "inclusion\_..." set to `False` and then drops all the "inclusion\_..." variables because these are not useful features for the prediction

# %%
def apply_inclusion_criteria(df):
    print('Initial size of table : ' + str(df.shape[0]))
    df = df.drop_duplicates(['icustay_id','creatinine_time'])
    print('After dropping duplicates : ' + str(df.shape[0]))
    criteria_list = [i for i in df.columns.values if 'inclusion' in i]
    for c in criteria_list:
        df = df.loc[df[c]==1,:].drop(c,axis=1)    
    print('After applying inclusion criteria : ' + str(df.shape[0]))
    return df

# %% [markdown]
# ## 3. Load file features_info.csv describing features to be found in chartevents table
# - This table describes the list of item_id that should be used to retrieve a given variable in the chartevents table
# - The list of item_id has been derived from the [d_items table](https://mimic.physionet.org/mimictables/d_items/)

# %%
# Read file
features_info = pd.read_csv('features_info.csv')
# Drop lines with no item_id
item_col = [c for c in features_info.columns.values if "item" in c]
features_info = features_info.dropna(axis=0, how='all', subset=item_col).reset_index(drop=True)
features_info.head()
# Out:
#                           name        table  variable   item_id  item_id_2  \
# 0   Arterial_pressure_systolic  chartevents  valuenum       6.0       51.0
# 1  Arterial_pressure_diastolic  chartevents  valuenum    8364.0     8368.0
# 2                   Heart_rate  chartevents  valuenum     211.0   220045.0
# 3                 Weight_daily  chartevents  valuenum     763.0   224639.0
# 4                  Temperature  chartevents  valuenum  223761.0      678.0
#
#    item_id_3  item_id_4  item_id_5  item_id_6
# 0      455.0   220050.0   220179.0   225309.0
# 1     8441.0   220051.0   220180.0   225310.0
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4      645.0        NaN        NaN        NaN

# %% [markdown]
# ## 4. Retrieve interesting features for patients that match inclusion criteria
# Exclusion criteria :
# - Patients with age < 15 years
# - Patients who stayed less than 48 hours in the ICU
# - Patients under renal replacement therapy
# - Patients suffering from ESDR
# - Patients that had a kidney transplant

# %%
# From features_info, retrieve the list of item_id to use with chartevents
item_col = [c for c in features_info.columns.values if "item_id" in c]
item_list = features_info.loc[0,item_col].dropna().astype('int').values
item_str = "(" + str(item_list[0])
for it in item_list[1:]:
    item_str = item_str + "," + str(it)
item_str = item_str + ")"

# List of ICD-9 codes to be excluded
icd_list = ['5856','V420','99681'] # ESRD: 5856 / kidney transplant: V420,99681
icd_str = "'{" + str(icd_list[0])
for icd in icd_list[1:]:
    icd_str = icd_str + "," + str(icd)
icd_str = icd_str + "}'"
print(icd_str)

query = query_schema + """
with cr1 as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    ce.valuenum as creatinine, ce.storetime as creatinine_time,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt,
    diag.icd9_code as diagnosis 
  from icustays icu
  inner join chartevents ce
    on icu.subject_id = ce.subject_id
    and ce.itemid = 220615
    and ce.valuenum is not null
    and ce.storetime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
  inner join diagnoses_icd diag
    on icu.subject_id = diag.subject_id
    and icu.hadm_id = diag.hadm_id
),
cr as
(
select
cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime,
cr1.creatinine, cr1.creatinine_time,
cr1.age,
cr1.length_of_stay,
cr1.rrt,
array_agg(cr1.diagnosis) as diagnoses
from cr1
group by cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime, cr1.creatinine, cr1.creatinine_time, cr1.age,
cr1.length_of_stay,cr1.rrt
),
cr_inc as
(
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt,
  cr.diagnoses, CASE
            WHEN cr.diagnoses && """ + icd_str + """ then 0
          ELSE 1 END
          as inclusion_diagnoses
  from cr
),
cr_feat as
(
select
cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
    cr_inc.creatinine, cr_inc.creatinine_time,
    cr_inc.age, cr_inc.inclusion_age,
    cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
    cr_inc.rrt, cr_inc.inclusion_rrt, cr_inc.diagnoses, cr_inc.inclusion_diagnoses,
    ce.valuenum as """+features_info.loc[0,'name']+""", 
    EXTRACT('epoch' from cr_inc.creatinine_time - ce.storetime) as """+features_info.loc[0,'name']+"""_delay,
    ce.storetime as """+features_info.loc[0,'name']+"""_time,
    ce.itemid as """+features_info.loc[0,'name']+"""_itemid
  from cr_inc
  inner join """+features_info.loc[0,'table']+""" ce
    on cr_inc.subject_id = ce.subject_id
    and ce.itemid in """+ item_str +"""
    and ce."""+features_info.loc[0,'variable']+""" is not null
    and ce.storetime between cr_inc.intime and cr_inc.creatinine_time
)
select 
a.subject_id, a.icustay_id, a.intime, a.outtime,
    a.creatinine, a.creatinine_time,
    a.age, a.inclusion_age,
    a.length_of_stay, a.inclusion_length_of_stay,
    a.rrt, a.inclusion_rrt, a.diagnoses, a.inclusion_diagnoses,
    a."""+features_info.loc[0,'name']+""", a."""+features_info.loc[0,'name']+"""_delay,
    a."""+features_info.loc[0,'name']+"""_time,
    a."""+features_info.loc[0,'name']+"""_itemid
from cr_feat as a
    join (
        select creatinine_time, min("""+features_info.loc[0,'name']+"""_delay) as """+features_info.loc[0,'name']+"""_delay
        from cr_feat
        group by creatinine_time
    ) as b on a.creatinine_time = b.creatinine_time
where a."""+features_info.loc[0,'name']+"""_delay = b."""+features_info.loc[0,'name']+"""_delay
"""
df_chartevents = pd.read_sql_query(query, con)
df_chartevents = apply_inclusion_criteria(df_chartevents)

# Convert list of diagnoses into str (required to perform the merge)
df_chartevents.loc[:,'diagnoses'] = df_chartevents['diagnoses'].apply(lambda x: ', '.join(sorted(x)))

for i,row in features_info.loc[1:,:].iterrows():
    print('------------------------------------')
    print('--- Processing feature : ' + row['name'])
    # From features_info, retrieve the list of item_id to use with chartevents
    item_col = [c for c in features_info.columns.values if "item_id" in c]
    item_list = features_info.loc[i,item_col].dropna().astype('int').values
    item_str = "(" + str(item_list[0])
    for it in item_list[1:]:
        item_str = item_str + "," + str(it)
    item_str = item_str + ")"

    # List of ICD-9 codes to be excluded
    icd_list = ['5856','V420','99681'] # ESRD: 5856 / kidney transplant: V420,99681
    icd_str = "'{" + str(icd_list[0])
    for icd in icd_list[1:]:
        icd_str = icd_str + "," + str(icd)
    icd_str = icd_str + "}'"

    query = query_schema + """
    with cr1 as
    (
    select
        icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
        ce.valuenum as creatinine, ce.storetime as creatinine_time,
        EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
        (rrt.icustay_id is null) as rrt,
        diag.icd9_code as diagnosis 
      from icustays icu
      inner join chartevents ce
        on icu.subject_id = ce.subject_id
        and ce.itemid = 220615
        and ce.valuenum is not null
        and ce.storetime between icu.intime and icu.outtime
      inner join patients pat
        ON icu.subject_id = pat.subject_id
      left outer join rrt 
        on icu.icustay_id = rrt.icustay_id
      inner join diagnoses_icd diag
        on icu.subject_id = diag.subject_id
        and icu.hadm_id = diag.hadm_id
    ),
    cr as
    (
    select
    cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime,
    cr1.creatinine, cr1.creatinine_time,
    cr1.age,
    cr1.length_of_stay,
    cr1.rrt,
    array_agg(cr1.diagnosis) as diagnoses
    from cr1
    group by cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime, cr1.creatinine, cr1.creatinine_time, cr1.age,
    cr1.length_of_stay,cr1.rrt
    ),
    cr_inc as
    (
    select
    cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
        cr.creatinine, cr.creatinine_time,
        cr.age, CASE
                    WHEN cr.age >= 15 then 1
                ELSE 0 END
                as inclusion_age,
      cr.length_of_stay, CASE
                            WHEN cr.length_of_stay >= 48 then 1
                         ELSE 0 END
                         as inclusion_length_of_stay,
      cr.rrt, CASE
                WHEN cr.rrt = False then 1
              ELSE 0 END
              as inclusion_rrt,
      cr.diagnoses, CASE
                WHEN cr.diagnoses && """ + icd_str + """ then 0
              ELSE 1 END
              as inclusion_diagnoses
      from cr
    ),
    cr_feat as
    (
    select
    cr_inc.subject_id, cr_inc.icustay_id, cr_inc.intime, cr_inc.outtime,
        cr_inc.creatinine, cr_inc.creatinine_time,
        cr_inc.age, cr_inc.inclusion_age,
        cr_inc.length_of_stay, cr_inc.inclusion_length_of_stay,
        cr_inc.rrt, cr_inc.inclusion_rrt, cr_inc.diagnoses, cr_inc.inclusion_diagnoses,
        ce.valuenum as """+features_info.loc[i,'name']+""", 
        EXTRACT('epoch' from cr_inc.creatinine_time - ce.storetime) as """+features_info.loc[i,'name']+"""_delay,
        ce.storetime as """+features_info.loc[i,'name']+"""_time,
        ce.itemid as """+features_info.loc[i,'name']+"""_itemid
      from cr_inc
      inner join """+features_info.loc[i,'table']+""" ce
        on cr_inc.subject_id = ce.subject_id
        and ce.itemid in """+ item_str +"""
        and ce."""+features_info.loc[i,'variable']+""" is not null
        and ce.storetime between cr_inc.intime and cr_inc.creatinine_time
    )
    select 
    a.subject_id, a.icustay_id, a.intime, a.outtime,
        a.creatinine, a.creatinine_time,
        a.age, a.inclusion_age,
        a.length_of_stay, a.inclusion_length_of_stay,
        a.rrt, a.inclusion_rrt, a.diagnoses, a.inclusion_diagnoses,
        a."""+features_info.loc[i,'name']+""", a."""+features_info.loc[i,'name']+"""_delay,
        a."""+features_info.loc[i,'name']+"""_time,
        a."""+features_info.loc[i,'name']+"""_itemid
    from cr_feat as a
        join (
            select creatinine_time, min("""+features_info.loc[i,'name']+"""_delay) as """+features_info.loc[i,'name']+"""_delay
            from cr_feat
            group by creatinine_time
        ) as b on a.creatinine_time = b.creatinine_time
    where a."""+features_info.loc[i,'name']+"""_delay = b."""+features_info.loc[i,'name']+"""_delay
    """
    
    df = pd.read_sql_query(query, con)
    df = apply_inclusion_criteria(df)
    # Convert list of diagnoses into str (required to perform the merge)
    df.loc[:,'diagnoses'] = df['diagnoses'].apply(lambda x: ', '.join(sorted(x)))
    
    df_chartevents = pd.merge(df_chartevents,df,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt', 'diagnoses'],how='outer')
    print('Merged table size : ' + str(df_chartevents.shape[0]))
    print(df_chartevents.head())
# Out:
# '{5856,V420,99681}'
# Initial size of table : 208840
# After dropping duplicates : 150528
# After applying inclusion criteria : 114382
# ------------------------------------
# --- Processing feature : Arterial_pressure_diastolic
# Initial size of table : 208914
# After dropping duplicates : 150526
# After applying inclusion criteria : 114382
# Merged table size : 114383
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses  \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...
#
#    arterial_pressure_systolic  arterial_pressure_systolic_delay  \
# 0                       155.0                            1800.0
# 1                       165.0                            1440.0
# 2                       162.0                             600.0
# 3                        98.0                            3060.0
# 4                       124.0                            4320.0
#
#   arterial_pressure_systolic_time  arterial_pressure_systolic_itemid  \
# 0             2166-09-21 02:51:00                           220050.0
# 1             2150-07-17 01:12:00                               51.0
# 2             2194-12-21 04:02:00                           220050.0
# 3             2114-04-08 06:15:00                           220179.0
# 4             2110-07-22 17:02:00                           220050.0
#
#    arterial_pressure_diastolic  arterial_pressure_diastolic_delay  \
# 0                         75.0                             1800.0
# 1                         75.0                             1440.0
# 2                         76.0                              600.0
# 3                         51.0                             3060.0
# 4                         60.0                             4320.0
#
#   arterial_pressure_diastolic_time  arterial_pressure_diastolic_itemid
# 0              2166-09-21 02:51:00                            220051.0
# 1              2150-07-17 01:12:00                              8368.0
# 2              2194-12-21 04:02:00                            220051.0
# 3              2114-04-08 06:15:00                            220180.0
# 4              2110-07-22 17:02:00                            220051.0
# ------------------------------------
# --- Processing feature : Heart_rate
# Initial size of table : 200758
# After dropping duplicates : 150627
# After applying inclusion criteria : 114425
# Merged table size : 114459
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses        ...          \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...        ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...        ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...        ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...        ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...        ...
#
#    arterial_pressure_systolic_time  arterial_pressure_systolic_itemid  \
# 0              2166-09-21 02:51:00                           220050.0
# 1              2150-07-17 01:12:00                               51.0
# 2              2194-12-21 04:02:00                           220050.0
# 3              2114-04-08 06:15:00                           220179.0
# 4              2110-07-22 17:02:00                           220050.0
#
#   arterial_pressure_diastolic  arterial_pressure_diastolic_delay  \
# 0                        75.0                             1800.0
# 1                        75.0                             1440.0
# 2                        76.0                              600.0
# 3                        51.0                             3060.0
# 4                        60.0                             4320.0
#
#    arterial_pressure_diastolic_time  arterial_pressure_diastolic_itemid  \
# 0               2166-09-21 02:51:00                            220051.0
# 1               2150-07-17 01:12:00                              8368.0
# 2               2194-12-21 04:02:00                            220051.0
# 3               2114-04-08 06:15:00                            220180.0
# 4               2110-07-22 17:02:00                            220051.0
#
#   heart_rate  heart_rate_delay     heart_rate_time  heart_rate_itemid
# 0       58.0            1800.0 2166-09-21 02:51:00           220045.0
# 1      102.0            1440.0 2150-07-17 01:12:00              211.0
# 2      101.0             600.0 2194-12-21 04:02:00           220045.0
# 3       95.0            3060.0 2114-04-08 06:15:00           220045.0
# 4       87.0            4320.0 2110-07-22 17:02:00           220045.0
#
# [5 rows x 22 columns]
# ------------------------------------
# --- Processing feature : Weight_daily
# Initial size of table : 86837
# After dropping duplicates : 82006
# After applying inclusion criteria : 69012
# Merged table size : 114594
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses         ...           \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...         ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...         ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...         ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...         ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...         ...
#
#    arterial_pressure_diastolic_time  arterial_pressure_diastolic_itemid  \
# 0               2166-09-21 02:51:00                            220051.0
# 1               2150-07-17 01:12:00                              8368.0
# 2               2194-12-21 04:02:00                            220051.0
# 3               2114-04-08 06:15:00                            220180.0
# 4               2110-07-22 17:02:00                            220051.0
#
#   heart_rate  heart_rate_delay     heart_rate_time  heart_rate_itemid  \
# 0       58.0            1800.0 2166-09-21 02:51:00           220045.0
# 1      102.0            1440.0 2150-07-17 01:12:00              211.0
# 2      101.0             600.0 2194-12-21 04:02:00           220045.0
# 3       95.0            3060.0 2114-04-08 06:15:00           220045.0
# 4       87.0            4320.0 2110-07-22 17:02:00           220045.0
#
#   weight_daily  weight_daily_delay   weight_daily_time  weight_daily_itemid
# 0         93.7             73380.0 2166-09-20 06:58:00             224639.0
# 1        110.0             83700.0 2150-07-16 02:21:00                763.0
# 2        126.5            100020.0 2194-12-20 00:25:00             224639.0
# 3          NaN                 NaN                 NaT                  NaN
# 4         74.1              1920.0 2110-07-22 17:42:00             224639.0
#
# [5 rows x 26 columns]
# ------------------------------------
# --- Processing feature : Temperature
# Initial size of table : 145880
# After dropping duplicates : 142139
# After applying inclusion criteria : 108923
# Merged table size : 114691
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses         ...          \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...         ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...         ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...         ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...         ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...         ...
#
#       heart_rate_time  heart_rate_itemid weight_daily  weight_daily_delay  \
# 0 2166-09-21 02:51:00           220045.0         93.7             73380.0
# 1 2150-07-17 01:12:00              211.0        110.0             83700.0
# 2 2194-12-21 04:02:00           220045.0        126.5            100020.0
# 3 2114-04-08 06:15:00           220045.0          NaN                 NaN
# 4 2110-07-22 17:02:00           220045.0         74.1              1920.0
#
#     weight_daily_time  weight_daily_itemid temperature  temperature_delay  \
# 0 2166-09-20 06:58:00             224639.0   98.600000             1740.0
# 1 2150-07-16 02:21:00                763.0   98.599998             4800.0
# 2 2194-12-20 00:25:00             224639.0   98.000000              540.0
# 3                 NaT                  NaN   98.300000             6120.0
# 4 2110-07-22 17:42:00             224639.0   98.100000             6300.0
#
#      temperature_time  temperature_itemid
# 0 2166-09-21 02:52:00            223761.0
# 1 2150-07-17 00:16:00               678.0
# 2 2194-12-21 04:03:00            223761.0
# 3 2114-04-08 05:24:00            223761.0
# 4 2110-07-22 16:29:00            223761.0
#
# [5 rows x 30 columns]
# ------------------------------------
# --- Processing feature : Urine_output
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 114691
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses         ...           \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...         ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...         ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...         ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...         ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...         ...
#
#     weight_daily_time  weight_daily_itemid temperature  temperature_delay  \
# 0 2166-09-20 06:58:00             224639.0   98.600000             1740.0
# 1 2150-07-16 02:21:00                763.0   98.599998             4800.0
# 2 2194-12-20 00:25:00             224639.0   98.000000              540.0
# 3                 NaT                  NaN   98.300000             6120.0
# 4 2110-07-22 17:42:00             224639.0   98.100000             6300.0
#
#      temperature_time  temperature_itemid urine_output  urine_output_delay  \
# 0 2166-09-21 02:52:00            223761.0          NaN                 NaN
# 1 2150-07-17 00:16:00               678.0          NaN                 NaN
# 2 2194-12-21 04:03:00            223761.0          NaN                 NaN
# 3 2114-04-08 05:24:00            223761.0          NaN                 NaN
# 4 2110-07-22 16:29:00            223761.0          NaN                 NaN
#
#    urine_output_time  urine_output_itemid
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
#
# [5 rows x 34 columns]
# ------------------------------------
# --- Processing feature : day_urine_output
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 114691
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses           ...             \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...           ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...           ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...           ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...           ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...           ...
#
#      temperature_time  temperature_itemid urine_output  urine_output_delay  \
# 0 2166-09-21 02:52:00            223761.0          NaN                 NaN
# 1 2150-07-17 00:16:00               678.0          NaN                 NaN
# 2 2194-12-21 04:03:00            223761.0          NaN                 NaN
# 3 2114-04-08 05:24:00            223761.0          NaN                 NaN
# 4 2110-07-22 16:29:00            223761.0          NaN                 NaN
#
#    urine_output_time  urine_output_itemid day_urine_output  \
# 0                NaN                  NaN              NaN
# 1                NaN                  NaN              NaN
# 2                NaN                  NaN              NaN
# 3                NaN                  NaN              NaN
# 4                NaN                  NaN              NaN
#
#    day_urine_output_delay  day_urine_output_time  day_urine_output_itemid
# 0                     NaN                    NaN                      NaN
# 1                     NaN                    NaN                      NaN
# 2                     NaN                    NaN                      NaN
# 3                     NaN                    NaN                      NaN
# 4                     NaN                    NaN                      NaN
#
# [5 rows x 38 columns]
# ------------------------------------
# --- Processing feature : SCr
# Initial size of table : 19493
# After dropping duplicates : 19487
# After applying inclusion criteria : 15083
# Merged table size : 114732
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses     ...      \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...     ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...     ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...     ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...     ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...     ...
#
#    urine_output_time  urine_output_itemid day_urine_output  \
# 0                NaN                  NaN              NaN
# 1                NaN                  NaN              NaN
# 2                NaN                  NaN              NaN
# 3                NaN                  NaN              NaN
# 4                NaN                  NaN              NaN
#
#    day_urine_output_delay  day_urine_output_time  day_urine_output_itemid  \
# 0                     NaN                    NaN                      NaN
# 1                     NaN                    NaN                      NaN
# 2                     NaN                    NaN                      NaN
# 3                     NaN                    NaN                      NaN
# 4                     NaN                    NaN                      NaN
#
#    scr  scr_delay            scr_time  scr_itemid
# 0  NaN        NaN                 NaT         NaN
# 1  0.6     3600.0 2150-07-17 00:36:00      1525.0
# 2  NaN        NaN                 NaT         NaN
# 3  NaN        NaN                 NaT         NaN
# 4  NaN        NaN                 NaT         NaN
#
# [5 rows x 42 columns]
# ------------------------------------
# --- Processing feature : Sodium
# Initial size of table : 52176
# After dropping duplicates : 52044
# After applying inclusion criteria : 43008
# Merged table size : 115042
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses      ...        \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...      ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...      ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...      ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...      ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...      ...
#
#    day_urine_output_time  day_urine_output_itemid  scr  scr_delay  \
# 0                    NaN                      NaN  NaN        NaN
# 1                    NaN                      NaN  0.6     3600.0
# 2                    NaN                      NaN  NaN        NaN
# 3                    NaN                      NaN  NaN        NaN
# 4                    NaN                      NaN  NaN        NaN
#
#              scr_time  scr_itemid sodium  sodium_delay         sodium_time  \
# 0                 NaT         NaN    NaN           NaN                 NaT
# 1 2150-07-17 00:36:00      1525.0  136.0      196980.0 2150-07-14 18:53:00
# 2                 NaT         NaN    NaN           NaN                 NaT
# 3                 NaT         NaN    NaN           NaN                 NaT
# 4                 NaT         NaN    NaN           NaN                 NaT
#
#    sodium_itemid
# 0            NaN
# 1       226534.0
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 46 columns]
# ------------------------------------
# --- Processing feature : Potassium
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 115042
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses        ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...        ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...        ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...        ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...        ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...        ...
#
#              scr_time  scr_itemid sodium  sodium_delay         sodium_time  \
# 0                 NaT         NaN    NaN           NaN                 NaT
# 1 2150-07-17 00:36:00      1525.0  136.0      196980.0 2150-07-14 18:53:00
# 2                 NaT         NaN    NaN           NaN                 NaT
# 3                 NaT         NaN    NaN           NaN                 NaT
# 4                 NaT         NaN    NaN           NaN                 NaT
#
#    sodium_itemid potassium  potassium_delay  potassium_time  potassium_itemid
# 0            NaN       NaN              NaN             NaN               NaN
# 1       226534.0       NaN              NaN             NaN               NaN
# 2            NaN       NaN              NaN             NaN               NaN
# 3            NaN       NaN              NaN             NaN               NaN
# 4            NaN       NaN              NaN             NaN               NaN
#
# [5 rows x 50 columns]
# ------------------------------------
# --- Processing feature : Calcium
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 115042
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses       ...        \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...       ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...       ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...       ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...       ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...       ...
#
#           sodium_time  sodium_itemid potassium  potassium_delay  \
# 0                 NaT            NaN       NaN              NaN
# 1 2150-07-14 18:53:00       226534.0       NaN              NaN
# 2                 NaT            NaN       NaN              NaN
# 3                 NaT            NaN       NaN              NaN
# 4                 NaT            NaN       NaN              NaN
#
#    potassium_time  potassium_itemid calcium  calcium_delay  calcium_time  \
# 0             NaN               NaN     NaN            NaN           NaN
# 1             NaN               NaN     NaN            NaN           NaN
# 2             NaN               NaN     NaN            NaN           NaN
# 3             NaN               NaN     NaN            NaN           NaN
# 4             NaN               NaN     NaN            NaN           NaN
#
#    calcium_itemid
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 54 columns]
# ------------------------------------
# --- Processing feature : Phosphor
# Initial size of table : 18364
# After dropping duplicates : 18361
# After applying inclusion criteria : 14480
# Merged table size : 115042
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses       ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...       ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...       ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...       ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...       ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...       ...
#
#    potassium_time  potassium_itemid calcium  calcium_delay  calcium_time  \
# 0             NaN               NaN     NaN            NaN           NaN
# 1             NaN               NaN     NaN            NaN           NaN
# 2             NaN               NaN     NaN            NaN           NaN
# 3             NaN               NaN     NaN            NaN           NaN
# 4             NaN               NaN     NaN            NaN           NaN
#
#    calcium_itemid phosphor  phosphor_delay       phosphor_time  \
# 0             NaN      NaN             NaN                 NaT
# 1             NaN      3.5          3600.0 2150-07-17 00:36:00
# 2             NaN      NaN             NaN                 NaT
# 3             NaN      NaN             NaN                 NaT
# 4             NaN      NaN             NaN                 NaT
#
#    phosphor_itemid
# 0              NaN
# 1           1534.0
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 58 columns]
# ------------------------------------
# --- Processing feature : Hemoglobine
# Initial size of table : 19354
# After dropping duplicates : 19348
# After applying inclusion criteria : 15044
# Merged table size : 115049
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses         ...          \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...         ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...         ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...         ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...         ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...         ...
#
#    calcium_time  calcium_itemid phosphor  phosphor_delay       phosphor_time  \
# 0           NaN             NaN      NaN             NaN                 NaT
# 1           NaN             NaN      3.5          3600.0 2150-07-17 00:36:00
# 2           NaN             NaN      NaN             NaN                 NaT
# 3           NaN             NaN      NaN             NaN                 NaT
# 4           NaN             NaN      NaN             NaN                 NaT
#
#    phosphor_itemid hemoglobine  hemoglobine_delay    hemoglobine_time  \
# 0              NaN         NaN                NaN                 NaT
# 1           1534.0         8.4             4560.0 2150-07-17 00:20:00
# 2              NaN         NaN                NaN                 NaT
# 3              NaN         NaN                NaN                 NaT
# 4              NaN         NaN                NaN                 NaT
#
#    hemoglobine_itemid
# 0                 NaN
# 1               814.0
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 62 columns]
# ------------------------------------
# --- Processing feature : Uric_acid
# Initial size of table : 1017
# After dropping duplicates : 1017
# After applying inclusion criteria : 937
# Merged table size : 115049
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses        ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...        ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...        ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...        ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...        ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...        ...
#
#         phosphor_time  phosphor_itemid hemoglobine  hemoglobine_delay  \
# 0                 NaT              NaN         NaN                NaN
# 1 2150-07-17 00:36:00           1534.0         8.4             4560.0
# 2                 NaT              NaN         NaN                NaN
# 3                 NaT              NaN         NaN                NaN
# 4                 NaT              NaN         NaN                NaN
#
#      hemoglobine_time  hemoglobine_itemid uric_acid  uric_acid_delay  \
# 0                 NaT                 NaN       NaN              NaN
# 1 2150-07-17 00:20:00               814.0       NaN              NaN
# 2                 NaT                 NaN       NaN              NaN
# 3                 NaT                 NaN       NaN              NaN
# 4                 NaT                 NaN       NaN              NaN
#
#    uric_acid_time  uric_acid_itemid
# 0             NaT               NaN
# 1             NaT               NaN
# 2             NaT               NaN
# 3             NaT               NaN
# 4             NaT               NaN
#
# [5 rows x 66 columns]
# ------------------------------------
# --- Processing feature : Chloride
# Initial size of table : 19465
# After dropping duplicates : 19460
# After applying inclusion criteria : 15071
# Merged table size : 115049
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses       ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...       ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...       ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...       ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...       ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...       ...
#
#      hemoglobine_time  hemoglobine_itemid uric_acid  uric_acid_delay  \
# 0                 NaT                 NaN       NaN              NaN
# 1 2150-07-17 00:20:00               814.0       NaN              NaN
# 2                 NaT                 NaN       NaN              NaN
# 3                 NaT                 NaN       NaN              NaN
# 4                 NaT                 NaN       NaN              NaN
#
#    uric_acid_time  uric_acid_itemid chloride  chloride_delay  \
# 0             NaT               NaN      NaN             NaN
# 1             NaT               NaN    109.0          3600.0
# 2             NaT               NaN      NaN             NaN
# 3             NaT               NaN      NaN             NaN
# 4             NaT               NaN      NaN             NaN
#
#         chloride_time  chloride_itemid
# 0                 NaT              NaN
# 1 2150-07-17 00:36:00           1523.0
# 2                 NaT              NaN
# 3                 NaT              NaN
# 4                 NaT              NaN
#
# [5 rows x 70 columns]
# ------------------------------------
# --- Processing feature : Platelet_count
# Initial size of table : 19366
# After dropping duplicates : 19364
# After applying inclusion criteria : 15057
# Merged table size : 115049
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses          ...            \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...          ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...          ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...          ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...          ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...          ...
#
#    uric_acid_time  uric_acid_itemid chloride  chloride_delay  \
# 0             NaT               NaN      NaN             NaN
# 1             NaT               NaN    109.0          3600.0
# 2             NaT               NaN      NaN             NaN
# 3             NaT               NaN      NaN             NaN
# 4             NaT               NaN      NaN             NaN
#
#         chloride_time  chloride_itemid platelet_count  platelet_count_delay  \
# 0                 NaT              NaN            NaN                   NaN
# 1 2150-07-17 00:36:00           1523.0          741.0                4560.0
# 2                 NaT              NaN            NaN                   NaN
# 3                 NaT              NaN            NaN                   NaN
# 4                 NaT              NaN            NaN                   NaN
#
#    platelet_count_time  platelet_count_itemid
# 0                  NaT                    NaN
# 1  2150-07-17 00:20:00                  828.0
# 2                  NaT                    NaN
# 3                  NaT                    NaN
# 4                  NaT                    NaN
#
# [5 rows x 74 columns]
# ------------------------------------
# --- Processing feature : pH_blood
# Initial size of table : 109899
# After dropping duplicates : 109719
# After applying inclusion criteria : 91660
# Merged table size : 115341
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses       ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...       ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...       ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...       ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...       ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...       ...
#
#         chloride_time  chloride_itemid platelet_count  platelet_count_delay  \
# 0                 NaT              NaN            NaN                   NaN
# 1 2150-07-17 00:36:00           1523.0          741.0                4560.0
# 2                 NaT              NaN            NaN                   NaN
# 3                 NaT              NaN            NaN                   NaN
# 4                 NaT              NaN            NaN                   NaN
#
#    platelet_count_time  platelet_count_itemid ph_blood  ph_blood_delay  \
# 0                  NaT                    NaN      NaN             NaN
# 1  2150-07-17 00:20:00                  828.0     7.28          5040.0
# 2                  NaT                    NaN      NaN             NaN
# 3                  NaT                    NaN     7.58        168120.0
# 4                  NaT                    NaN     7.31          3240.0
#
#         ph_blood_time  ph_blood_itemid
# 0                 NaT              NaN
# 1 2150-07-17 00:12:00         223830.0
# 2                 NaT              NaN
# 3 2114-04-06 08:24:00         223830.0
# 4 2110-07-22 17:20:00         223830.0
#
# [5 rows x 78 columns]
# ------------------------------------
# --- Processing feature : fibrinogen
# Initial size of table : 6262
# After dropping duplicates : 6262
# After applying inclusion criteria : 5144
# Merged table size : 115342
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses        ...          \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...        ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...        ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...        ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...        ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...        ...
#
#    platelet_count_time  platelet_count_itemid ph_blood  ph_blood_delay  \
# 0                  NaT                    NaN      NaN             NaN
# 1  2150-07-17 00:20:00                  828.0     7.28          5040.0
# 2                  NaT                    NaN      NaN             NaN
# 3                  NaT                    NaN     7.58        168120.0
# 4                  NaT                    NaN     7.31          3240.0
#
#         ph_blood_time  ph_blood_itemid fibrinogen  fibrinogen_delay  \
# 0                 NaT              NaN        NaN               NaN
# 1 2150-07-17 00:12:00         223830.0        NaN               NaN
# 2                 NaT              NaN        NaN               NaN
# 3 2114-04-06 08:24:00         223830.0        NaN               NaN
# 4 2110-07-22 17:20:00         223830.0        NaN               NaN
#
#    fibrinogen_time  fibrinogen_itemid
# 0              NaT                NaN
# 1              NaT                NaN
# 2              NaT                NaN
# 3              NaT                NaN
# 4              NaT                NaN
#
# [5 rows x 82 columns]
# ------------------------------------
# --- Processing feature : urinary_sodium
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 115342
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses          ...            \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...          ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...          ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...          ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...          ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...          ...
#
#         ph_blood_time  ph_blood_itemid fibrinogen  fibrinogen_delay  \
# 0                 NaT              NaN        NaN               NaN
# 1 2150-07-17 00:12:00         223830.0        NaN               NaN
# 2                 NaT              NaN        NaN               NaN
# 3 2114-04-06 08:24:00         223830.0        NaN               NaN
# 4 2110-07-22 17:20:00         223830.0        NaN               NaN
#
#    fibrinogen_time  fibrinogen_itemid urinary_sodium  urinary_sodium_delay  \
# ...
# 3                       NaN             NaN                    NaN
# 4                       NaN             NaN                    NaN
#
#    urine_creatinin_time  urine_creatinin_itemid alkaline_phospatase  \
# 0                   NaN                     NaN                 NaN
# 1                   NaN                     NaN                 NaN
# 2                   NaN                     NaN                 NaN
# 3                   NaN                     NaN                 NaN
# 4                   NaN                     NaN                 NaN
#
#    alkaline_phospatase_delay  alkaline_phospatase_time  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    alkaline_phospatase_itemid
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 98 columns]
# ------------------------------------
# --- Processing feature : Total_protein_blood
# Initial size of table : 6255
# After dropping duplicates : 6255
# After applying inclusion criteria : 5171
# Merged table size : 115345
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses  \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...
#
#               ...              urine_creatinin_time  urine_creatinin_itemid  \
# 0             ...                               NaN                     NaN
# 1             ...                               NaN                     NaN
# 2             ...                               NaN                     NaN
# 3             ...                               NaN                     NaN
# 4             ...                               NaN                     NaN
#
#   alkaline_phospatase  alkaline_phospatase_delay  alkaline_phospatase_time  \
# 0                 NaN                        NaN                       NaN
# 1                 NaN                        NaN                       NaN
# 2                 NaN                        NaN                       NaN
# 3                 NaN                        NaN                       NaN
# 4                 NaN                        NaN                       NaN
#
#    alkaline_phospatase_itemid total_protein_blood  total_protein_blood_delay  \
# 0                         NaN                 NaN                        NaN
# 1                         NaN                 NaN                        NaN
# 2                         NaN                 NaN                        NaN
# 3                         NaN                 NaN                        NaN
# 4                         NaN                 NaN                        NaN
#
#    total_protein_blood_time  total_protein_blood_itemid
# 0                       NaT                         NaN
# 1                       NaT                         NaN
# 2                       NaT                         NaN
# 3                       NaT                         NaN
# 4                       NaT                         NaN
#
# [5 rows x 102 columns]
# ------------------------------------
# --- Processing feature : albumin
# Initial size of table : 11253
# After dropping duplicates : 11251
# After applying inclusion criteria : 9527
# Merged table size : 115345
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses       ...        \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...       ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...       ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...       ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...       ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...       ...
#
#    alkaline_phospatase_time  alkaline_phospatase_itemid total_protein_blood  \
# 0                       NaN                         NaN                 NaN
# 1                       NaN                         NaN                 NaN
# 2                       NaN                         NaN                 NaN
# 3                       NaN                         NaN                 NaN
# 4                       NaN                         NaN                 NaN
#
#    total_protein_blood_delay  total_protein_blood_time  \
# 0                        NaN                       NaT
# 1                        NaN                       NaT
# 2                        NaN                       NaT
# 3                        NaN                       NaT
# 4                        NaN                       NaT
#
#    total_protein_blood_itemid albumin  albumin_delay        albumin_time  \
# 0                         NaN     NaN            NaN                 NaT
# 1                         NaN     2.3       256500.0 2150-07-14 02:21:00
# 2                         NaN     NaN            NaN                 NaT
# 3                         NaN     NaN            NaN                 NaT
# 4                         NaN     NaN            NaN                 NaT
#
#    albumin_itemid
# 0             NaN
# 1          1521.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 106 columns]
# ------------------------------------
# --- Processing feature : Total_protein_urine
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 115345
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses  \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...
#
#               ...              total_protein_blood_time  \
# 0             ...                                   NaT
# 1             ...                                   NaT
# 2             ...                                   NaT
# 3             ...                                   NaT
# 4             ...                                   NaT
#
#    total_protein_blood_itemid albumin  albumin_delay        albumin_time  \
# 0                         NaN     NaN            NaN                 NaT
# 1                         NaN     2.3       256500.0 2150-07-14 02:21:00
# 2                         NaN     NaN            NaN                 NaT
# 3                         NaN     NaN            NaN                 NaT
# 4                         NaN     NaN            NaN                 NaT
#
#    albumin_itemid total_protein_urine  total_protein_urine_delay  \
# 0             NaN                 NaN                        NaN
# 1          1521.0                 NaN                        NaN
# 2             NaN                 NaN                        NaN
# 3             NaN                 NaN                        NaN
# 4             NaN                 NaN                        NaN
#
#    total_protein_urine_time  total_protein_urine_itemid
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
# [5 rows x 110 columns]
# ------------------------------------
# --- Processing feature : bilirubin
# Initial size of table : 0
# After dropping duplicates : 0
# After applying inclusion criteria : 0
# Merged table size : 115345
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses        ...         \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...        ...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...        ...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...        ...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...        ...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...        ...
#
#          albumin_time  albumin_itemid total_protein_urine  \
# 0                 NaT             NaN                 NaN
# 1 2150-07-14 02:21:00          1521.0                 NaN
# 2                 NaT             NaN                 NaN
# 3                 NaT             NaN                 NaN
# 4                 NaT             NaN                 NaN
#
#    total_protein_urine_delay  total_protein_urine_time  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    total_protein_urine_itemid bilirubin  bilirubin_delay  bilirubin_time  \
# 0                         NaN       NaN              NaN             NaN
# 1                         NaN       NaN              NaN             NaN
# 2                         NaN       NaN              NaN             NaN
# 3                         NaN       NaN              NaN             NaN
# 4                         NaN       NaN              NaN             NaN
#
#    bilirubin_itemid
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 114 columns]
# ------------------------------------
# --- Processing feature : C_reactive_protein
# Initial size of table : 5012
# After dropping duplicates : 4986
# After applying inclusion criteria : 4359
# Merged table size : 115345
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses  \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...
#
#              ...              total_protein_urine_time  \
# 0            ...                                   NaN
# 1            ...                                   NaN
# 2            ...                                   NaN
# 3            ...                                   NaN
# 4            ...                                   NaN
#
#    total_protein_urine_itemid bilirubin  bilirubin_delay  bilirubin_time  \
# 0                         NaN       NaN              NaN             NaN
# 1                         NaN       NaN              NaN             NaN
# 2                         NaN       NaN              NaN             NaN
# 3                         NaN       NaN              NaN             NaN
# 4                         NaN       NaN              NaN             NaN
#
#    bilirubin_itemid c_reactive_protein  c_reactive_protein_delay  \
# 0               NaN                NaN                       NaN
# 1               NaN                NaN                       NaN
# 2               NaN                NaN                       NaN
# 3               NaN                NaN                       NaN
# 4               NaN                NaN                       NaN
#
#    c_reactive_protein_time  c_reactive_protein_itemid
# 0                      NaT                        NaN
# 1                      NaT                        NaN
# 2                      NaT                        NaN
# 3                      NaT                        NaN
# 4                      NaT                        NaN
#
# [5 rows x 118 columns]

# %%
# Dump to file
df_chartevents.to_csv('creatinine_measurements_1.csv')
df_chartevents.head()
# Out:
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       77815      239231 2166-09-16 16:45:22 2166-09-29 10:07:21         0.6
# 1       31558      249349 2150-07-04 03:10:20 2150-07-22 14:13:53         0.6
# 2       53763      223136 2194-12-19 10:00:17 2194-12-26 23:51:37         0.8
# 3        7533      208809 2114-03-29 09:36:53 2114-04-08 18:39:51         0.8
# 4       50772      272254 2110-07-21 12:00:12 2110-07-27 14:20:35         0.8
#
#       creatinine_time        age  length_of_stay    rrt  \
# 0 2166-09-21 03:21:00  58.363217      305.366389  False
# 1 2150-07-17 01:36:00  52.688716      443.059167  False
# 2 2194-12-21 04:12:00  70.937671      181.855556  False
# 3 2114-04-08 07:06:00  66.441977      249.049444  False
# 4 2110-07-22 18:14:00  74.513611      146.339722  False
#
#                                            diagnoses  \
# 0  04104, 2724, 2761, 3229, 3314, 3485, 4019, 430...
# 1  0389, 4538, 4822, 5109, 5118, 51881, 8052, 807...
# 2  2536, 2724, 29181, 30000, 3051, 34290, 3485, 4...
# 3  0389, 2442, 2724, 2763, 2875, 2930, 34982, 401...
# 4  0414, 25002, 2724, 2760, 2859, 2948, 3004, 427...
#
#              ...              total_protein_urine_time  \
# 0            ...                                   NaN
# 1            ...                                   NaN
# 2            ...                                   NaN
# 3            ...                                   NaN
# 4            ...                                   NaN
#
#    total_protein_urine_itemid bilirubin  bilirubin_delay  bilirubin_time  \
# 0                         NaN       NaN              NaN             NaN
# 1                         NaN       NaN              NaN             NaN
# 2                         NaN       NaN              NaN             NaN
# 3                         NaN       NaN              NaN             NaN
# 4                         NaN       NaN              NaN             NaN
#
#    bilirubin_itemid c_reactive_protein  c_reactive_protein_delay  \
# 0               NaN                NaN                       NaN
# 1               NaN                NaN                       NaN
# 2               NaN                NaN                       NaN
# 3               NaN                NaN                       NaN
# 4               NaN                NaN                       NaN
#
#    c_reactive_protein_time  c_reactive_protein_itemid
# 0                      NaT                        NaN
# 1                      NaT                        NaN
# 2                      NaT                        NaN
# 3                      NaT                        NaN
# 4                      NaT                        NaN
#
# [5 rows x 118 columns]

# %% [markdown]
# ## 5. Retrieve missing static information
# On top of the variables from chartevents table, retrieve following static information that may have an impact on the quality of the predictions :
# - Reason of stay (i.e. diagnosis at entrance)
# - Ethnicity
# - Age
# - Gender

# %%
query = query_schema + """
with cr1 as
(
select
    icu.subject_id, icu.icustay_id, icu.intime, icu.outtime, EXTRACT(EPOCH FROM icu.outtime - icu.intime)/60.0/60.0 as length_of_stay,
    ce.valuenum as creatinine, ce.storetime as creatinine_time,
    adm.ethnicity, adm.diagnosis as diagnosis,
    pat.gender as gender,
    EXTRACT('epoch' from icu.intime - pat.dob) / 60.0 / 60.0 / 24.0 / 365.242 AS age,
    (rrt.icustay_id is null) as rrt,
    diag.icd9_code as diag 
  from icustays icu
  inner join chartevents ce
    on icu.subject_id = ce.subject_id
    and ce.itemid = 220615
    and ce.valuenum is not null
    and ce.storetime between icu.intime and icu.outtime
  inner join patients pat
    ON icu.subject_id = pat.subject_id
  inner join admissions adm
    on icu.subject_id = adm.subject_id
  left outer join rrt 
    on icu.icustay_id = rrt.icustay_id
  inner join diagnoses_icd diag
    on icu.subject_id = diag.subject_id
    and icu.hadm_id = diag.hadm_id
),
cr as
(
select
cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime,
cr1.creatinine, cr1.creatinine_time,
cr1.ethnicity, cr1.diagnosis,
cr1.gender as gender,
cr1.age,
cr1.length_of_stay,
cr1.rrt,
array_agg(cr1.diag) as diagnoses
from cr1
group by cr1.subject_id, cr1.icustay_id, cr1.intime, cr1.outtime, cr1.creatinine, cr1.creatinine_time,
cr1.ethnicity, cr1.diagnosis, cr1.gender, cr1.age, cr1.length_of_stay, cr1.rrt
)
select
cr.subject_id, cr.icustay_id, cr.intime, cr.outtime,
    cr.creatinine, cr.creatinine_time,
    cr.ethnicity, cr.diagnosis, cr.gender,
    cr.age, CASE
                WHEN cr.age >= 15 then 1
            ELSE 0 END
            as inclusion_age,
  cr.length_of_stay, CASE
                        WHEN cr.length_of_stay >= 48 then 1
                     ELSE 0 END
                     as inclusion_length_of_stay,
  cr.rrt, CASE
            WHEN cr.rrt = False then 1
          ELSE 0 END
          as inclusion_rrt,
  cr.diagnoses, CASE
            WHEN cr.diagnoses && """ + icd_str + """ then 0
          ELSE 1 END
          as inclusion_diagnoses
  from cr
"""
df_static = pd.read_sql_query(query, con)
df_static = apply_inclusion_criteria(df_static)

# Convert list of diagnoses into str (required to perform the merge)
df_static.loc[:,'diagnoses'] = df_static['diagnoses'].apply(lambda x: ', '.join(sorted(x)))
print(df_static.head())
# Out:
# Initial size of table : 288243
# After dropping duplicates : 152630
# After applying inclusion criteria : 115784
#    subject_id  icustay_id              intime             outtime  creatinine  \
# 0       96260      278161 2196-08-31 18:24:20 2196-09-05 15:39:35         1.1
# 1       92788      241776 2148-12-05 18:00:11 2148-12-23 19:52:48         5.8
# 3       56854      279535 2201-02-02 11:39:44 2201-03-17 14:55:55         1.8
# 4       74626      274172 2137-05-06 20:20:31 2137-05-30 15:14:22         1.3
# 6       90834      280700 2161-05-16 07:30:53 2161-05-20 19:03:29         0.7
#
#       creatinine_time               ethnicity                 diagnosis  \
# 0 2196-08-31 21:23:00  BLACK/AFRICAN AMERICAN  STEVENS JOHNSON SYNDROME
# 1 2148-12-09 06:13:00                   WHITE              ENDOCARDITIS
# 3 2201-02-04 01:46:00                   WHITE               HYPOTENSION
# 4 2137-05-17 05:09:00                   WHITE                   DYSPNEA
# 6 2161-05-20 16:27:00                   WHITE                 PNEUMONIA
#
#   gender         age  length_of_stay    rrt  \
# 0      F   52.079900      117.254167  False
# 11                                 GASTROINTESTINAL BLEED      M   62.867591
# 13                       TRACHEOMALASIA;FAILED EXTUBATION      F   76.584000
# 14                                                 ANEMIA      M   57.949956
# 15      AORTIC STENOSIS\AVR; ? CORONARY ARTERY BYPASS ...      F   70.620153
# 16                                      SUICIDAL IDEATION      M   36.411656
# 17                             NONHODGKINS LYMPHOMA/FEVER      M   60.583242
# 21                                             DISSECTION      M   64.477751
# 22                              INGESTION OF FOREIGN BODY      M   39.239041
# 24                                  ALTERED MENTAL STATUS      F   54.445582
# 28                           UROSEPSIS; OBSTRUCTING STONE      F   53.862007
# 29                                CORONARY ARTERY DISEASE      F   59.864146
# 30                                URINARY TRACT INFECTION      F   85.656230
# 31                           CORONARY ARTERY DISEASE\CATH      F   72.776655
# 32                                           PANCREATITIS      M   28.148728
# 34                                  ALTERED MENTAL STATUS      M   53.649198
# 36                                                  FEVER      M   57.721457
# 37                      ST ELEVATED MYOCARDIAL INFARCTION      M  300.002946
# 38                                  HEPATITIS C;CIRRHOSIS      M   47.992978
# 42                                     BRAIN ANEURYSM/SDA      F   53.778154
# 46                                          FEVER,DYSPNEA      M   49.491317
# 48                               TRACHEOBROCHOMALACIA/SDA      F   56.323324
# ...                                                   ...    ...         ...
# 288103                                   STROKE;TELEMETRY      M   82.254288
# 288105                                          PNEUMONIA      F   44.810246
# 288106                                           LIVER TX      M   53.446255
# 288108                              DIABETIC KETOACIDOSIS      M   62.055525
# 288127                                  ETOH INTOXICATION      M   51.242588
# 288129                     HEPATICOCELLULAR CARCINOMA/SDA      M   64.301801
# 288131                                  C5 BURST FRACTURE      M   34.270628
# 288132                                       BLUNT TRAUMA      M   41.732994
# 288136                                LUMBAR STENOSIS/SDA      M   65.000380
# 288137                               HYPERTENSIVE URGENCY      F   79.593390
# 288142                       S/P FALL;RESPIRATORY FAILURE      M   60.886255
# 288147  NON ST ELEVATION MYOCARDIAL INFARCTION;ACUTE C...      F   87.121449
# 288149                                           GI BLEED      F   85.258820
# 288156                                             SEPSIS      M   38.434680
# 288164                                     BLADDER CANCER      M   88.535114
# 288168        AORTIC VALVE DISORDER\BENTAL PROCEDURE /SDA      F   46.296522
# 288169            OBSTRUCTIVE JAUNDICE;CHOLANGIOCARCINOMA      F   52.573616
# 288173                                           OVERDOSE      F   22.980945
# 288183                            INTRACRANIAL HEMORRHAGE      F   84.787713
# 288184                                       S/P MVC, SAH      M   18.481709
# 288192                   ASTHMA;CHRONIC OBST PULM DISEASE      F   64.818974
# 288202                                       KIDNEY STONE      M   83.076288
# 288203                         S/P MOTOR VEHICLE ACCIDENT      F   79.970848
# 288208  HYPOTENSION;NEW CARDIOMYOPATHY;RESPIRATORY DIS...      M   68.058301
# 288215                              CENTRAL CORD SYNDROME      M   74.456889
# 288222                                         BRAIN MASS      M   62.742911
# 288226                                    HEPATIC FAILURE      F   24.382965
# 288227                           CONGESTIVE HEART FAILURE      F   68.589756
# 288228                                         HEAD BLEED      F   46.287813
# 288232  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS
# 37      2724, 40390, 41041, 412, 41401, 41404, 42731, ...
# 38      03849, 0414, 07032, 2841, 42731, 42732, 4329, ...
# 42      3051, 3314, 3485, 430, 4373, 5184, 51851, 7806...
# 46      00845, 042, 2753, 2859, 34982, 3569, 49121, 51...
# 48      2449, 25000, 2720, 2762, 27652, 496, 51919, 53...
# ...                                                   ...
# 288103  2724, 34281, 40390, 4264, 42731, 431, 43401, 4...
# 288105  00845, 0389, 04104, 1122, 2535, 2760, 2761, 27...
# 288106  07054, 1550, 24900, 27669, 3051, 4556, 4561, 5...
# 288108  25002, 2851, 3004, 3051, 33394, 41189, 412, 41...
# 288127  27652, 2910, 30301, 3051, 30520, 78039, 78659,...
# 288129  0389, 07044, 1125, 1550, 19889, 261, 2762, 286...
# 288131            30500, 34404, 5185, 80609, 99731, E8830
# 288132  00845, 2724, 2762, 29181, 2920, 30391, 30400, ...
# 288136  2851, 3320, 33812, 3384, 34931, 5559, 5571, 72...
# 288137  25000, 2724, 2762, 2859, 2875, 4019, 41071, 41...
# 288142  00845, 25000, 2762, 2767, 27801, 27803, 2859, ...
# 288147  04112, 25050, 25060, 25080, 3572, 36201, 4019,...
# 288149  25000, 2869, 4019, 42731, 43411, 496, 5185, 56...
# 288156  03812, 07070, 27800, 2858, 2866, 28749, 30391,...
# 288164  0389, 04119, 1888, 2724, 2859, 2866, 2948, 401...
# 288168  27651, 27800, 2851, 4019, 4241, 4271, 42741, 4...
# 288169  1551, 2449, 2851, 3051, 34690, 4589, 4590, 493...
# 288173  2511, 2760, 2762, 28521, 29620, 29650, 34400, ...
# 288183  0414, 2930, 3314, 4019, 42689, 431, 4414, 496,...
# 288184  2875, 28860, 30500, 3101, 3380, 48249, 78060, ...
# 288192  0389, 2449, 2851, 32723, 4019, 41071, 481, 491...
# 288202  00845, 0389, 25000, 2630, 27652, 2859, 4011, 4...
# 288203  25080, 2720, 2761, 2767, 27800, 2851, 2875, 28...
# 288208  0389, 0414, 2749, 28860, 29181, 30391, 4019, 4...
# 288215  24990, 28860, 3659, 4019, 42731, 42789, 496, 5...
# 288222  0549, 2639, 2724, 2761, 3202, 3240, 3314, 3485...
# 288226  0389, 28959, 5119, 51881, 51909, 52689, 570, 5...
# 288227  2449, 25000, 40390, 412, 41400, 42731, 4280, 4...
# 288228  04102, 04104, 1890, 2411, 25000, 2763, 27800, ...
# 288232  2449, 25000, 2724, 2749, 2762, 27669, 27801, 3...
#
# [115784 rows x 13 columns]

# %% [markdown]
# ## 6. Merge df_chartevents and df_static tables into one
# Create one unique dataframe holding the static and dynamic features

# %%
print('Chartevents :')
print(df_chartevents.shape)
print(df_chartevents.columns.values)
print('')

print('Static:')
print(df_static.shape)
print(df_static.columns.values)
# Out:
# Chartevents :
# (115345, 118)
# ['subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'age' 'length_of_stay' 'rrt' 'diagnoses'
#  'arterial_pressure_systolic' 'arterial_pressure_systolic_delay'
#  'arterial_pressure_systolic_time' 'arterial_pressure_systolic_itemid'
#  'arterial_pressure_diastolic' 'arterial_pressure_diastolic_delay'
#  'arterial_pressure_diastolic_time' 'arterial_pressure_diastolic_itemid'
#  'heart_rate' 'heart_rate_delay' 'heart_rate_time' 'heart_rate_itemid'
#  'weight_daily' 'weight_daily_delay' 'weight_daily_time'
#  'weight_daily_itemid' 'temperature' 'temperature_delay'
#  'temperature_time' 'temperature_itemid' 'urine_output'
#  'urine_output_delay' 'urine_output_time' 'urine_output_itemid'
#  'day_urine_output' 'day_urine_output_delay' 'day_urine_output_time'
#  'day_urine_output_itemid' 'scr' 'scr_delay' 'scr_time' 'scr_itemid'
#  'sodium' 'sodium_delay' 'sodium_time' 'sodium_itemid' 'potassium'
#  'potassium_delay' 'potassium_time' 'potassium_itemid' 'calcium'
#  'calcium_delay' 'calcium_time' 'calcium_itemid' 'phosphor'
#  'phosphor_delay' 'phosphor_time' 'phosphor_itemid' 'hemoglobine'
#  'hemoglobine_delay' 'hemoglobine_time' 'hemoglobine_itemid' 'uric_acid'
#  'uric_acid_delay' 'uric_acid_time' 'uric_acid_itemid' 'chloride'
#  'chloride_delay' 'chloride_time' 'chloride_itemid' 'platelet_count'
#  'platelet_count_delay' 'platelet_count_time' 'platelet_count_itemid'
#  'ph_blood' 'ph_blood_delay' 'ph_blood_time' 'ph_blood_itemid'
#  'fibrinogen' 'fibrinogen_delay' 'fibrinogen_time' 'fibrinogen_itemid'
#  'urinary_sodium' 'urinary_sodium_delay' 'urinary_sodium_time'
#  'urinary_sodium_itemid' 'urinary_potassium' 'urinary_potassium_delay'
#  'urinary_potassium_time' 'urinary_potassium_itemid' 'urine_creatinin'
#  'urine_creatinin_delay' 'urine_creatinin_time' 'urine_creatinin_itemid'
#  'alkaline_phospatase' 'alkaline_phospatase_delay'
#  'alkaline_phospatase_time' 'alkaline_phospatase_itemid'
#  'total_protein_blood' 'total_protein_blood_delay'
#  'total_protein_blood_time' 'total_protein_blood_itemid' 'albumin'
#  'albumin_delay' 'albumin_time' 'albumin_itemid' 'total_protein_urine'
#  'total_protein_urine_delay' 'total_protein_urine_time'
#  'total_protein_urine_itemid' 'bilirubin' 'bilirubin_delay'
#  'bilirubin_time' 'bilirubin_itemid' 'c_reactive_protein'
#  'c_reactive_protein_delay' 'c_reactive_protein_time'
#  'c_reactive_protein_itemid']
#
# Static:
# (115784, 13)
# ['subject_id' 'icustay_id' 'intime' 'outtime' 'creatinine'
#  'creatinine_time' 'ethnicity' 'diagnosis' 'gender' 'age' 'length_of_stay'
#  'rrt' 'diagnoses']

# %%
merged_df = pd.merge(df_chartevents,df_static,on=['subject_id', 'icustay_id', 'intime', 'outtime', 'creatinine',
       'creatinine_time', 'age', 'length_of_stay', 'rrt', 'diagnoses'],how='outer')

# %% [markdown]
# ## 7. Remove columns that are not features
# (except icustay_id and patient_id that are needed to build the table with labels)

# %%
# REMOVE COLUMNS THAT WERE USED FOR INCLUSION CRITERIA BUT THAT ARE NOT AVAILABLE FEATURES FOR THE PREDICTION
# REMOVE ICUSTAY_IDS FOR WHICH THERE IS ONLY ONE MEASUREMENT OF CREATININE

print('Number of lines : ' + str(merged_df.shape[0]))
to_remove = ['intime','outtime','length_of_stay','rrt','diagnoses']
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)
        
# Remove columns with _time suffix EXCEPT the time for creatinine which is required to compute the labels
to_remove = [i for i in merged_df.columns.values if (('_time' in i) & (i!='creatinine_time'))]
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)

# Remove columns with _itemid suffix
to_remove = [i for i in merged_df.columns.values if '_itemid' in i]
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)

# Remove icustay_ids for which there's only one measurement of creatinine
count_mes = merged_df['icustay_id'].value_counts()
to_remove = count_mes.index.values[count_mes==1]
for i in to_remove:
    merged_df = merged_df.loc[merged_df['icustay_id']!=i,:]

# Drop duplicate values of creatinine_time
merged_df = merged_df.drop_duplicates(['icustay_id','creatinine_time'])
print('After dropping unique measurements of creatinine : ' + str(merged_df.shape[0]))
merged_df.head()
# Out:
# Number of lines : 119104
# After dropping unique measurements of creatinine : 115717
#    subject_id  icustay_id  creatinine     creatinine_time        age  \
# 0       77815      239231         0.6 2166-09-21 03:21:00  58.363217
# 1       31558      249349         0.6 2150-07-17 01:36:00  52.688716
# 2       53763      223136         0.8 2194-12-21 04:12:00  70.937671
# 3        7533      208809         0.8 2114-04-08 07:06:00  66.441977
# 4       50772      272254         0.8 2110-07-22 18:14:00  74.513611
#
#    arterial_pressure_systolic  arterial_pressure_systolic_delay  \
# 0                       155.0                            1800.0
# 1                       165.0                            1440.0
# 2                       162.0                             600.0
# 3                        98.0                            3060.0
# 4                       124.0                            4320.0
#
#    arterial_pressure_diastolic  arterial_pressure_diastolic_delay  heart_rate  \
# 0                         75.0                             1800.0        58.0
# 1                         75.0                             1440.0       102.0
# 2                         76.0                              600.0       101.0
# 3                         51.0                             3060.0        95.0
# 4                         60.0                             4320.0        87.0
#
#     ...    albumin_delay  total_protein_urine  total_protein_urine_delay  \
# 0   ...              NaN                  NaN                        NaN
# 1   ...         256500.0                  NaN                        NaN
# 2   ...              NaN                  NaN                        NaN
# 3   ...              NaN                  NaN                        NaN
# 4   ...              NaN                  NaN                        NaN
#
#    bilirubin  bilirubin_delay c_reactive_protein c_reactive_protein_delay  \
# 0        NaN              NaN                NaN                      NaN
# 1        NaN              NaN                NaN                      NaN
# 2        NaN              NaN                NaN                      NaN
# 3        NaN              NaN                NaN                      NaN
# 4        NaN              NaN                NaN                      NaN
#
#         ethnicity                diagnosis  gender
# 0           WHITE  INTRACRANIAL HEMORRHAGE       M
# 1           WHITE     S/P BOATING ACCIDENT       M
# 2           WHITE               HEAD BLEED       M
# 3  ASIAN - KOREAN               S/P ARREST       F
# 4           WHITE    ALTERED MENTAL STATUS       F
#
# [5 rows x 62 columns]

# %% [markdown]
# **WARNING : the columns named "..._itemid" can be used to filter on the itemid used to retrieve the feature after the query has been done. But these are not features.**

# %%
# Dump to file
merged_df.to_csv('creatinine_measurements_merged.csv')
print(merged_df)
# Out:
#         subject_id  icustay_id  creatinine     creatinine_time         age  \
# 0            77815      239231         0.6 2166-09-21 03:21:00   58.363217
# 1            31558      249349         0.6 2150-07-17 01:36:00   52.688716
# 119000         NaN   ...              NaN                  NaN
# 119001         NaN   ...              NaN                  NaN
# 119005         NaN   ...              NaN                  NaN
# 119007         NaN   ...              NaN                  NaN
# 119008         NaN   ...              NaN                  NaN
# 119017         NaN   ...              NaN                  NaN
# 119042         NaN   ...              NaN                  NaN
# 119046         NaN   ...              NaN                  NaN
# 119051         NaN   ...              NaN                  NaN
# 119068         NaN   ...              NaN                  NaN
# 119071         NaN   ...              NaN                  NaN
# 119075         NaN   ...              NaN                  NaN
# 119081         NaN   ...              NaN                  NaN
# 119082         NaN   ...              NaN                  NaN
# 119083         NaN   ...              NaN                  NaN
# 119092         NaN   ...              NaN                  NaN
# 119098         NaN   ...              NaN                  NaN
# 119100         NaN   ...              NaN                  NaN
# 119102         NaN   ...              NaN                  NaN
# 119103         NaN   ...              NaN                  NaN
#
#         total_protein_urine_delay  bilirubin  bilirubin_delay  \
# 0                             NaN        NaN              NaN
# 1                             NaN        NaN              NaN
# 2                             NaN        NaN              NaN
# 3                             NaN        NaN              NaN
# 4                             NaN        NaN              NaN
# 5                             NaN        NaN              NaN
# 6                             NaN        NaN              NaN
# 7                             NaN        NaN              NaN
# 8                             NaN        NaN              NaN
# 9                             NaN        NaN              NaN
# 10                            NaN        NaN              NaN
# 11                            NaN        NaN              NaN
# 12                            NaN        NaN              NaN
# 13                            NaN        NaN              NaN
# 14                            NaN        NaN              NaN
# 15                            NaN        NaN              NaN
# 16                            NaN        NaN              NaN
# 17                            NaN        NaN              NaN
# 18                            NaN        NaN              NaN
# 19                            NaN        NaN              NaN
# 20                            NaN        NaN              NaN
# 21                            NaN        NaN              NaN
# 22                            NaN        NaN              NaN
# 23                            NaN        NaN              NaN
# 24                            NaN        NaN              NaN
# 25                            NaN        NaN              NaN
# 26                            NaN        NaN              NaN
# 27                            NaN        NaN              NaN
# 28                            NaN        NaN              NaN
# 29                            NaN        NaN              NaN
# ...                           ...        ...              ...
# 118944                        NaN        NaN              NaN
# 118945                        NaN        NaN              NaN
# 118950                        NaN        NaN              NaN
# 118953                        NaN        NaN              NaN
# 118963                        NaN        NaN              NaN
# 118980                        NaN        NaN              NaN
# 118982                        NaN        NaN              NaN
# 118987                        NaN        NaN              NaN
# 118990                        NaN        NaN              NaN
# 118994                        NaN        NaN              NaN
# 119000                        NaN        NaN              NaN
# 119001                        NaN        NaN              NaN
# 119005                        NaN        NaN              NaN
# 119007                        NaN        NaN              NaN
# 119008                        NaN        NaN              NaN
# 119017                        NaN        NaN              NaN
# 119042                        NaN        NaN              NaN
# 119046                        NaN        NaN              NaN
# 119051                        NaN        NaN              NaN
# 119068                        NaN        NaN              NaN
# 119071                        NaN        NaN              NaN
# 119075                        NaN        NaN              NaN
# 119081                        NaN        NaN              NaN
# 119082                        NaN        NaN              NaN
# 119083                        NaN        NaN              NaN
# 119092                        NaN        NaN              NaN
# 119098                        NaN        NaN              NaN
# 119100                        NaN        NaN              NaN
# 119102                        NaN        NaN              NaN
# 119103                        NaN        NaN              NaN
#
#        c_reactive_protein c_reactive_protein_delay               ethnicity  \
# 8                                                  SEPSIS       M
# 9                                          UNABLE TO WALK       F
# 10                                      CARDIOGENIC SHOCK       F
# 11                                        NAUSEA,VOMITING       F
# 12                           LOWER GASTROINTESTINAL BLEED       M
# 13                                               S/P FALL       F
# 14       CONGESTIVE HEART FAILURE\CARDIAC CATHETERIZATION       F
# 15      CRITICAL AORTIC STENOSIS;CARDIOGENICSHOCK;CONG...       M
# 16      ALCHOLIC CIRRHOSIS\EGD ** REMOTE EAST STONEMAN...       M
# 17                               TRACHEOBRONCHIAL MALASIA       F
# 18                               SEPSIS;RESPITORY FAILURE       M
# 19                                       HYPONATREMIA;PNA       M
# 20      MITRAL VALVE INSUFFICENCY\MITRAL VALVE REPLACE...       M
# 21         FEVER;RULE-OUT MYOCARDIAL INFARCTION;TELEMETRY       F
# 22                                     ACUTE PANCREATITIS       M
# 23                                            PERITONITIS       F
# 24                           UPPER GASTROINTESTINAL BLEED       M
# 25                                  ALTERED MENTAL STATUS       F
# 26                            TRACHEO-BRONCHO MALACEA/SDA       F
# 27                                              PNEUMONIA       M
# 28                                               OVERDOSE       F
# 29                                         UPPER GI BLEED       F
# ...                                                   ...     ...
# 118944                                          PNEUMONIA       M
# 118945                                              FEVER       M
# 118950                                          HEMATURIA       M
# 118953                           DIAPGAHAMATIV HERNIA/SDA       F
# 118963                         INTRA ABDOMINAL HEMORRHAGE       F
# 118980                                CHOLEDOCHOLITHIASIS       F
# 118982                    HYPOTENSION;ACUTE RENAL FAILURE       M
# 118987                                        CHOLANGITIS       F
# 118990                                           FRACTURE       F
# 118994                           CONGESTIVE HEART FAILURE       F
# 119000                           RETROPERITONEAL HEMATOMA       M
# 119001                      PNEUMONIA;RESPIRATORY FAILURE       M
# 119005                             ISCHEMIC ARM;TELEMETRY       F
# 119007                          SEPSIS;ICD LEAD INFECTION       M
# 119008                                     UPPER GI BLEED       F
# 119017                       HEPATACELLULAR CARCINOMA/SDA       M
# 119042                                       PANCREATITIS       M
# 119046                                 CHOLEDOCOLITHIASIS       F
# 119051                                 STATUS EPILEPTICUS       M
# 119068                           CONGESTIVE HEART FAILURE       F
# 119071                                         CHEST PAIN       M
# 119075                           LEFT MAIN ARTERY DISEASE       F
# 119081                     LEFT LOWER EXTREMITY ULCER/SDA       F
# 119082                                           WEAKNESS       M
# 119083                                  PULMONAY EMBOLISM       M
# 119092                                            COLITIS       F
# 119098                                    ETOH WITHDRAWAL       F
# 119100                              MYOCARDIAL INFARCTION       F
# 119102                                     SZ/HYPOTENSION       M
# 119103                                 RIGHT HIP FRACTURE       F
#
# [115717 rows x 62 columns]

# %% [markdown]
# ## 8. Create labels for evolution of creatinine
# - The models would be used around 6a.m., when the team for the day begins to work
# - The prediction would concern the values of creatinine the next day (how it will have evolved after 20-24 hours)
# - Therefore, we take into account only measurements of creatinine performed between midnight and 5am, and consider the "next day" is "next day between midnight and 5am"

# %%
merged_df = pd.read_csv('creatinine_measurements_merged.csv').drop('Unnamed: 0',axis=1)

# %%
# Keep only creatinine measured between 0am and 5am
merged_df.loc[:,'creatinine_hour'] = merged_df['creatinine_time'].astype('datetime64[ns]').apply(lambda x: x.hour)
merged_df = merged_df.loc[((merged_df['creatinine_hour']>=0) & (merged_df['creatinine_hour']<=5)) ,:]

# %%
# In each row, report values of creatinine for next day and days before
merged_df.loc[:,'creatinine_time'] = merged_df.loc[:,'creatinine_time'].astype('datetime64[ns]')
for i, row in merged_df.iterrows():
    same_stay = merged_df.loc[merged_df['icustay_id']==row['icustay_id'],:]
    delay = (same_stay['creatinine_time']-row['creatinine_time']).apply(lambda x: x.days)
    merged_df.loc[i,'creatinine_tomorrow'] =same_stay.loc[delay==1,'creatinine'].max()
    merged_df.loc[i,'creatinine_yesterday'] =same_stay.loc[delay==-1,'creatinine'].max()
    merged_df.loc[i,'creatinine_before_yesterday'] =same_stay.loc[delay==-2,'creatinine'].max()

# %%
def create_labels(diff):
    if diff>0.15 :
        return 0
    elif diff<-0.15 :
        return 1
    elif math.isnan(diff):
        return None
    else:
        return 2

merged_df.loc[:,'creatinine_diff'] = merged_df['creatinine_tomorrow']-merged_df['creatinine']
merged_df.loc[:,'label'] = merged_df['creatinine_diff'].apply(create_labels)

# Drop NaN labels (lines with no "creatinine_tomorrow")
merged_df = merged_df.dropna(subset=['label'])
print(merged_df)
# Out:
#         subject_id  icustay_id  creatinine     creatinine_time         age  \
# 0            77815      239231         0.6 2166-09-21 03:21:00   58.363217
# 1            31558      249349         0.6 2150-07-17 01:36:00   52.688716
# 8            60897      282836         2.0 2188-09-29 04:04:00   67.864024
# 12           85141      251157         0.7 2129-01-08 05:17:00   72.399244
# 16           27172      248284         1.4 2109-08-29 04:34:00   53.707219
# 17           55672      224244         0.6 2167-10-17 04:03:00   55.968185
# 21           13806      215159         0.8 2125-03-14 03:36:00   72.826190
# 22           98196      246311         1.0 2134-09-27 00:50:00   74.303777
# 24           81232      241161         0.9 2176-07-06 04:15:00   80.477997
# 29           48833      266634         0.5 2165-04-28 01:59:00   60.185586
# 32           44851      226614         0.2 2193-12-17 05:54:00   37.302500
# 36           90208      244844         1.3 2168-03-04 03:05:00   76.448056
# 37           49658      218951         2.0 2145-07-27 02:41:00   60.681446
# 39           98435      243733         1.2 2129-12-18 05:40:00   87.571230
# 50           13373      286016         1.2 2203-08-24 05:53:00   54.846120
# 53           44941      285812         1.1 2184-08-01 03:58:00   78.251681
# 54           86145      250364         0.7 2113-04-05 03:24:00   48.107077
# 61           51045      221224         1.0 2119-09-09 04:01:00   79.111278
# 65           27157      247368         0.7 2101-03-23 05:16:00   46.363775
# 66             345      260258         0.4 2169-05-22 02:19:00  300.003614
# 70           31190      292101         0.3 2124-03-04 02:27:00   76.587524
# 73           78076      257336         1.7 2113-08-03 04:51:00   70.273805
# 76           90658      274671         0.4 2177-10-13 01:40:00   34.313262
# 78           71848      221187         0.9 2198-06-13 03:00:00   43.102976
# 83           58634      240545         0.9 2104-03-14 05:11:00   64.189504
# 84           30252      228518         0.7 2130-07-01 04:09:00   53.158888
# 85           32658      255383         0.9 2143-05-14 03:20:00   48.308788
# 91                           108.0                            3420.0
# 98                           150.0                            3120.0
# ...                            ...                               ...
# 115598                         NaN                               NaN
# 115601                         NaN                               NaN
# 115602                         NaN                               NaN
# 115603                         NaN                               NaN
# 115609                         NaN                               NaN
# 115611                         NaN                               NaN
# 115616                         NaN                               NaN
# 115619                         NaN                               NaN
# 115623                         NaN                               NaN
# 115629                         NaN                               NaN
# 115636                         NaN                               NaN
# 115642                         NaN                               NaN
# 115643                         NaN                               NaN
# 115650                         NaN                               NaN
# 115653                         NaN                               NaN
# 115657                         NaN                               NaN
# 115662                         NaN                               NaN
# 115665                         NaN                               NaN
# 115666                         NaN                               NaN
# 115671                         NaN                               NaN
# 115674                         NaN                               NaN
# 115675                         NaN                               NaN
# 115677                         NaN                               NaN
# 115679                         NaN                               NaN
# 115681                         NaN                               NaN
# 115685                         NaN                               NaN
# 115703                         NaN                               NaN
# 115709                         NaN                               NaN
# 115711                         NaN                               NaN
# 115715                         NaN                               NaN
#
#         arterial_pressure_diastolic  arterial_pressure_diastolic_delay  \
# 0                              75.0                             1800.0
# 1                              75.0                             1440.0
# 8                              50.0                             4200.0
# 12                             74.0                               60.0
# 16                             75.0                              900.0
# 17                             62.0                             2820.0
# 21                             41.0                             2280.0
# 22                             79.0                             1860.0
# 24                             48.0                              540.0
# 29                             74.0                              240.0
# 32                             59.0                             2820.0
# 36                             49.0                             1800.0
# 37                             50.0                             1620.0
# 39                             50.0                              600.0
# 50                             64.0                             2580.0
# 53                             51.0                             1020.0
# 54                             52.0                              240.0
# 61                             45.0                             5580.0
# 65                             73.0                             2460.0
# 66                             63.0                             1620.0
# 70                             79.0                             1440.0
# 73                             70.0                             2520.0
# 76                             60.0                             6060.0
# 78                             69.0                             3240.0
# 83                             70.0                              240.0
# 84                             68.0                              420.0
# 85                             42.0                             1080.0
# 87                             59.0                             1620.0
# 91                             62.0                             3420.0
# 98                             58.0                             3120.0
# ...                             ...                                ...
# 115598                          NaN                                NaN
# 115601                          NaN                                NaN
# 115602                          NaN                                NaN
# 115603                          NaN                                NaN
# 115609                          NaN                                NaN
# 115611                          NaN                                NaN
# 115616                          NaN                                NaN
# 115619                          NaN                                NaN
# 115623                          NaN                                NaN
# 115629                          NaN                                NaN
# 115636                          NaN                                NaN
# 115642                          NaN                                NaN
# 115643                          NaN                                NaN
# 115650                          NaN                                NaN
# 115653                          NaN                                NaN
# 115657                          NaN                                NaN
# 115662                          NaN                                NaN
# 115665                          NaN                                NaN
# 115666                          NaN                                NaN
# 115671                          NaN                                NaN
# 115674                          NaN                                NaN
# 115675                          NaN                                NaN
# 115677                          NaN                                NaN
# 115679                          NaN                                NaN
# 115681                          NaN                                NaN
# 115685                          NaN                                NaN
# 115703                          NaN                                NaN
# 115709                          NaN                                NaN
# 115711                          NaN                                NaN
# 115715                          NaN                                NaN
#
#         heart_rate  ...    c_reactive_protein_delay  \
# 0             58.0  ...                         NaN
# 1            102.0  ...                         NaN
# 8            104.0  ...                         NaN
# 12           103.0  ...                         NaN
# 16            67.0  ...                         NaN
# 17           123.0  ...                         NaN
# 21           101.0  ...                         NaN
# 22           103.0  ...                         NaN
# 24            86.0  ...                         NaN
# 29            93.0  ...                         NaN
# 32            69.0  ...                         NaN
# 36            77.0  ...                         NaN
# 37            77.0  ...                         NaN
# 39            72.0  ...                         NaN
# 50            55.0  ...                         NaN
# 53            91.0  ...                         NaN
# 54            80.0  ...                         NaN
# 61            86.0  ...                         NaN
# 65            75.0  ...                         NaN
# 66            80.0  ...                         NaN
# 70           119.0  ...                         NaN
# 73            86.0  ...                    919920.0
# 76           102.0  ...                         NaN
# 78           107.0  ...                         NaN
# 83            82.0  ...                         NaN
# 84            84.0  ...                    149940.0
# 85           110.0  ...                         NaN
# 87            91.0  ...                         NaN
# 91            99.0  ...                         NaN
# 98            85.0  ...                         NaN
# ...            ...  ...                         ...
# 115598         NaN  ...                         NaN
# 115601         NaN  ...                         NaN
# 115602         NaN  ...                         NaN
# 115603         NaN  ...                         NaN
# 115609         NaN  ...                         NaN
# 115611         NaN  ...                         NaN
# 115616         NaN  ...                         NaN
# 115619         NaN  ...                         NaN
# 115623         NaN  ...                         NaN
# 115629         NaN  ...                         NaN
# 115636         NaN  ...                         NaN
# 115642         NaN  ...                         NaN
# 115643         NaN  ...                         NaN
# 115650         NaN  ...                         NaN
# 115653         NaN  ...                         NaN
# 115657         NaN  ...                         NaN
# 115662         NaN  ...                         NaN
# 115665         NaN  ...                         NaN
# 115666         NaN  ...                         NaN
# 115671         NaN  ...                         NaN
# 115674         NaN  ...                         NaN
# 115675         NaN  ...                         NaN
# 115677         NaN  ...                         NaN
# 115679         NaN  ...                         NaN
# 115681         NaN  ...                         NaN
# 115685         NaN  ...                         NaN
# 115703         NaN  ...                         NaN
# 115709         NaN  ...                         NaN
# 115711         NaN  ...                         NaN
# 115715         NaN  ...                         NaN
#
#                           ethnicity  \
# 0                             WHITE
# 1                             WHITE
# 8                             WHITE
# 12                            WHITE
# 16                            WHITE
# 17                            WHITE
# 21                            WHITE
# 22                 UNABLE TO OBTAIN
# 24                            WHITE
# 29                            OTHER
# 32           BLACK/AFRICAN AMERICAN
# 36            UNKNOWN/NOT SPECIFIED
# 37           BLACK/AFRICAN AMERICAN
# 39                            WHITE
# 50                            WHITE
# 53                            WHITE
# 54                 UNABLE TO OBTAIN
# 61                            WHITE
# 65      HISPANIC/LATINO - DOMINICAN
# 66               HISPANIC OR LATINO
# 70                            WHITE
# 73                              NaN
# 76                            OTHER
# 78                            WHITE
# 83                            WHITE
# 84                            WHITE
# 85       PATIENT DECLINED TO ANSWER
# 87           BLACK/AFRICAN AMERICAN
# 91                            WHITE
# 98                            WHITE
# ...                             ...
# 115598             UNABLE TO OBTAIN
# 115601       BLACK/AFRICAN AMERICAN
# 115602                        ASIAN
# 115603                        ASIAN
# 115609       BLACK/AFRICAN AMERICAN
# 115611       BLACK/AFRICAN AMERICAN
# 115616                        WHITE
# 115619           HISPANIC OR LATINO
# 115623                        WHITE
# 115629                        WHITE
# 115636                        WHITE
# 115642                        WHITE
# 115643                        WHITE
# 115650                        WHITE
# 115653                        WHITE
# 115657             UNABLE TO OBTAIN
# 115662                        WHITE
# 115665                        WHITE
# 115666                        WHITE
# 115671             UNABLE TO OBTAIN
# 115674                        WHITE
# 115675                        WHITE
# 115677                        WHITE
# 115679           HISPANIC OR LATINO
# 115681                        WHITE
# 115685                        WHITE
# 115703                        WHITE
# 115709             UNABLE TO OBTAIN
# 115711                        WHITE
# 115715                        WHITE
#
#                                                 diagnosis  gender  \
# 0                                 INTRACRANIAL HEMORRHAGE       M
# 1                                    S/P BOATING ACCIDENT       M
# 8                                                  SEPSIS       M
# 12                           LOWER GASTROINTESTINAL BLEED       M
# 16      ALCHOLIC CIRRHOSIS\EGD ** REMOTE EAST STONEMAN...       M
# 17                               TRACHEOBRONCHIAL MALASIA       F
# 21         FEVER;RULE-OUT MYOCARDIAL INFARCTION;TELEMETRY       F
# 22                                     ACUTE PANCREATITIS       M
# 24                           UPPER GASTROINTESTINAL BLEED       M
# 29                                         UPPER GI BLEED       F
# 32                                             BRAIN METS       F
# 36                                   NECROTIZING FASCITIS       F
# 37                                      AORTIC DISSECTION       M
# 39                                                 SEPSIS       F
# 50                                  ALTERED MENTAL STATUS       M
# 53                                       BILE DUCT INJURY       F
# 54                                      SEPSIS;CELLULITIS       M
# 61                        LEFT HIP AVASCULAR NECROSIS/SDA       F
# 65                                INTRACRANIAL HEMORRHAGE       M
# 66                                  ALTERED MENTAL STATUS       F
# 70                                SUBARACHNOID HEMORRHAGE       F
# 73                                                    NaN     NaN
# 76                                           PANCREATITIS       F
# 78       MOTOR VEHICLE ACCIDENT WITH UNSPECIFIED INJURIES       M
# 83                                   UGIB;PANCREATIC MASS       M
# 84           CONGESTIVE HEART FAILURE;ACUTE RENAL FAILURE       F
# 85                                         VARICEAL BLEED       M
# 87                                            CHOLANGITIS       M
# 91      MITRAL REGURGITATION\MITRAL VALVE REPLACEMENT ...       F
# 98                         S/P COLON RESECTION; ?ISCHEMIA       M
# ...                                                   ...     ...
# 115598   CORONARY ARTERY DISEASE;CONGESTIVE HEART FAILURE       F
# 115601                             HYPERGLYCEMIA,SEIZURES       M
# 115602                                         HEMOPTYSIS       M
# 115603                                         LIVER MASS       M
# 115609                              ALTERED MENTAL STATUS       M
# 115611                                         CHEST PAIN       M
# 115616                                             SEPSIS       F
# 115619                           DIAPGAHAMATIV HERNIA/SDA       F
# 115623                                     UPPER GI BLEED       M
# 115629                               PERICARDIAL EFFUSION       F
# 115636                                     LOWER GI BLEED       F
# 115642                                  SUBDURAL HEMATOMA       M
# 115643                                     LOWER GI BLEED       M
# 115650  JAUNDICE, GASTRIC CANCER; PERCUTANROUS TRANSHE...       M
# 115653                             HEPATIC ENCEPHALOPATHY       F
# 115657                            INTRACRANIAL HEMORRHAGE       M
# 115662                                            SEIZURE       F
# 115665                             LIVER FAILURE AND SIRS       M
# 115666                              DIABETIC KETOACIDOSIS       M
# 115671                                 SUBURAL HEMORRHAGE       M
# 115674                                         CHEST PAIN       M
# 115675                                             SEPSIS       F
# 115677                         S/P MOTOR VEHICLE ACCIDEMT       M
# 115679                           DIAPGAHAMATIV HERNIA/SDA       F
# 115681                            SUBARRACHNOID HEMMORAGE       M
# 115685                       UPPER GASTROINTESTINAL BLEED       F
# 115703                                       PANCREATITIS       M
# 115709                     LEFT LOWER EXTREMITY ULCER/SDA       F
# 115711                                  PULMONAY EMBOLISM       M
# 115715                                     SZ/HYPOTENSION       M
#
#         creatinine_hour  creatinine_tomorrow  creatinine_yesterday  \
# 0                     3                  0.6                   NaN
# 1                     1                  0.6                   0.6
# 8                     4                  1.6                   1.9
# 12                    5                  0.6                   NaN
# 16                    4                  1.4                   NaN
# 17                    4                  0.7                   0.7
# 21                    3                  0.9                   NaN
# 22                    0                  1.1                   1.3
# 24                    4                  0.8                   NaN
# 29                    1                  0.5                   NaN
# 32                    5                  0.2                   NaN
# 36                    3                  1.1                   1.7
# 37                    2                  2.0                   2.1
# 39                    5                  1.4                   NaN
# 50                    5                  1.0                   NaN
# 53                    3                  1.3                   NaN
# 54                    3                  0.7                   0.8
# 61                    4                  1.1                   0.7
# 65                    5                  0.5                   NaN
# 66                    2                  0.4                   NaN
# 70                    2                  0.3                   0.4
# 73                    4                  2.0                   1.8
# 76                    1                  0.4                   0.5
# 78                    3                  0.9                   0.9
# 83                    5                  1.0                   NaN
# 84                    4                  0.7                   NaN
# 85                    3                  1.2                   NaN
# 87                    5                  0.8                   0.6
# 91                    3                  0.4                   NaN
# 98                    3                  1.0                   NaN
# ...                 ...                  ...                   ...
# 115598                0                  1.8                   NaN
# 115601                4                  2.4                   NaN
# 115602                4                  0.6                   NaN
# 115603                4                  2.4                   NaN
# 115609                5                  1.6                   NaN
# 115611                3                  6.0                   NaN
# 115616                5                  0.7                   NaN
# 115619                5                  0.5                   NaN
# 115623                4                  1.8                   NaN
# 115629                5                  0.5                   NaN
# 115636                5                  0.5                   NaN
# 115642                3                  0.8                   NaN
# 115643                1                  1.0                   NaN
# 115650                3                  0.7                   NaN
# 115653                0                  1.5                   NaN
# 115657                1                  0.9                   NaN
# 115662                3                  0.3                   NaN
# 115665                5                  1.0                   NaN
# 115666                0                  1.0                   NaN
# 115671                0                  1.8                   NaN
# 115674                2                  0.8                   NaN
# 115675                0                  0.5                   NaN
# 115677                4                  1.0                   NaN
# 115679                5                  0.5                   NaN
# 115681                3                  1.1                   0.9
# 115685                0                  0.7                   NaN
# 115703                5                  2.0                   NaN
# 115709                5                  3.2                   NaN
# 115711                4                  0.7                   NaN
# 115715                5                  0.5                   NaN
#
#         creatinine_before_yesterday  creatinine_diff  label
# 0                               0.7              0.0    2.0
# 1                               0.6              0.0    2.0
# 8                               NaN             -0.4    1.0
# 12                              NaN             -0.1    2.0
# 16                              1.3              0.0    2.0
# 17                              NaN              0.1    2.0
# 21                              0.8              0.1    2.0
# 22                              NaN              0.1    2.0
# 24                              NaN             -0.1    2.0
# 29                              NaN              0.0    2.0
# 32                              0.1              0.0    2.0
# 36                              NaN             -0.2    1.0
# 37                              2.6              0.0    2.0
# 39                              NaN              0.2    0.0
# 50                              NaN             -0.2    1.0
# 50                           104.0                            2580.0
# 53                           128.0                            1020.0
# 54                            98.0                             240.0
# 61                            93.0                            5580.0
# 65                           125.0                            2460.0
# 66                           136.0                            1620.0
# 70                           155.0                            1440.0
# 73                           120.0                            2520.0
# 76                           109.0                            6060.0
# 78                           123.0                            3240.0
# 83                           164.0                             240.0
# 84                           103.0                             420.0
# 85                            84.0                            1080.0
# 87                           143.0                            1620.0
# 91                           108.0                            3420.0
# 98                           150.0                            3120.0
# ...                            ...                               ...
# 115598                         NaN                               NaN
# 115601                         NaN                               NaN
# 115602                         NaN                               NaN
# 115603                         NaN                               NaN
# 115609                         NaN                               NaN
# 115611                         NaN                               NaN
# 115616                         NaN                               NaN
# 115619                         NaN                               NaN
# 115623                         NaN                               NaN
# 115629                         NaN                               NaN
# 115636                         NaN                               NaN
# 115642                         NaN                               NaN
# 115643                         NaN                               NaN
# 115650                         NaN                               NaN
# 115653                         NaN                               NaN
# 115657                         NaN                               NaN
# 115662                         NaN                               NaN
# 115665                         NaN                               NaN
# 115666                         NaN                               NaN
# 115671                         NaN                               NaN
# 115674                         NaN                               NaN
# 115675                         NaN                               NaN
# 115677                         NaN                               NaN
# 115679                         NaN                               NaN
# 115681                         NaN                               NaN
# 115685                         NaN                               NaN
# 115703                         NaN                               NaN
# 115709                         NaN                               NaN
# 115711                         NaN                               NaN
# 115715                         NaN                               NaN
#
#         arterial_pressure_diastolic  arterial_pressure_diastolic_delay  \
# 0                              75.0                             1800.0
# 1                              75.0                             1440.0
# 8                              50.0                             4200.0
# 12                             74.0                               60.0
# 16                             75.0                              900.0
# 17                             62.0                             2820.0
# 21                             41.0                             2280.0
# 22                             79.0                             1860.0
# 24                             48.0                              540.0
# 29                             74.0                              240.0
# 32                             59.0                             2820.0
# 36                             49.0                             1800.0
# 37                             50.0                             1620.0
# 39                             50.0                              600.0
# 50                             64.0                             2580.0
# 53                             51.0                             1020.0
# 54                             52.0                              240.0
# 61                             45.0                             5580.0
# 65                             73.0                             2460.0
# 66                             63.0                             1620.0
# 70                             79.0                             1440.0
# 73                             70.0                             2520.0
# 76                             60.0                             6060.0
# 78                             69.0                             3240.0
# 83                             70.0                              240.0
# 84                             68.0                              420.0
# 85                             42.0                             1080.0
# 87                             59.0                             1620.0
# 91                             62.0                             3420.0
# 98                             58.0                             3120.0
# ...                             ...                                ...
# 115598                          NaN                                NaN
# 115601                          NaN                                NaN
# 115602                          NaN                                NaN
# 115603                          NaN                                NaN
# 115609                          NaN                                NaN
# 115611                          NaN                                NaN
# 115616                          NaN                                NaN
# 115619                          NaN                                NaN
# 115623                          NaN                                NaN
# 115629                          NaN                                NaN
# 115636                          NaN                                NaN
# 115642                          NaN                                NaN
# 115643                          NaN                                NaN
# 115650                          NaN                                NaN
# 115653                          NaN                                NaN
# 115657                          NaN                                NaN
# 115662                          NaN                                NaN
# 115665                          NaN                                NaN
# 115666                          NaN                                NaN
# 115671                          NaN                                NaN
# 115674                          NaN                                NaN
# 115675                          NaN                                NaN
# 115677                          NaN                                NaN
# 115679                          NaN                                NaN
# 115681                          NaN                                NaN
# 115685                          NaN                                NaN
# 115703                          NaN                                NaN
# 115709                          NaN                                NaN
# 115711                          NaN                                NaN
# 115715                          NaN                                NaN
#
#         heart_rate  ...    c_reactive_protein_delay  \
# 0             58.0  ...                         NaN
# 1            102.0  ...                         NaN
# 8            104.0  ...                         NaN
# 12           103.0  ...                         NaN
# 16            67.0  ...                         NaN
# 17           123.0  ...                         NaN
# 21           101.0  ...                         NaN
# 22           103.0  ...                         NaN
# 24            86.0  ...                         NaN
# 29            93.0  ...                         NaN
# 32            69.0  ...                         NaN
# 36            77.0  ...                         NaN
# 37            77.0  ...                         NaN
# 39            72.0  ...                         NaN
# 50            55.0  ...                         NaN
# 53            91.0  ...                         NaN
# 54            80.0  ...                         NaN
# 61            86.0  ...                         NaN
# 65            75.0  ...                         NaN
# 66            80.0  ...                         NaN
# 70           119.0  ...                         NaN
# 73            86.0  ...                    919920.0
# 76           102.0  ...                         NaN
# 78           107.0  ...                         NaN
# 83            82.0  ...                         NaN
# 84            84.0  ...                    149940.0
# 85           110.0  ...                         NaN
# 87            91.0  ...                         NaN
# 91            99.0  ...                         NaN
# 98            85.0  ...                         NaN
# ...            ...  ...                         ...
# 115598         NaN  ...                         NaN
# 115601         NaN  ...                         NaN
# 115602         NaN  ...                         NaN
# 115603         NaN  ...                         NaN
# 115609         NaN  ...                         NaN
# 115611         NaN  ...                         NaN
# 115616         NaN  ...                         NaN
# 115619         NaN  ...                         NaN
# 115623         NaN  ...                         NaN
# 115629         NaN  ...                         NaN
# 115636         NaN  ...                         NaN
# 115642         NaN  ...                         NaN
# 115643         NaN  ...                         NaN
# 115650         NaN  ...                         NaN
# 115653         NaN  ...                         NaN
# 115657         NaN  ...                         NaN
# 115662         NaN  ...                         NaN
# 115665         NaN  ...                         NaN
# 115666         NaN  ...                         NaN
# 115671         NaN  ...                         NaN
# 115674         NaN  ...                         NaN
# 115675         NaN  ...                         NaN
# 115677         NaN  ...                         NaN
# 115679         NaN  ...                         NaN
# 115681         NaN  ...                         NaN
# 115685         NaN  ...                         NaN
# 115703         NaN  ...                         NaN
# 115709         NaN  ...                         NaN
# 115711         NaN  ...                         NaN
# 115715         NaN  ...                         NaN
#
#                           ethnicity  \
# 0                             WHITE
# 1                             WHITE
# 8                             WHITE
# 12                            WHITE
# 16                            WHITE
# 17                            WHITE
# 21                            WHITE
# 22                 UNABLE TO OBTAIN
# 24                            WHITE
# 29                            OTHER
# 32           BLACK/AFRICAN AMERICAN
# 36            UNKNOWN/NOT SPECIFIED
# 37           BLACK/AFRICAN AMERICAN
# 39                            WHITE
# 50                            WHITE
# 53                            WHITE
# 54                 UNABLE TO OBTAIN
# 61                            WHITE
# 65      HISPANIC/LATINO - DOMINICAN
# 66               HISPANIC OR LATINO
# 70                            WHITE
# 73                              NaN
# 76                            OTHER
# 78                            WHITE
# 83                            WHITE
# 84                            WHITE
# 85       PATIENT DECLINED TO ANSWER
# 87           BLACK/AFRICAN AMERICAN
# 91                            WHITE
# 98                            WHITE
# ...                             ...
# 115598             UNABLE TO OBTAIN
# 115601       BLACK/AFRICAN AMERICAN
# 115602                        ASIAN
# 115603                        ASIAN
# 115609       BLACK/AFRICAN AMERICAN
# 115611       BLACK/AFRICAN AMERICAN
# 115616                        WHITE
# 115619           HISPANIC OR LATINO
# 115623                        WHITE
# 115629                        WHITE
# 115636                        WHITE
# 115642                        WHITE
# 115643                        WHITE
# 115650                        WHITE
# 115653                        WHITE
# 115657             UNABLE TO OBTAIN
# 115662                        WHITE
# 115665                        WHITE
# 115666                        WHITE
# 115671             UNABLE TO OBTAIN
# 115674                        WHITE
# 115675                        WHITE
# 115677                        WHITE
# 115679           HISPANIC OR LATINO
# 115681                        WHITE
# 115685                        WHITE
# 115703                        WHITE
# 115709             UNABLE TO OBTAIN
# 115711                        WHITE
# 115715                        WHITE
#
#                                                 diagnosis  gender  \
# 0                                 INTRACRANIAL HEMORRHAGE       M
# 1                                    S/P BOATING ACCIDENT       M
# 8                                                  SEPSIS       M
# 12                           LOWER GASTROINTESTINAL BLEED       M
# 16      ALCHOLIC CIRRHOSIS\EGD ** REMOTE EAST STONEMAN...       M
# 17                               TRACHEOBRONCHIAL MALASIA       F
# 21         FEVER;RULE-OUT MYOCARDIAL INFARCTION;TELEMETRY       F
# 22                                     ACUTE PANCREATITIS       M
# 24                           UPPER GASTROINTESTINAL BLEED       M
# 29                                         UPPER GI BLEED       F
# 32                                             BRAIN METS       F
# 36                                   NECROTIZING FASCITIS       F
# 37                                      AORTIC DISSECTION       M
# 39                                                 SEPSIS       F
# 50                                  ALTERED MENTAL STATUS       M
# 53                                       BILE DUCT INJURY       F
# 54                                      SEPSIS;CELLULITIS       M
# 61                        LEFT HIP AVASCULAR NECROSIS/SDA       F
# 65                                INTRACRANIAL HEMORRHAGE       M
# 66                                  ALTERED MENTAL STATUS       F
# 70                                SUBARACHNOID HEMORRHAGE       F
# 73                                                    NaN     NaN
# 76                                           PANCREATITIS       F
# 78       MOTOR VEHICLE ACCIDENT WITH UNSPECIFIED INJURIES       M
# 83                                   UGIB;PANCREATIC MASS       M
# 84           CONGESTIVE HEART FAILURE;ACUTE RENAL FAILURE       F
# 85                                         VARICEAL BLEED       M
# 87                                            CHOLANGITIS       M
# 91      MITRAL REGURGITATION\MITRAL VALVE REPLACEMENT ...       F
# 98                         S/P COLON RESECTION; ?ISCHEMIA       M
# ...                                                   ...     ...
# 115598   CORONARY ARTERY DISEASE;CONGESTIVE HEART FAILURE       F
# 115601                             HYPERGLYCEMIA,SEIZURES       M
# 115602                                         HEMOPTYSIS       M
# 115603                                         LIVER MASS       M
# 115609                              ALTERED MENTAL STATUS       M
# 115611                                         CHEST PAIN       M
# 115616                                             SEPSIS       F
# 115619                           DIAPGAHAMATIV HERNIA/SDA       F
# 115623                                     UPPER GI BLEED       M
# 115629                               PERICARDIAL EFFUSION       F
# 115636                                     LOWER GI BLEED       F
# 115642                                  SUBDURAL HEMATOMA       M
# 115643                                     LOWER GI BLEED       M
# 115650  JAUNDICE, GASTRIC CANCER; PERCUTANROUS TRANSHE...       M
# 115653                             HEPATIC ENCEPHALOPATHY       F
# 115657                            INTRACRANIAL HEMORRHAGE       M
# 115662                                            SEIZURE       F
# 115665                             LIVER FAILURE AND SIRS       M
# 115666                              DIABETIC KETOACIDOSIS       M
# 115671                                 SUBURAL HEMORRHAGE       M
# 115674                                         CHEST PAIN       M
# 115675                                             SEPSIS       F
# 115677                         S/P MOTOR VEHICLE ACCIDEMT       M
# 115679                           DIAPGAHAMATIV HERNIA/SDA       F
# 115681                            SUBARRACHNOID HEMMORAGE       M
# 115685                       UPPER GASTROINTESTINAL BLEED       F
# 115703                                       PANCREATITIS       M
# 115709                     LEFT LOWER EXTREMITY ULCER/SDA       F
# 115711                                  PULMONAY EMBOLISM       M
# 115715                                     SZ/HYPOTENSION       M
#
#         creatinine_hour  creatinine_tomorrow  creatinine_yesterday  \
# 0                     3                  0.6                   NaN
# 1                     1                  0.6                   0.6
# 8                     4                  1.6                   1.9
# 12                    5                  0.6                   NaN
# 16                    4                  1.4                   NaN
# 17                    4                  0.7                   0.7
# 21                    3                  0.9                   NaN
# 22                    0                  1.1                   1.3
# 24                    4                  0.8                   NaN
# 29                    1                  0.5                   NaN
# 32                    5                  0.2                   NaN
# 36                    3                  1.1                   1.7
# 37                    2                  2.0                   2.1
# 39                    5                  1.4                   NaN
# 50                    5                  1.0                   NaN
# 53                    3                  1.3                   NaN
# 54                    3                  0.7                   0.8
# 61                    4                  1.1                   0.7
# 65                    5                  0.5                   NaN
# 66                    2                  0.4                   NaN
# 70                    2                  0.3                   0.4
# 73                    4                  2.0                   1.8
# 76                    1                  0.4                   0.5
# 78                    3                  0.9                   0.9
# 83                    5                  1.0                   NaN
# 84                    4                  0.7                   NaN
# 85                    3                  1.2                   NaN
# 87                    5                  0.8                   0.6
# 91                    3                  0.4                   NaN
# 98                    3                  1.0                   NaN
# ...                 ...                  ...                   ...
# 115598                0                  1.8                   NaN
# 115601                4                  2.4                   NaN
# 115602                4                  0.6                   NaN
# 115603                4                  2.4                   NaN
# 115609                5                  1.6                   NaN
# 115611                3                  6.0                   NaN
# 115616                5                  0.7                   NaN
# 115619                5                  0.5                   NaN
# 115623                4                  1.8                   NaN
# 115629                5                  0.5                   NaN
# 115636                5                  0.5                   NaN
# 115642                3                  0.8                   NaN
# 115643                1                  1.0                   NaN
# 115650                3                  0.7                   NaN
# 115653                0                  1.5                   NaN
# 115657                1                  0.9                   NaN
# 115662                3                  0.3                   NaN
# 115665                5                  1.0                   NaN
# 115666                0                  1.0                   NaN
# 115671                0                  1.8                   NaN
# 115674                2                  0.8                   NaN
# 115675                0                  0.5                   NaN
# 115677                4                  1.0                   NaN
# 115679                5                  0.5                   NaN
# 115681                3                  1.1                   0.9
# 115685                0                  0.7                   NaN
# 115703                5                  2.0                   NaN
# 115709                5                  3.2                   NaN
# 115711                4                  0.7                   NaN
# 115715                5                  0.5                   NaN
#
#         creatinine_before_yesterday  creatinine_diff  label
# 0                               0.7              0.0    2.0
# 1                               0.6              0.0    2.0
# 8                               NaN             -0.4    1.0
# 12                              NaN             -0.1    2.0
# 16                              1.3              0.0    2.0
# 17                              NaN              0.1    2.0
# 21                              0.8              0.1    2.0
# 22                              NaN              0.1    2.0
# 24                              NaN             -0.1    2.0
# 29                              NaN              0.0    2.0
# 32                              0.1              0.0    2.0
# 36                              NaN             -0.2    1.0
# 37                              2.6              0.0    2.0
# 39                              NaN              0.2    0.0
# 50                              NaN             -0.2    1.0
# 53                              1.3              0.2    0.0
# 54                              NaN              0.0    2.0
# 61                              0.7              0.1    2.0
# 65                              0.5             -0.2    1.0
# 66                              NaN              0.0    2.0
# 70                              NaN              0.0    2.0
# 73                              1.8              0.3    0.0
# 76                              0.4              0.0    2.0
# 78                              0.8              0.0    2.0
# 83                              1.0              0.1    2.0
# 84                              0.9              0.0    2.0
# 85                              0.4              0.3    0.0
# 87                              0.8              0.2    0.0
# 91                              0.6             -0.1    2.0
# 98                              2.0             -0.6    1.0
# ...                             ...              ...    ...
# 115598                          NaN              0.4    0.0
# 115601                          NaN              0.0    2.0
# 115602                          NaN             -0.2    1.0
# 115603                          2.4              0.1    2.0
# 115609                          NaN              0.2    0.0
# 115611                          NaN              1.2    0.0
# 115616                          NaN             -0.2    1.0
# 115619                          NaN             -0.1    2.0
# 115623                          NaN             -0.5    1.0
# 115629                          NaN             -0.1    2.0
# 115636                          NaN             -0.1    2.0
# 115642                          0.9             -0.1    2.0
# 115643                          NaN             -0.6    1.0
# 115650                          NaN              0.1    2.0
# 115653                          NaN              0.3    0.0
# 115657                          NaN              0.1    2.0
# 115662                          NaN             -0.1    2.0
# 115665                          0.9             -0.1    2.0
# 115666                          NaN             -0.6    1.0
# 115671                          NaN              0.5    0.0
# 115674                          NaN             -0.1    2.0
# 115675                          NaN             -0.2    1.0
# 115677                          NaN             -0.5    1.0
# 115679                          0.6              0.0    2.0
# 115681                          NaN              0.0    2.0
# 115685                          NaN             -0.4    1.0
# 115703                          NaN             -0.3    1.0
# 115709                          NaN             -0.2    1.0
# 115711                          NaN             -0.1    2.0
# 115715                          NaN             -0.2    1.0
#
# [36251 rows x 68 columns]

# %%
# Remove features that are not labels
to_remove = ['creatinine_time','creatinine_hour','creatinine_tomorrow','creatinine_diff']
for c in to_remove:
    if (c in merged_df.columns.values): merged_df = merged_df.drop(c,axis=1)
print(merged_df.columns)
# Out:
# Index(['subject_id', 'icustay_id', 'creatinine', 'age',
#        'arterial_pressure_systolic', 'arterial_pressure_systolic_delay',
#        'arterial_pressure_diastolic', 'arterial_pressure_diastolic_delay',
#        'heart_rate', 'heart_rate_delay', 'weight_daily', 'weight_daily_delay',
#        'temperature', 'temperature_delay', 'urine_output',
#        'urine_output_delay', 'day_urine_output', 'day_urine_output_delay',
#        'scr', 'scr_delay', 'sodium', 'sodium_delay', 'potassium',
#        'potassium_delay', 'calcium', 'calcium_delay', 'phosphor',
#        'phosphor_delay', 'hemoglobine', 'hemoglobine_delay', 'uric_acid',
#        'uric_acid_delay', 'chloride', 'chloride_delay', 'platelet_count',
#        'platelet_count_delay', 'ph_blood', 'ph_blood_delay', 'fibrinogen',
#        'fibrinogen_delay', 'urinary_sodium', 'urinary_sodium_delay',
#        'urinary_potassium', 'urinary_potassium_delay', 'urine_creatinin',
#        'urine_creatinin_delay', 'alkaline_phospatase',
#        'alkaline_phospatase_delay', 'total_protein_blood',
#        'total_protein_blood_delay', 'albumin', 'albumin_delay',
#        'total_protein_urine', 'total_protein_urine_delay', 'bilirubin',
#        'bilirubin_delay', 'c_reactive_protein', 'c_reactive_protein_delay',
#        'ethnicity', 'diagnosis', 'gender', 'creatinine_yesterday',
#        'creatinine_before_yesterday', 'label'],
#       dtype='object')

# %%
# Dump to file
merged_df.to_csv('dataset_with_labels.csv')
print(merged_df)
# Out:
#         subject_id  icustay_id  creatinine         age  \
# 0            77815      239231         0.6   58.363217
# 1            31558      249349         0.6   52.688716
# 8            60897      282836         2.0   67.864024
# 12           85141      251157         0.7   72.399244
# 16           27172      248284         1.4   53.707219
# 17           55672      224244         0.6   55.968185
# 21           13806      215159         0.8   72.826190
# 22           98196      246311         1.0   74.303777
# 24           81232      241161         0.9   80.477997
# 29           48833      266634         0.5   60.185586
# 32           44851      226614         0.2   37.302500
# 36           90208      244844         1.3   76.448056
# 37           49658      218951         2.0   60.681446
# 39           98435      243733         1.2   87.571230
# 50           13373      286016         1.2   54.846120
# 53           44941      285812         1.1   78.251681
# 54           86145      250364         0.7   48.107077
# 61           51045      221224         1.0   79.111278
# 65           27157      247368         0.7   46.363775
# 66             345      260258         0.4  300.003614
# 70           31190      292101         0.3   76.587524
# 73           78076      257336         1.7   70.273805
# 76           90658      274671         0.4   34.313262
# 78           71848      221187         0.9   43.102976
# 83           58634      240545         0.9   64.189504
# 84           30252      228518         0.7   53.158888
# 85           32658      255383         0.9   48.308788
# 87           66010      279038         0.6   87.218543
# 91           46373      279248         0.5   49.869439
# 98           57572      284176         1.6   78.309437
# ...            ...         ...         ...         ...
# 115598       85464      265824         1.4   80.699900
# 115601       73280      214569         2.4   72.979364
# 115602       71924      261563         0.8   55.859029
# 115603       65312      284210         2.3   84.385093
# 115609       58685      204958         1.4   57.543256
# 115611       95013      268226         4.8   85.921373
# 115616       56149      237256         0.9   84.659509
# 115619       86239      290213         0.6   69.748082
# 115623       50822      211130         2.3   52.502716
# 115629       77665      257471         0.6   70.546936
# 115636       64297      276768         0.6   68.586750
# 115642       92105      294698         0.9   45.142635
# 115643       32332      292202         1.6   61.781009
# 115650       55111      234285         0.6   80.152688
# 115653       70926      246840         1.2   54.969004
# 115657       50178      236402         0.8   77.469236
# 115662       78260      264143         0.4   43.600186
# 115665       83728      295560         1.1   54.758174
# 115666       87135      226893         1.6   55.915892
# 115671       71698      246272         1.3   72.940619
# 115674       82132      235756         0.9   59.070586
# 115675       75737      218085         0.7   77.811378
# 115677       59980      290237         1.5   24.398028
# 115679       86239      290213         0.5   69.748082
# 115681       31202      294451         1.1   50.064700
# 115685       64772      275393         1.1   53.682147
# 115703       74291      263109         2.3   66.687902
# 115709       58576      279323         3.4   86.474806
# 115711       76126      273038         0.8   79.832095
# 115715       64197      244278         0.7   79.186400
#
#         arterial_pressure_systolic  arterial_pressure_systolic_delay  \
# 0                            155.0                            1800.0
# 1                            165.0                            1440.0
# 8                             84.0                            4200.0
# 12                           120.0                              60.0
# 16                           144.0                             900.0
# 17                           116.0                            2820.0
# 21                            95.0                            2280.0
# 22                           148.0                            1860.0
# 24                            88.0                             540.0
# 29                           132.0                             240.0
# 32                            96.0                            2820.0
# 36                           151.0                            1800.0
# 37                           135.0                            1680.0
# 39                           127.0                             600.0
# 50                           104.0                            2580.0
# 53                           128.0                            1020.0
# 54                            98.0                             240.0
# 61                            93.0                            5580.0
# 65                           125.0                            2460.0
# 66                           136.0                            1620.0
# 70                           155.0                            1440.0
# 73                           120.0                            2520.0
# 76                           109.0                            6060.0
# 78                           123.0                            3240.0
# 83                           164.0                             240.0
# 84                           103.0                             420.0
# 85                            84.0                            1080.0
# 87                           143.0                            1620.0
# 91                           108.0                            3420.0
# 98                           150.0                            3120.0
# ...                            ...                               ...
# 115598                         NaN                               NaN
# 115601                         NaN                               NaN
# 115602                         NaN                               NaN
# 115603                         NaN                               NaN
# 115609                         NaN                               NaN
# 115611                         NaN                               NaN
# 115616                         NaN                               NaN
# 115619                         NaN                               NaN
# 115623                         NaN                               NaN
# 115629                         NaN                               NaN
# 115636                         NaN                               NaN
# 115642                         NaN                               NaN
# 115643                         NaN                               NaN
# 115650                         NaN                               NaN
# 115653                         NaN                               NaN
# 115657                         NaN                               NaN
# 115662                         NaN                               NaN
# 115665                         NaN                               NaN
# 115666                         NaN                               NaN
# 115671                         NaN                               NaN
# 115674                         NaN                               NaN
# 115675                         NaN                               NaN
# 115677                         NaN                               NaN
# 115679                         NaN                               NaN
# 115681                         NaN                               NaN
# 115685                         NaN                               NaN
# 115703                         NaN                               NaN
# 115709                         NaN                               NaN
# 115711                         NaN                               NaN
# 115715                         NaN                               NaN
#
#         arterial_pressure_diastolic  arterial_pressure_diastolic_delay  \
# 0                              75.0                             1800.0
# 1                              75.0                             1440.0
# 8                              50.0                             4200.0
# 12                             74.0                               60.0
# 16                             75.0                              900.0
# 17                             62.0                             2820.0
# 21                             41.0                             2280.0
# 22                             79.0                             1860.0
# 24                             48.0                              540.0
# 29                             74.0                              240.0
# 32                             59.0                             2820.0
# 36                             49.0                             1800.0
# 37                             50.0                             1620.0
# 39                             50.0                              600.0
# 50                             64.0                             2580.0
# 53                             51.0                             1020.0
# 54                             52.0                              240.0
# 61                             45.0                             5580.0
# 65                             73.0                             2460.0
# 66                             63.0                             1620.0
# 70                             79.0                             1440.0
# 73                             70.0                             2520.0
# 76                             60.0                             6060.0
# 78                             69.0                             3240.0
# 83                             70.0                              240.0
# 84                             68.0                              420.0
# 85                             42.0                             1080.0
# 87                             59.0                             1620.0
# 91                             62.0                             3420.0
# 98                             58.0                             3120.0
# ...                             ...                                ...
# 115598                          NaN                                NaN
# 115601                          NaN                                NaN
# 115602                          NaN                                NaN
# 115603                          NaN                                NaN
# 115609                          NaN                                NaN
# 115611                          NaN                                NaN
# 115616                          NaN                                NaN
# 115619                          NaN                                NaN
# 115623                          NaN                                NaN
# 115629                          NaN                                NaN
# 115636                          NaN                                NaN
# 115642                          NaN                                NaN
# 115643                          NaN                                NaN
# 115650                          NaN                                NaN
# 115653                          NaN                                NaN
# 115657                          NaN                                NaN
# 115662                          NaN                                NaN
# 115665                          NaN                                NaN
# 115666                          NaN                                NaN
# 115671                          NaN                                NaN
# 115674                          NaN                                NaN
# 115675                          NaN                                NaN
# 115677                          NaN                                NaN
# 115679                          NaN                                NaN
# 115681                          NaN                                NaN
# 115685                          NaN                                NaN
# 115703                          NaN                                NaN
# 115709                          NaN                                NaN
# 115711                          NaN                                NaN
# 115715                          NaN                                NaN
#
#         heart_rate  heart_rate_delay  ...    bilirubin  bilirubin_delay  \
# 0             58.0            1800.0  ...          NaN              NaN
# 1            102.0            1440.0  ...          NaN              NaN
# 8            104.0            4260.0  ...          NaN              NaN
# 12           103.0              60.0  ...          NaN              NaN
# 16            67.0             900.0  ...          NaN              NaN
# 17           123.0            2820.0  ...          NaN              NaN
# 21           101.0            2280.0  ...          NaN              NaN
# 22           103.0            1860.0  ...          NaN              NaN
# 24            86.0             540.0  ...          NaN              NaN
# 29            93.0             300.0  ...          NaN              NaN
# 32            69.0            2820.0  ...          NaN              NaN
# 36            77.0            1800.0  ...          NaN              NaN
# 37            77.0            1680.0  ...          NaN              NaN
# 39            72.0             600.0  ...          NaN              NaN
# 50            55.0            2580.0  ...          NaN              NaN
# 53            91.0            1020.0  ...          NaN              NaN
# 54            80.0             240.0  ...          NaN              NaN
# 61            86.0            3600.0  ...          NaN              NaN
# 65            75.0            2460.0  ...          NaN              NaN
# 66            80.0            1620.0  ...          NaN              NaN
# 70           119.0            1440.0  ...          NaN              NaN
# 73            86.0            2520.0  ...          NaN              NaN
# 76           102.0            5640.0  ...          NaN              NaN
# 78           107.0            3240.0  ...          NaN              NaN
# 83            82.0             240.0  ...          NaN              NaN
# 84            84.0             420.0  ...          NaN              NaN
# 85           110.0            1080.0  ...          NaN              NaN
# 87            91.0            1620.0  ...          NaN              NaN
# 91            99.0            3420.0  ...          NaN              NaN
# 98            85.0            3120.0  ...          NaN              NaN
# ...            ...               ...  ...          ...              ...
# 115598         NaN               NaN  ...          NaN              NaN
# 115601         NaN               NaN  ...          NaN              NaN
# 115602         NaN               NaN  ...          NaN              NaN
# 115603         NaN               NaN  ...          NaN              NaN
# 115609         NaN               NaN  ...          NaN              NaN
# 115611         NaN               NaN  ...          NaN              NaN
# 115616         NaN               NaN  ...          NaN              NaN
# 115619         NaN               NaN  ...          NaN              NaN
# 115623         NaN               NaN  ...          NaN              NaN
# 115629         NaN               NaN  ...          NaN              NaN
# 115636         NaN               NaN  ...          NaN              NaN
# 115642         NaN               NaN  ...          NaN              NaN
# 115643         NaN               NaN  ...          NaN              NaN
# 115650         NaN               NaN  ...          NaN              NaN
# 115653         NaN               NaN  ...          NaN              NaN
# 115657         NaN               NaN  ...          NaN              NaN
# 115662         NaN               NaN  ...          NaN              NaN
# 115665         NaN               NaN  ...          NaN              NaN
# 115666         NaN               NaN  ...          NaN              NaN
# 115671         NaN               NaN  ...          NaN              NaN
# 115674         NaN               NaN  ...          NaN              NaN
# 115675         NaN               NaN  ...          NaN              NaN
# 115677         NaN               NaN  ...          NaN              NaN
# 115679         NaN               NaN  ...          NaN              NaN
# 115681         NaN               NaN  ...          NaN              NaN
# 115685         NaN               NaN  ...          NaN              NaN
# 115703         NaN               NaN  ...          NaN              NaN
# 115709         NaN               NaN  ...          NaN              NaN
# 115711         NaN               NaN  ...          NaN              NaN
# 115715         NaN               NaN  ...          NaN              NaN
#
#         c_reactive_protein  c_reactive_protein_delay  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 8                      NaN                       NaN
# 12                     NaN                       NaN
# 16                     NaN                       NaN
# 17                     NaN                       NaN
# 21                     NaN                       NaN
# 22                     NaN                       NaN
# 24                     NaN                       NaN
# 29                     NaN                       NaN
# 32                     NaN                       NaN
# 36                     NaN                       NaN
# 37                     NaN                       NaN
# 39                     NaN                       NaN
# 50                     NaN                       NaN
# 53                     NaN                       NaN
# 54                     NaN                       NaN
# 61                     NaN                       NaN
# 65                     NaN                       NaN
# 66                     NaN                       NaN
# 70                     NaN                       NaN
# 73                   200.9                  919920.0
# 76                     NaN                       NaN
# 78                     NaN                       NaN
# 83                     NaN                       NaN
# 84                    56.9                  149940.0
# 85                     NaN                       NaN
# 87                     NaN                       NaN
# 91                     NaN                       NaN
# 98                     NaN                       NaN
# ...                    ...                       ...
# 115598                 NaN                       NaN
# 115601                 NaN                       NaN
# 115602                 NaN                       NaN
# 115603                 NaN                       NaN
# 115609                 NaN                       NaN
# 115611                 NaN                       NaN
# 115616                 NaN                       NaN
# 115619                 NaN                       NaN
# 115623                 NaN                       NaN
# 115629                 NaN                       NaN
# 115636                 NaN                       NaN
# 115642                 NaN                       NaN
# 115643                 NaN                       NaN
# 115650                 NaN                       NaN
# 115653                 NaN                       NaN
# 115657                 NaN                       NaN
# 115662                 NaN                       NaN
# 115665                 NaN                       NaN
# 115666                 NaN                       NaN
# 115671                 NaN                       NaN
# 115674                 NaN                       NaN
# 115675                 NaN                       NaN
# 115677                 NaN                       NaN
# 115679                 NaN                       NaN
# 115681                 NaN                       NaN
# 115685                 NaN                       NaN
# 115703                 NaN                       NaN
# 115709                 NaN                       NaN
# 115711                 NaN                       NaN
# 115715                 NaN                       NaN
#
#                           ethnicity  \
# 0                             WHITE
# 1                             WHITE
# 8                             WHITE
# 12                            WHITE
# 16                            WHITE
# 17                            WHITE
# 21                            WHITE
# 22                 UNABLE TO OBTAIN
# 24                            WHITE
# 29                            OTHER
# 32           BLACK/AFRICAN AMERICAN
# 36            UNKNOWN/NOT SPECIFIED
# 37           BLACK/AFRICAN AMERICAN
# 39                            WHITE
# 50                            WHITE
# 53                            WHITE
# 54                 UNABLE TO OBTAIN
# 61                            WHITE
# 65      HISPANIC/LATINO - DOMINICAN
# 66               HISPANIC OR LATINO
# 70                            WHITE
# 73                              NaN
# 76                            OTHER
# 78                            WHITE
# 83                            WHITE
# 84                            WHITE
# 85       PATIENT DECLINED TO ANSWER
# 87           BLACK/AFRICAN AMERICAN
# 91                            WHITE
# 98                            WHITE
# ...                             ...
# 115598             UNABLE TO OBTAIN
# 115601       BLACK/AFRICAN AMERICAN
# 115602                        ASIAN
# 115603                        ASIAN
# 115609       BLACK/AFRICAN AMERICAN
# 115611       BLACK/AFRICAN AMERICAN
# 115616                        WHITE
# 115619           HISPANIC OR LATINO
# 115623                        WHITE
# 115629                        WHITE
# 115636                        WHITE
# 115642                        WHITE
# 115643                        WHITE
# 115650                        WHITE
# 115653                        WHITE
# 115657             UNABLE TO OBTAIN
# 115662                        WHITE
# 115665                        WHITE
# 115666                        WHITE
# 115671             UNABLE TO OBTAIN
# 115674                        WHITE
# 115675                        WHITE
# 115677                        WHITE
# 115679           HISPANIC OR LATINO
# 115681                        WHITE
# 115685                        WHITE
# 115703                        WHITE
# 115709             UNABLE TO OBTAIN
# 115711                        WHITE
# 115715                        WHITE
#
#                                                 diagnosis  gender  \
# 0                                 INTRACRANIAL HEMORRHAGE       M
# 1                                    S/P BOATING ACCIDENT       M
# 8                                                  SEPSIS       M
# 12                           LOWER GASTROINTESTINAL BLEED       M
# 16      ALCHOLIC CIRRHOSIS\EGD ** REMOTE EAST STONEMAN...       M
# 17                               TRACHEOBRONCHIAL MALASIA       F
# 21         FEVER;RULE-OUT MYOCARDIAL INFARCTION;TELEMETRY       F
# 22                                     ACUTE PANCREATITIS       M
# 24                           UPPER GASTROINTESTINAL BLEED       M
# 29                                         UPPER GI BLEED       F
# 32                                             BRAIN METS       F
# 36                                   NECROTIZING FASCITIS       F
# 37                                      AORTIC DISSECTION       M
# 39                                                 SEPSIS       F
# 50                                  ALTERED MENTAL STATUS       M
# 53                                       BILE DUCT INJURY       F
# 54                                      SEPSIS;CELLULITIS       M
# 61                        LEFT HIP AVASCULAR NECROSIS/SDA       F
# 65                                INTRACRANIAL HEMORRHAGE       M
# 66                                  ALTERED MENTAL STATUS       F
# 70                                SUBARACHNOID HEMORRHAGE       F
# 73                                                    NaN     NaN
# 76                                           PANCREATITIS       F
# 78       MOTOR VEHICLE ACCIDENT WITH UNSPECIFIED INJURIES       M
# 83                                   UGIB;PANCREATIC MASS       M
# 84           CONGESTIVE HEART FAILURE;ACUTE RENAL FAILURE       F
# 85                                         VARICEAL BLEED       M
# 87                                            CHOLANGITIS       M
# 91      MITRAL REGURGITATION\MITRAL VALVE REPLACEMENT ...       F
# 98                         S/P COLON RESECTION; ?ISCHEMIA       M
# ...                                                   ...     ...
# 115598   CORONARY ARTERY DISEASE;CONGESTIVE HEART FAILURE       F
# 115601                             HYPERGLYCEMIA,SEIZURES       M
# 115602                                         HEMOPTYSIS       M
# 115603                                         LIVER MASS       M
# 115609                              ALTERED MENTAL STATUS       M
# 115611                                         CHEST PAIN       M
# 115616                                             SEPSIS       F
# 115619                           DIAPGAHAMATIV HERNIA/SDA       F
# 115623                                     UPPER GI BLEED       M
# 115629                               PERICARDIAL EFFUSION       F
# 115636                                     LOWER GI BLEED       F
# 115642                                  SUBDURAL HEMATOMA       M
# 115643                                     LOWER GI BLEED       M
# 115650  JAUNDICE, GASTRIC CANCER; PERCUTANROUS TRANSHE...       M
# 115653                             HEPATIC ENCEPHALOPATHY       F
# 115657                            INTRACRANIAL HEMORRHAGE       M
# 115662                                            SEIZURE       F
# 115665                             LIVER FAILURE AND SIRS       M
# 115666                              DIABETIC KETOACIDOSIS       M
# 115671                                 SUBURAL HEMORRHAGE       M
# 115674                                         CHEST PAIN       M
# 115675                                             SEPSIS       F
# 115677                         S/P MOTOR VEHICLE ACCIDEMT       M
# 115679                           DIAPGAHAMATIV HERNIA/SDA       F
# 115681                            SUBARRACHNOID HEMMORAGE       M
# 115685                       UPPER GASTROINTESTINAL BLEED       F
# 115703                                       PANCREATITIS       M
# 115709                     LEFT LOWER EXTREMITY ULCER/SDA       F
# 115711                                  PULMONAY EMBOLISM       M
# 115715                                     SZ/HYPOTENSION       M
#
#         creatinine_yesterday  creatinine_before_yesterday  label
# 0                        NaN                          0.7    2.0
# 1                        0.6                          0.6    2.0
# 8                        1.9                          NaN    1.0
# 12                       NaN                          NaN    2.0
# 16                       NaN                          1.3    2.0
# 17                       0.7                          NaN    2.0
# 21                       NaN                          0.8    2.0
# 22                       1.3                          NaN    2.0
# 24                       NaN                          NaN    2.0
# 29                       NaN                          NaN    2.0
# 32                       NaN                          0.1    2.0
# 36                       1.7                          NaN    1.0
# 37                       2.1                          2.6    2.0
# 39                       NaN                          NaN    0.0
# 50                       NaN                          NaN    1.0
# 53                       NaN                          1.3    0.0
# 54                       0.8                          NaN    2.0
# 61                       0.7                          0.7    2.0
# 65                       NaN                          0.5    1.0
# 66                       NaN                          NaN    2.0
# 70                       0.4                          NaN    2.0
# 73                       1.8                          1.8    0.0
# 76                       0.5                          0.4    2.0
# 78                       0.9                          0.8    2.0
# 83                       NaN                          1.0    2.0
# 84                       NaN                          0.9    2.0
# 85                       NaN                          0.4    0.0
# 87                       0.6                          0.8    0.0
# 91                       NaN                          0.6    2.0
# 98                       NaN                          2.0    1.0
# ...                      ...                          ...    ...
# 115598                   NaN                          NaN    0.0
# 115601                   NaN                          NaN    2.0
# 115602                   NaN                          NaN    1.0
# 115603                   NaN                          2.4    2.0
# 115609                   NaN                          NaN    0.0
# 115611                   NaN                          NaN    0.0
# 115616                   NaN                          NaN    1.0
# 115619                   NaN                          NaN    2.0
# 115623                   NaN                          NaN    1.0
# 115629                   NaN                          NaN    2.0
# 115636                   NaN                          NaN    2.0
# 115642                   NaN                          0.9    2.0
# 115643                   NaN                          NaN    1.0
# 115650                   NaN                          NaN    2.0
# 115653                   NaN                          NaN    0.0
# 115657                   NaN                          NaN    2.0
# 115662                   NaN                          NaN    2.0
# 115665                   NaN                          0.9    2.0
# 115666                   NaN                          NaN    1.0
# 115671                   NaN                          NaN    0.0
# 115674                   NaN                          NaN    2.0
# 115675                   NaN                          NaN    1.0
# 115677                   NaN                          NaN    1.0
# 115679                   NaN                          0.6    2.0
# 115681                   0.9                          NaN    2.0
# 115685                   NaN                          NaN    1.0
# 115703                   NaN                          NaN    1.0
# 115709                   NaN                          NaN    1.0
# 115711                   NaN                          NaN    2.0
# 115715                   NaN                          NaN    1.0
#
# [36251 rows x 64 columns]
